# %%
########################################################
# Project - GAN generate pixel art like ff6 spritesheets
#
# Target - generated image with resolution 32x32 
#
# This notebook is for education purpose only.
# 
# All input images used are found at http://finalfantasy.wikia.com/
# 
########################################################

############################################
# ***Go straight to Part 3 - GAN***
# ***if data images is already downloaded, pre-processed, and saved as x_train.pickle***
############################################

############################################
# Project folders

# data/ 
#   pickle files contain webpage hyperlinks array
#   images downloaded from website

# img/ 
#   pre-processed images, input from data/
#     by spliting large spritesheets
#     removed blank images, small character images
#   copied single character images 96x96

# gan_images/
#   generated images of current model training

# train001/ -> train00X/
#   saved version of trained model .h5 file
#   gen_images/ is generated images during model training

############################################

# %%
#####################################################
# Part 1 - Get Images Online
#####################################################

#####################################################
# website structure
#   http://finalfantasy.wikia.com/

# 4 web pages, each page got over hundred links to indivdual web page for each spritesheet 
# for each spritesheet web page (there are total of hundreds), contains one image link

# each page link - example
# http://finalfantasy.wikia.com/wiki/File:FFRK_AC_Cloud.png

# each image page contains one a link, html soup analysis
# <div class="fullImageLink" id="file"><a href="https://vignette.wikia.nocookie.net/finalfantasy/images/5/53/FFRK_AC_Cloud.png/revision/latest?cb=20150930085325"><img alt="File:FFRK AC Cloud.png" src="https://vignette.wikia.nocookie.net/finalfantasy/images/5/53/FFRK_AC_Cloud.png/revision/latest?cb=20150930085325" data-image-name="FFRK AC Cloud.png" data-image-key="FFRK_AC_Cloud.png" data-src="https://vignette.wikia.nocookie.net/finalfantasy/images/5/53/FFRK_AC_Cloud.png/revision/latest?cb=20150930085325" class="lzyPlcHld lzyTrns lzyLoaded" onload="if(typeof ImgLzy==='object'){ImgLzy.load(this)}" width="96" height="96"><noscript><img alt="File:FFRK AC Cloud.png" src="https://vignette.wikia.nocookie.net/finalfantasy/images/5/53/FFRK_AC_Cloud.png/revision/latest?cb=20150930085325" width="96" height="96" data-image-name="FFRK AC Cloud.png" data-image-key="FFRK_AC_Cloud.png" /></noscript></a><div class="mw-filepage-resolutioninfo">No higher resolution available.</div></div>
#####################################################

# %%
# packages
import bs4 as bs
import pickle
import requests

import numpy as np
import os
import time

from tqdm import tnrange, tqdm_notebook

# %%
data_folder = 'data'
img_folder = 'img'
domain = 'http://finalfantasy.wikia.com/'

# %%
# get all image a links from html page
def save_img_links(i, page_link):

    #create folder data if not exist
    if not os.path.exists(data_folder):
        os.makedirs(data_folder)
        
    save_path = "%s/ff6pages%d.pickle" % (data_folder, i)
    
    # do not get links if already retrieved
    if os.path.exists(save_path):
        print ('%s already exist.' % (save_path))
        return
    
    resp = requests.get(page_link)
    soup = bs.BeautifulSoup(resp.text, 'lxml')
    div = soup.find('div', {'class': 'category-page__members'})

    img_links = []
    for a_tag in div.findAll('a'):
        a_link = a_tag['href']
        img_links.append(a_link)
        print (a_link)
        
    
    with open(save_path,"wb") as f:
        pickle.dump(img_links, f)
        
    return img_links
    
# html soup analysis
# soup.find('div', {'class': 'category-page__members'})
# soup.find('a', {'class': 'category-page__member-link'})

# %%
# run to get page html a links
def get_page_links():
    
    page_links = []

    # 4 pages of spritesheets
    page_links.append('http://finalfantasy.wikia.com/wiki/Category:Final_Fantasy_Record_Keeper_Sprite_Images')
    page_links.append('http://finalfantasy.wikia.com/wiki/Category:Final_Fantasy_Record_Keeper_Sprite_Images?from=FFRK+Gladiator+sprites.png')
    page_links.append('http://finalfantasy.wikia.com/wiki/Category:Final_Fantasy_Record_Keeper_Sprite_Images?from=FFRK+Reynn.png')
    page_links.append('http://finalfantasy.wikia.com/wiki/Category:Final_Fantasy_Record_Keeper_Sprite_Images?from=FFRK+Ysayle.png')

    return page_links

def run_save_img_links():
    
    page_links = get_page_links()
    for i, page_link in enumerate(page_links):
        save_img_links(i, page_link)

run_save_img_links()
# Out:
# /wiki/File:FFRK_AC_Cloud.png
# /wiki/File:FFRK_Ace_sprites.png
# /wiki/File:FFRK_Ace.png
# /wiki/File:FFRK_Adult_Palom.png
# /wiki/File:FFRK_Adult_Porom.png
# /wiki/File:FFRK_Adult_Rydia_sprites.png
# /wiki/File:FFRK_Adult_Rydia.png
# /wiki/File:FFRK_Aemo_sprites.png
# /wiki/File:FFRK_Aemo.png
# /wiki/File:FFRK_Aerith_Spell_Casting_Frame.png
# /wiki/File:FFRK_Aerith_Sprite.png
# /wiki/File:FFRK_Aerith_sprites.png
# /wiki/File:FFRK_Agrias_sprites.png
# /wiki/File:FFRK_Agrias.png
# /wiki/File:FFRK_Alma_sprites.png
# /wiki/File:FFRK_Alma.png
# /wiki/File:FFRK_Alphinaud_sprites.png
# /wiki/File:FFRK_Alphinaud.png
# /wiki/File:FFRK_Amarant_sprites.png
# /wiki/File:FFRK_Amarant.png
# /wiki/File:FFRK_Angeal_sprites.png
# /wiki/File:FFRK_Angeal.png
# /wiki/File:FFRK_Angelo_Sprite.png
# /wiki/File:FFRK_Aphmau_sprites.png
# /wiki/File:FFRK_Aphmau.png
# /wiki/File:FFRK_Aranea_FFXV_sprites.png
# /wiki/File:FFRK_Aranea.png
# /wiki/File:FFRK_Arc_White_Mage_sprites.png
# /wiki/File:FFRK_Arc_White_Mage.png
# /wiki/File:FFRK_Aria_FFIII_sprites.png
# /wiki/File:FFRK_Aria.png
# /wiki/File:FFRK_Ashe_sprites.png
# /wiki/File:FFRK_Ashe.png
# /wiki/File:FFRK_Auron_Sprite.png
# /wiki/File:FFRK_Auron_sprites.png
# /wiki/File:FFRK_Ayame_sprites.png
# /wiki/File:FFRK_Ayame.png
# /wiki/File:FFRK_Balthier_sprites.png
# /wiki/File:FFRK_Balthier.png
# /wiki/File:FFRK_Barbariccia_sprites.png
# /wiki/File:FFRK_Barbariccia.png
# /wiki/File:FFRK_Bard_Sprite.png
# /wiki/File:FFRK_Bard_sprites.png
# /wiki/File:FFRK_Barret_sprites.png
# /wiki/File:FFRK_Barret.png
# /wiki/File:FFRK_Bartz_Freelancer_sprites.png
# /wiki/File:FFRK_Bartz_Knight_sprites.png
# /wiki/File:FFRK_Bartz.png
# /wiki/File:FFRK_Basch_sprites.png
# /wiki/File:FFRK_Basch.png
# /wiki/File:FFRK_Beastmaster_Krile.png
# /wiki/File:FFRK_Beastmaster_Sprite.png
# /wiki/File:FFRK_Beastmaster_sprites.png
# /wiki/File:FFRK_Beatrix_sprites.png
# /wiki/File:FFRK_Beatrix.png
# /wiki/File:FFRK_Belgemine.png
# /wiki/File:FFRK_Berserker_sprites.png
# /wiki/File:FFRK_Berserker.png
# /wiki/File:FFRK_Biggs.png
# /wiki/File:FFRK_Black_Mage_Sprite.png
# /wiki/File:FFRK_Black_Mage_sprites.png
# /wiki/File:FFRK_Blazefire_Saber_Sprite.png
# /wiki/File:FFRK_Blue_Mage_Sprite.png
# /wiki/File:FFRK_Blue_Mage_sprites.png
# /wiki/File:FFRK_Braska_sprites.png
# /wiki/File:FFRK_Braska.png
# /wiki/File:FFRK_Brave_Blade_Sprite.png
# /wiki/File:FFRK_Braveheart_Sprite.png
# /wiki/File:FFRK_Brotherhood_Sprite_2.png
# /wiki/File:FFRK_Buster_Sword_Sprite.png
# /wiki/File:FFRK_Cait_Sith_FFVII_sprites.png
# /wiki/File:FFRK_Cait_Sith.png
# /wiki/File:FFRK_Cater_sprites.png
# /wiki/File:FFRK_Cater.png
# /wiki/File:FFRK_Cecil_DFF.png
# /wiki/File:FFRK_Cecil_Paladin_DFF_sprites.png
# /wiki/File:FFRK_Cecil_Sprite.png
# /wiki/File:FFRK_Celes_Actress_sprites.png
# /wiki/File:FFRK_Celes_sprites.png
# /wiki/File:FFRK_Celes.png
# /wiki/File:FFRK_Ceodore_sprites.png
# /wiki/File:FFRK_Ceodore.png
# /wiki/File:FFRK_Chakram_FFVIII_Sprite.png
# /wiki/File:FFRK_Chaos_Blade_FFXII_Sprite.png
# /wiki/File:FFRK_Chaos%27s_Revenge_XIII-2_Sprite.png
# /wiki/File:FFRK_Child_Rydia_Sprite.png
# /wiki/File:FFRK_Child_Rydia_sprites.png
# /wiki/File:FFRK_Cid_FFIV.png
# /wiki/File:FFRK_Cid_Garlond.png
# /wiki/File:FFRK_Cid_Highwind_sprites.png
# /wiki/File:FFRK_Cid_Highwind.png
# /wiki/File:FFRK_Cid_nan_Garlond_sprites.png
# /wiki/File:FFRK_Cid_Pollendina_sprites.png
# /wiki/File:FFRK_Cid_Raines_Sprite.png
# /wiki/File:FFRK_Cid_Raines_sprites.png
# /wiki/File:FFRK_Cidolfus_Orlandeau_sprites.png
# /wiki/File:FFRK_Cinque_sprites.png
# /wiki/File:FFRK_Cinque.png
# /wiki/File:FFRK_Cloud_(Festival)_sprites.png
# /wiki/File:FFRK_Cloud_KH_sprites.png
# /wiki/File:FFRK_Cloud_of_Darkness_sprites.png
# /wiki/File:FFRK_Cloud_of_Darkness.png
# /wiki/File:FFRK_Cloud_FFVII_Sprite.png
# /wiki/File:FFRK_Cloud_FFVII_sprites.png
# /wiki/File:FFRK_Cloud_VIIAC_sprites.png
# /wiki/File:FFRK_Curilla_sprites.png
# /wiki/File:FFRK_Curilla.png
# /wiki/File:FFRK_Cyan_Sprite.png
# /wiki/File:FFRK_Cyan_sprites.png
# /wiki/File:FFRK_Dancer_Sprite.png
# /wiki/File:FFRK_Dancer_sprites.png
# /wiki/File:FFRK_Dark_Knight_Cecil_Sprite.png
# /wiki/File:FFRK_Dark_Knight_Cecil_sprites.png
# /wiki/File:FFRK_Dark_Knight.png
# /wiki/File:FFRK_Deci_Sprite.png
# /wiki/File:FFRK_Delita_Holy_Knight_sprites.png
# /wiki/File:FFRK_Delita.png
# /wiki/File:FFRK_Desch_sprites.png
# /wiki/File:FFRK_Desch.png
# /wiki/File:FFRK_Deuce_sprites.png
# /wiki/File:FFRK_Deuce.png
# /wiki/File:FFRK_Devout_Sprite.png
# /wiki/File:FFRK_Devout_sprites.png
# /wiki/File:FFRK_Devout.png
# /wiki/File:FFRK_Dorgann_sprites.png
# /wiki/File:FFRK_Dorgann.png
# /wiki/File:FFRK_Dr._Mog_Sprite.png
# /wiki/File:FFRK_Dr._Mog_sprites.png
# /wiki/File:FFRK_Dragoon_sprites.png
# /wiki/File:FFRK_Dragoon.png
# /wiki/File:FFRK_Echo_sprites.png
# /wiki/File:FFRK_Echo.png
# /wiki/File:FFRK_Edea_sprites.png
# /wiki/File:FFRK_Edea.png
# /wiki/File:FFRK_Edgar_sprites.png
# /wiki/File:FFRK_Edgar.png
# /wiki/File:FFRK_Edge_sprites.png
# /wiki/File:FFRK_Edge.png
# /wiki/File:FFRK_Edward_sprites.png
# /wiki/File:FFRK_Edward.png
# /wiki/File:FFRK_Eight_sprites.png
# /wiki/File:FFRK_Eight.png
# /wiki/File:FFRK_Eiko_(Trance)_sprites.png
# /wiki/File:FFRK_Eiko_sprites.png
# /wiki/File:FFRK_Eiko.png
# /wiki/File:FFRK_Elarra_Sprite.png
# /wiki/File:FFRK_Elarra_sprites.png
# /wiki/File:FFRK_Elena_sprites.png
# /wiki/File:FFRK_Elena.png
# /wiki/File:FFRK_Emperor_Mateus_sprites.png
# /wiki/File:FFRK_Emperor_Mateus.png
# /wiki/File:FFRK_Enhancer_Sprite.png
# /wiki/File:FFRK_Enna_Kros_sprites.png
# /wiki/File:FFRK_Enna_Kros.png
# /wiki/File:FFRK_Estinien_sprites.png
# /wiki/File:FFRK_Estinien.png
# /wiki/File:FFRK_Evoker_sprites.png
# /wiki/File:FFRK_Exdeath_sprites.png
# /wiki/File:FFRK_Exdeath.png
# /wiki/File:FFRK_Famed_Mimic_Gogo.png
# /wiki/File:FFRK_Fang_sprites.png
# /wiki/File:FFRK_Fang.png
# /wiki/File:FFRK_Faris_Freelancer_sprites.png
# /wiki/File:FFRK_Faris_Summoner.png
# /wiki/File:FFRK_Faris_Summoner_sprites.png
# /wiki/File:FFRK_Faris.png
# /wiki/File:FFRK_Festival_Cloud.png
# /wiki/File:FFRK_Firion_sprites.png
# /wiki/File:FFRK_Firion.png
# /wiki/File:FFRK_Fran_sprites.png
# /wiki/File:FFRK_Fran.png
# /wiki/File:FFRK_Freya_sprites.png
# /wiki/File:FFRK_Freya.png
# /wiki/File:FFRK_Fujin_FFVIII_sprites.png
# /wiki/File:FFRK_Fujin.png
# /wiki/File:FFRK_Fusoya_sprites.png
# /wiki/File:FFRK_Fusoya.png
# /wiki/File:FFRK_Gabranth_sprites.png
# /wiki/File:FFRK_Gabranth.png
# /wiki/File:FFRK_Gaffgarion_sprites.png
# /wiki/File:FFRK_Gaffgarion.png
# /wiki/File:FFRK_Galuf_Freelancer_sprites.png
# /wiki/File:FFRK_Galuf_Freelancer.png
# /wiki/File:FFRK_Galuf_Monk.png
# /wiki/File:FFRK_Galuf_Monk_sprites.png
# /wiki/File:FFRK_Garland_FFI_sprites.png
# /wiki/File:FFRK_Garland.png
# /wiki/File:FFRK_Garnet_(Trance)_sprites.png
# /wiki/File:FFRK_Garnet_Show_of_Resolve_sprites.png
# /wiki/File:FFRK_Garnet_sprites.png
# /wiki/File:FFRK_Garnet.png
# /wiki/File:FFRK_Gau_sprites.png
# /wiki/File:FFRK_Gau.png
# /wiki/File:FFRK_General_Leo.png
# /wiki/File:FFRK_Geomancer_Sprite.png
# /wiki/File:FFRK_Geomancer_sprites.png
# /wiki/File:FFRK_Gilgamesh_sprites.png
# /wiki/File:FFRK_Gilgamesh.png
# /wiki/File:FFRK_Ginnem.png
# /wiki/File:FFRK_Gladiator_Job.png
# /wiki/File:FFRK_Gladiator_sprites.png
# /wiki/File:FFRK_Gladiolus_sprites.png
# /wiki/File:FFRK_Gladiolus.png
# /wiki/File:FFRK_Gogo_FFV_sprites.png
# /wiki/File:FFRK_Gogo_FFVI_sprites.png
# /wiki/File:FFRK_Gogo_FFVI.png
# /wiki/File:FFRK_Golbez_sprites.png
# /wiki/File:FFRK_Golbez.png
# /wiki/File:FFRK_Gordon_sprites.png
# /wiki/File:FFRK_Gordon.png
# /wiki/File:FFRK_Guy_sprites.png
# /wiki/File:FFRK_Guy.png
# /wiki/File:FFRK_Haurchefant_sprites.png
# /wiki/File:FFRK_Haurchefant.png
# /wiki/File:FFRK_Highway_Star_FFXII_Sprite.png
# /wiki/File:FFRK_Hilda_FFII.png
# /wiki/File:FFRK_Hilda_sprites.png
# /wiki/File:FFRK_Hope_FFXIII-2.png
# /wiki/File:FFRK_Hope_sprites.png
# /wiki/File:FFRK_Hope_XIII2_sprites.png
# /wiki/File:FFRK_Hope.png
# /wiki/File:FFRK_Hyperion_FFVIII_Sprite.png
# /wiki/File:FFRK_Ichiro_Hazama.png
# /wiki/File:FFRK_Ignis_FFXV.png
# /wiki/File:FFRK_Ignis_sprites.png
# /wiki/File:FFRK_Ingus_Knight_sprites.png
# /wiki/File:FFRK_Ingus.png
# /wiki/File:FFRK_Iris_sprites.png
# /wiki/File:FFRK_Iris.png
# /wiki/File:FFRK_Irvine_sprites.png
# /wiki/File:FFRK_Irvine.png
# /wiki/File:FFRK_Isaaru.png
# /wiki/File:FFRK_Jack_T0_sprites.png
# /wiki/File:FFRK_Jack_Type-0.png
# /wiki/File:FFRK_Jecht_sprites.png
# /wiki/File:FFRK_Jecht.png
# /wiki/File:FFRK_Jihl.png
# /wiki/File:FFRK_Josef_sprites.png
# /wiki/File:FFRK_Joseph_Sprite.png
# /wiki/File:FFRK_Kain_Holy_Dragoon.png
# /wiki/File:FFRK_Kain_IVTAY_sprites.png
# /wiki/File:FFRK_Kain_Sprite.png
# /wiki/File:FFRK_Kain_sprites.png
# /wiki/File:FFRK_Kefka_sprites.png
# /wiki/File:FFRK_Kefka.png
# /wiki/File:FFRK_Kelger_sprites.png
# /wiki/File:FFRK_Kelger.png
# /wiki/File:FFRK_KH_Cloud.png
# /wiki/File:FFRK_KH_Squall.png
# /wiki/File:FFRK_KH_Tyro.png
# /wiki/File:FFRK_Kimahri_sprites.png
# /wiki/File:FFRK_Kimahri.png
# /wiki/File:FFRK_King_sprites.png
# /wiki/File:FFRK_King_Type-0.png
# /wiki/File:FFRK_Kiros_sprites.png
# /wiki/File:FFRK_Kiros.png
# /wiki/File:FFRK_Knight_Bartz.png
# /wiki/File:FFRK_Knight_Sprite.png
# /wiki/File:FFRK_Knight_sprites.png
# /wiki/File:FFRK_Krile_Beastmaster_sprites.png
# /wiki/File:FFRK_Krile_Freelancer_sprites.png
# /wiki/File:FFRK_Krile.png
# /wiki/File:FFRK_Kuja_sprites.png
# /wiki/File:FFRK_Kuja.png
# /wiki/File:FFRK_Laguna_sprites.png
# /wiki/File:FFRK_Laguna.png
# /wiki/File:FFRK_Lann_sprites.png
# /wiki/File:FFRK_Lann.png
# /wiki/File:FFRK_Larsa_sprites.png
# /wiki/File:FFRK_Larsa.png
# /wiki/File:FFRK_Leila_sprites.png
# /wiki/File:FFRK_Leila.png
# /wiki/File:FFRK_Lenna_Freelancer_sprites.png
# /wiki/File:FFRK_Lenna_Freelancer.png
# /wiki/File:FFRK_Lenna_sprites.png
# /wiki/File:FFRK_Lenna.png
# /wiki/File:FFRK_Leo_sprites.png
# /wiki/File:FFRK_Leon_sprites.png
# /wiki/File:FFRK_Leon.png
# /wiki/File:FFRK_Lightning_FFXIII-2.png
# /wiki/File:FFRK_Lightning_Knight_of_Etro_sprites.png
# /wiki/File:FFRK_Lightning_sprites.png
# /wiki/File:FFRK_Lightning.png
# /wiki/File:FFRK_Lilisette_sprites.png
# /wiki/File:FFRK_Lilisette.png
# /wiki/File:FFRK_Lion_sprites.png
# /wiki/File:FFRK_Lion.png
# /wiki/File:FFRK_Locke_sprites.png
# /wiki/File:FFRK_Locke.png
# /wiki/File:FFRK_Lulu_sprites.png
# /wiki/File:FFRK_Lulu.png
# /wiki/File:FFRK_Luneth_Dark_Knight_sprites.png
# /wiki/File:FFRK_Luneth_Warrior_sprites.png
# /wiki/File:FFRK_Luneth_Warrior.png
# /wiki/File:FFRK_Machina_sprites.png
# /wiki/File:FFRK_Machina.png
# /wiki/File:FFRK_Magus_Sprite.png
# /wiki/File:FFRK_Magus_sprites.png
# /wiki/File:FFRK_Magus.png
# /wiki/File:FFRK_Marach_sprites.png
# /wiki/File:FFRK_Marach.png
# /wiki/File:FFRK_Marche_sprites.png
# /wiki/File:FFRK_Marche.png
# /wiki/File:FFRK_Marcus_sprites.png
# /wiki/File:FFRK_Marcus.png
# /wiki/File:FFRK_Maria_sprites.png
# /wiki/File:FFRK_Maria.png
# /wiki/File:FFRK_Masamune_FFVII_Sprite.png
# /wiki/File:FFRK_Master_FFI.png
# /wiki/File:FFRK_Master_Monk_FFI_sprites.png
# /wiki/File:FFRK_Matoya_FFI_sprites.png
# /wiki/File:FFRK_Matoya_FFI.png
# /wiki/File:FFRK_Meia_sprites.png
# /wiki/File:FFRK_Meia.png
# /wiki/File:FFRK_Meliadoul_sprites.png
# /wiki/File:FFRK_Meliadoul.png
# /wiki/File:FFRK_Mercenary_Ramza.png
# /wiki/File:FFRK_Minfilia_sprites.png
# /wiki/File:FFRK_Minfilia.png
# /wiki/File:FFRK_Mini_sprites.png
# /wiki/File:FFRK_Minwu_sprites.png
# /wiki/File:FFRK_Minwu.png
# /wiki/File:FFRK_Mog_sprites.png
# /wiki/File:FFRK_Mog.png
# /wiki/File:FFRK_Monk_Sprite.png
# /wiki/File:FFRK_Monk_sprites.png
# /wiki/File:FFRK_Montblanc_sprites.png
# /wiki/File:FFRK_Montblanc.png
# /wiki/File:FFRK_Morrow_sprites.png
# /wiki/File:FFRK_Morrow.png
# /wiki/File:FFRK_Mustadio.png
# /wiki/File:FFRK_Nabaat_sprites.png
# /wiki/File:FFRK_Nine_sprites.png
# /wiki/File:FFRK_Nine.png
# /wiki/File:FFRK_Ninja_sprites.png
# /wiki/File:FFRK_Ninja.png
# /wiki/File:FFRK_Nobuo_Uematsu_Sprite.png
# /wiki/File:FFRK_Noctis_sprites.png
# /wiki/File:FFRK_Noctis.png
# /wiki/File:FFRK_Noel_sprites.png
# /wiki/File:FFRK_Noel.png
# /wiki/File:FFRK_Onion_Knight_FFIII.png
# /wiki/File:FFRK_Onion_Knight_Sprite.png
# /wiki/File:FFRK_Onion_Knight_sprites.png
# /wiki/File:FFRK_Opera_Celes.png
# /wiki/File:FFRK_Orlandeau.png
# /wiki/File:FFRK_Orran_sprites.png
# /wiki/File:FFRK_Orran.png
# /wiki/File:FFRK_Ovelia.png
# /wiki/File:FFRK_Paine_sprites.png
# /wiki/File:FFRK_Paine.png
# /wiki/File:FFRK_Paladin_Cecil_sprites.png
# /wiki/File:FFRK_Palom_IVTAY_sprites.png
# /wiki/File:FFRK_Palom_sprites.png
# /wiki/File:FFRK_Palom.png
# /wiki/File:FFRK_Papalymo_sprites.png
# /wiki/File:FFRK_Papalymo.png
# /wiki/File:FFRK_Penelo_sprites.png
# /wiki/File:FFRK_Penelo.png
# /wiki/File:FFRK_Porom_IVTAY_sprites.png
# /wiki/File:FFRK_Porom_sprites.png
# /wiki/File:FFRK_Porom.png
# /wiki/File:FFRK_Princess_Sarisa_sprites.png
# /wiki/File:FFRK_Princess_Sarisa.png
# /wiki/File:FFRK_Prishe_sprites.png
# /wiki/File:FFRK_Prishe.png
# /wiki/File:FFRK_Prompto_sprites.png
# /wiki/File:FFRK_Prompto.png
# /wiki/File:FFRK_Queen_(updated)_sprites.png
# /wiki/File:FFRK_Queen_sprites.png
# /wiki/File:FFRK_Queen.png
# /wiki/File:FFRK_Quina_sprites.png
# /wiki/File:FFRK_Quina.png
# /wiki/File:FFRK_Quistis_sprites.png
# /wiki/File:FFRK_Quistis.png
# /wiki/File:FFRK_Raijin_FFVIII_sprites.png
# /wiki/File:FFRK_Raijin.png
# /wiki/File:FFRK_Ramza_Mercenary_sprites.png
# /wiki/File:FFRK_Ramza_sprites.png
# /wiki/File:FFRK_Ramza.png
# /wiki/File:FFRK_Ranger_sprites.png
# /wiki/File:FFRK_Ranger.png
# /wiki/File:FFRK_Rapha_sprites.png
# /wiki/File:FFRK_Rapha.png
# /wiki/File:FFRK_Red_Classic.png
# /wiki/File:FFRK_Red_Mage_Sprite.png
# /wiki/File:FFRK_Red_Mage_sprites.png
# /wiki/File:FFRK_Red_XIII_sprites.png
# /wiki/File:FFRK_Red_XIII.png
# /wiki/File:FFRK_Refia_Monk_sprites.png
# /wiki/File:FFRK_Refia_Monk.png
# /wiki/File:FFRK_Reks_sprites.png
# /wiki/File:FFRK_Reks.png
# /wiki/File:FFRK_Relm_sprites.png
# /wiki/File:FFRK_Relm.png
# /wiki/File:FFRK_Rem_sprites.png
# /wiki/File:FFRK_Rem.png
# /wiki/File:FFRK_Reno_sprites.png
# /wiki/File:FFRK_Reno.png
# /wiki/File:FFRK_Reynn_sprites.png
# /wiki/File:FFRK_Reynn.png
# /wiki/File:FFRK_Ricard_sprites.png
# /wiki/File:FFRK_Ricard.png
# /wiki/File:FFRK_Rikku_Divesuit_sprites.png
# /wiki/File:FFRK_Rikku_sprites.png
# /wiki/File:FFRK_Rikku_X2_sprites.png
# /wiki/File:FFRK_Rikku.png
# /wiki/File:FFRK_Riku_sprites.png
# /wiki/File:FFRK_Riku.png
# /wiki/File:FFRK_Rinoa_Ballroom_Sprite.png
# /wiki/File:FFRK_Rinoa_Dress_sprites.png
# /wiki/File:FFRK_Rinoa_sprites.png
# /wiki/File:FFRK_Rinoa.png
# /wiki/File:FFRK_Rosa_sprites.png
# /wiki/File:FFRK_Rosa.png
# /wiki/File:FFRK_Rubicante_Player.png
# /wiki/File:FFRK_Rubicante_sprites.png
# /wiki/File:FFRK_Rude_sprites.png
# /wiki/File:FFRK_Rude.png
# /wiki/File:FFRK_Rufus_sprites.png
# /wiki/File:FFRK_Rufus.png
# /wiki/File:FFRK_Sabin_sprites.png
# /wiki/File:FFRK_Sabin.png
# /wiki/File:FFRK_Sage_Sprite.png
# /wiki/File:FFRK_Sage_sprites.png
# /wiki/File:FFRK_Samurai_sprites.png
# /wiki/File:FFRK_Samurai.png
# /wiki/File:FFRK_Sarah_FFI_sprites.png
# /wiki/File:FFRK_Sarah_FFI.png
# /wiki/File:FFRK_Save_the_Queen_FFIX_Sprite.png
# /wiki/File:FFRK_Sazh_sprites.png
# /wiki/File:FFRK_Sazh.png
# /wiki/File:FFRK_Scott_sprites.png
# /wiki/File:FFRK_Scott.png
# /wiki/File:FFRK_Seifer_sprites.png
# /wiki/File:FFRK_Seifer.png
# /wiki/File:FFRK_Selphie_Garden_Uniform_sprites.png
# /wiki/File:FFRK_Selphie_sprites.png
# /wiki/File:FFRK_Selphie.png
# /wiki/File:FFRK_Sephiroth_Executioner_sprites.png
# /wiki/File:FFRK_Sephiroth_Sprite.png
# /wiki/File:FFRK_Sephiroth_sprites.png
# /wiki/File:FFRK_Serah_sprites.png
# /wiki/File:FFRK_Serah.png
# /wiki/File:FFRK_Setzer_sprites.png
# /wiki/File:FFRK_Setzer.png
# /wiki/File:FFRK_Seven_sprites.png
# /wiki/File:FFRK_Seven.png
# /wiki/File:FFRK_Seymour_Sprite.png
# /wiki/File:FFRK_Seymour_sprites.png
# /wiki/File:FFRK_Shadow_FFVI.png
# /wiki/File:FFRK_Shadow_sprites.png
# /wiki/File:FFRK_Shantotto.png
# /wiki/File:FFRK_Shelke_sprites.png
# /wiki/File:FFRK_Shelke.png
# /wiki/File:FFRK_Shield_of_Light_Sprite.png
# /wiki/File:FFRK_Shirtless_Sephiroth.png
# /wiki/File:FFRK_Short_Hair_Garnet.png
# /wiki/File:FFRK_Sice_sprites.png
# /wiki/File:FFRK_Sice.png
# /wiki/File:FFRK_Snow_sprites.png
# /wiki/File:FFRK_Snow.png
# /wiki/File:FFRK_Sora_sprites.png
# /wiki/File:FFRK_Sora.png
# /wiki/File:FFRK_Souba_VIIAC_Sprite.png
# /wiki/File:FFRK_Spellblade_Sprite.png
# /wiki/File:FFRK_Spellblade_sprites.png
# /wiki/File:FFRK_spritesheet_Aerith.png
# /wiki/File:FFRK_spritesheet_Arc_White_Mage.png
# /wiki/File:FFRK_spritesheet_Balthier.png
# /wiki/File:FFRK_spritesheet_Celes.png
# /wiki/File:FFRK_spritesheet_Cloud_FFVII.png
# /wiki/File:FFRK_spritesheet_Cyan.png
# /wiki/File:FFRK_spritesheet_Dark_Cecil.png
# /wiki/File:FFRK_spritesheet_Deci.png
# /wiki/File:FFRK_spritesheet_Edgar.png
# /wiki/File:FFRK_spritesheet_Fran.png
# /wiki/File:FFRK_spritesheet_Garnet.png
# /wiki/File:FFRK_spritesheet_Gordon.png
# /wiki/File:FFRK_spritesheet_Irvine.png
# /wiki/File:FFRK_spritesheet_Joseph.png
# /wiki/File:FFRK_spritesheet_Kain.png
# /wiki/File:FFRK_spritesheet_Lenna.png
# /wiki/File:FFRK_spritesheet_Locke.png
# /wiki/File:FFRK_spritesheet_Luneth_Warrior.png
# /wiki/File:FFRK_spritesheet_Paladin_Cecil.png
# /wiki/File:FFRK_spritesheet_Quina.png
# /wiki/File:FFRK_spritesheet_Quistis.png
# /wiki/File:FFRK_spritesheet_Red_XIII.png
# /wiki/File:FFRK_spritesheet_Refia_Monk.png
# /wiki/File:FFRK_spritesheet_Ricard.png
# /wiki/File:FFRK_spritesheet_Rinoa.png
# /wiki/File:FFRK_spritesheet_Rydia.png
# /wiki/File:FFRK_spritesheet_Sabin.png
# /wiki/File:FFRK_spritesheet_Selphie.png
# /wiki/File:FFRK_spritesheet_Sephiroth.png
# /wiki/File:FFRK_spritesheet_Snow.png
# /wiki/File:FFRK_spritesheet_Squall.png
# /wiki/File:FFRK_spritesheet_Terra.png
# /wiki/File:FFRK_spritesheet_Tidus.png
# /wiki/File:FFRK_spritesheet_Tifa.png
# /wiki/File:FFRK_spritesheet_Vanille.png
# /wiki/File:FFRK_spritesheet_Vivi.png
# /wiki/File:FFRK_spritesheet_Wakka.png
# /wiki/File:FFRK_spritesheet_Warrior_of_Light.png
# /wiki/File:FFRK_spritesheet_Yuna.png
# /wiki/File:FFRK_Squall_Garden_Uniform_sprites.png
# /wiki/File:FFRK_Squall_KH_sprites.png
# /wiki/File:FFRK_Squall_SeeD_Uniform_sprites.png
# /wiki/File:FFRK_Squall_SeeD_Uniform.png
# /wiki/File:FFRK_Squall_sprites.png
# /wiki/File:FFRK_Squall.png
# /wiki/File:FFRK_Steiner_sprites.png
# /wiki/File:FFRK_Steiner.png
# /wiki/File:FFRK_Strago_sprites.png
# /wiki/File:FFRK_Strago.png
# /wiki/File:FFRK_Summoner_Sprite.png
# /wiki/File:FFRK_Summoner_sprites.png
# /wiki/File:FFRK_Tama_sprites.png
# /wiki/File:FFRK_Tama.png
# /wiki/File:FFRK_Tellah_sprites.png
# /wiki/File:FFRK_Tellah.png
# /wiki/File:FFRK_Terra_DFF_sprites.png
# /wiki/File:FFRK_Terra_DFF.png
# /wiki/File:FFRK_Terra_Esper_sprites.png
# /wiki/File:FFRK_Terra_Sprite.png
# /wiki/File:FFRK_Terra_Sprite2.png
# /wiki/File:FFRK_Terra_sprites.png
# /wiki/File:FFRK_Tetsuya_Nomura.png
# /wiki/File:FFRK_Thancred_sprites.png
# /wiki/File:FFRK_Thancred.png
# /wiki/File:FFRK_Thief_FFI_sprites.png
# /wiki/File:FFRK_Thief_FFI.png
# /wiki/File:FFRK_Thief_Job.png
# /wiki/File:FFRK_Thief_Rikku.png
# /wiki/File:FFRK_Thief_Sprite.png
# /wiki/File:FFRK_Thief_sprites.png
# /wiki/File:FFRK_Tidus_A_Fleeting_Dream.png
# /wiki/File:FFRK_Tidus_Dreams_of_Glory_sprites.png
# /wiki/File:FFRK_Tidus_sprites.png
# /wiki/File:FFRK_Tidus.png
# /wiki/File:FFRK_Tifa_Sprite.png
# /wiki/File:FFRK_Tifa_sprites.png
# /wiki/File:FFRK_Tifa_VIIAC_sprites.png
# /wiki/File:FFRK_Tifa_VIIAC.png
# /wiki/File:FFRK_Time_Mage_Sprite.png
# /wiki/File:FFRK_Time_Mage_sprites.png
# /wiki/File:FFRK_Tyro_Black-Robed_Keeper_sprites.png
# /wiki/File:FFRK_Tyro_Sprite.png
# /wiki/File:FFRK_Tyro_sprites.png
# /wiki/File:FFRK_Ultima_Weapon_FFVIII_Weapon_Sprite.png
# /wiki/File:FFRK_Ultimecia_sprites.png
# /wiki/File:FFRK_Ultimecia.png
# /wiki/File:FFRK_Umaro_sprites.png
# /wiki/File:FFRK_Umaro.png
# /wiki/File:FFRK_Unknown_DQ_Wardrobe_Record_2.png
# /wiki/File:FFRK_Unknown_DQ_Wardrobe_Record.png
# /wiki/File:FFRK_Ursula_sprites.png
# /wiki/File:FFRK_Ursula.png
# /wiki/File:FFRK_Vaan_sprites.png
# /wiki/File:FFRK_Vaan.png
# /wiki/File:FFRK_Vanille_sprites.png
# /wiki/File:FFRK_Vanille.png
# /wiki/File:FFRK_Vayne_sprites.png
# /wiki/File:FFRK_Vayne.png
# /wiki/File:FFRK_Viking_sprites.png
# /wiki/File:FFRK_Viking.png
# /wiki/File:FFRK_Vincent_Galian_Beast_sprites.png
# /wiki/File:FFRK_Vincent_sprites.png
# /wiki/File:FFRK_Vincent.png
# /wiki/File:FFRK_Vivi_sprites.png
# /wiki/File:FFRK_Vivi.png
# /wiki/File:FFRK_Wakka_Sprite.png
# /wiki/File:FFRK_Wakka_sprites.png
# /wiki/File:FFRK_Ward_sprites.png
# /wiki/File:FFRK_Ward.png
# /wiki/File:FFRK_Warrior_of_Light_Classic_Red_sprites.png
# /wiki/File:FFRK_Warrior_of_Light_sprites.png
# /wiki/File:FFRK_Warrior_of_Light.png
# /wiki/File:FFRK_Warrior_Sprite.png
# /wiki/File:FFRK_Warrior_sprites.png
# /wiki/File:FFRK_Wedding_Dress_Yuna.png
# /wiki/File:FFRK_Wedge.png
# /wiki/File:FFRK_White_Mage_Sprite.png
# /wiki/File:FFRK_White_Mage_sprites.png
# /wiki/File:FFRK_Wol_sprites.png
# /wiki/File:FFRK_Wol.png
# /wiki/File:FFRK_Wrieg_sprites.png
# /wiki/File:FFRK_Wrieg.png
# /wiki/File:FFRK_Xezat_sprites.png
# /wiki/File:FFRK_Xezat.png
# /wiki/File:FFRK_Y%27shtola_sprites.png
# /wiki/File:FFRK_Y%27shtola.png
# /wiki/File:FFRK_Yang_FFIV.png
# /wiki/File:FFRK_Yang_sprites.png
# /wiki/File:FFRK_Yda_sprites.png
# /wiki/File:FFRK_Yda.png
# /wiki/File:FFRK_Young_Auron_sprites.png
# /wiki/File:FFRK_Young_Auron.png
# /wiki/File:FFRK_Ysayle_sprites.png
# /wiki/File:FFRK_Ysayle.png
# /wiki/File:FFRK_Yuffie_sprites.png
# /wiki/File:FFRK_Yuffie.png
# /wiki/File:FFRK_Yuna_(Swimsuit)_sprites.png
# /wiki/File:FFRK_Yuna_False_Bride_sprites.png
# /wiki/File:FFRK_Yuna_FFX-2.png
# /wiki/File:FFRK_Yuna_on_the_Beach.png
# /wiki/File:FFRK_Yuna_sprites.png
# /wiki/File:FFRK_Yuna_X2_sprites.png
# /wiki/File:FFRK_Yuna.png
# /wiki/File:FFRK_Zack_sprites.png
# /wiki/File:FFRK_Zack.png
# /wiki/File:FFRK_Zantetsuken_FFVIII_Sprite.png
# /wiki/File:FFRK_Zeid_sprites.png
# /wiki/File:FFRK_Zeid.png
# /wiki/File:FFRK_Zell_Garden_Uniform_sprites.png
# /wiki/File:FFRK_Zell_sprites.png
# /wiki/File:FFRK_Zell.png
# /wiki/File:FFRK_Zidane_Sprite.png
# /wiki/File:FFRK_Zidane_sprites.png
# /wiki/File:FFRK_Zidane_Trance_sprites.png
# /wiki/Category:Final_Fantasy_Record_Keeper_weapon_sprites

# %%
# download images from page links
def get_images_from_a_links(reload_page=False):
    if reload_page:
        tickers = run_save_img_links()
    else:
        # load all pickle(s)
        for file in tqdm_notebook(os.listdir(data_folder)):
            if file.endswith('.pickle'):
                load_path = '%s/%s' % (data_folder, file)
            
                with open(load_path, "rb") as f:
                    image_page_links = pickle.load(f)

                    for j in tqdm_notebook(range(len(image_page_links))):
                        link = image_page_links[j]
                        image_page_link = ('%s/%s' % (domain, link))

                        resp = requests.get(image_page_link)
                        soup = bs.BeautifulSoup(resp.text, 'lxml')
                        div = soup.find('div', {'class': 'fullImageLink'})
                        
                        # get image from link embeded in page link
                        a_tag = div.find('a')
                        a_link = a_tag['href']
                        
                        file_name = os.path.basename(link)
                        file_name = file_name.replace('File:', '') # remove prefix 'File:'
                        save_file_path = '%s/%s' % (data_folder, file_name)
                        
                        # check if file already downloaded
                        if os.path.exists(save_file_path):
                            # print ('%s already exist.' % (save_file_path))
                            continue
                        
                        # print ('Downloading - %s' % (a_link))
                        
                        get_file = requests.get(a_link)
                               
                        f = open(save_file_path, 'wb')
                        # print ('Saving - %s' % (a_link))
                        f.write(get_file.content)
                                        
                        # wait for a while to avoid being block
                        time.sleep(1.0)

get_images_from_a_links()
# Out:
# HBox(children=(IntProgress(value=0, max=282), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=22), HTML(value='')))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-634c7f3c5249> in <module>
#      44                         time.sleep(1.0)
#      45
# ---> 46 get_images_from_a_links()
#
# <ipython-input-6-634c7f3c5249> in get_images_from_a_links(reload_page)
#      21
#      22                         # get image from link embeded in page link
# ---> 23                         a_tag = div.find('a')
#      24                         a_link = a_tag['href']
#      25
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
# test terminal wget a single image - worked
# !wget https://vignette.wikia.nocookie.net/finalfantasy/images/5/53/FFRK_AC_Cloud.png/revision/latest?cb=20150930085325

# %%
#####################################################
# Part 2 - Pre-processing Images
# 2.1 preview downloaded raw mages
# 2.2 remove prefix in image names - no longer needed
# 2.3 crop/rip from big spritesheet with multi images, copy single 96x96 images
# 2.4 detect and delete blank + mini character images
# 2.5 resize all images to same dimension 32x32
# 2.6 load into one big list, save as pickle
#####################################################

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from tqdm import tqdm

# %%
# 2.1 Preview downloaded raw mages
def preview_raw_data(show_count=10):
    path = os.path.join(data_folder)  

    for i, file in enumerate(os.listdir(path)):  # iterate over each image in dir
        if not file.endswith('.png'):
            continue

        # load image as color, but not in original color
        img_array = cv2.imread(os.path.join(path,file), cv2.IMREAD_COLOR)

        # convert back to original color
        img_array_RGB = cv2.cvtColor(img_array,cv2.COLOR_BGR2RGB)

        plt.axis('off')
        plt.imshow(img_array_RGB)
        plt.show()

        if i > show_count:
            break  
            
preview_raw_data()

# %%
#######################
# crop / split analysis
#
# each large multi images spritesheet is 576x288, 
# it followed a foramt pattern of 6 images width by 3 images height
# width  = 576 / 6 = 96
# height = 288 / 3 = 96
# so crop large spritesheet to 6x3=18 smaller images
######################

# %%
# !conda install Pillow

# %%
# 2.2 rename all files - no longer needed
#
# remove prefix 'File:'
# e.g. 
# from File:FFRK_Devout_sprites.png
# to   FFRK_Devout_sprites.png

def rename_images():
    pattern = '*.png'
    path = data_folder
    for file in tqdm_notebook(os.listdir(path)):
        if not file.endswith('.png'):
            continue

        file_path = os.path.join(path, file)
        # print ('Renaming %s' % (file_path))

        os.rename(file_path, os.path.join(path, file.replace('File:', '')))
    
rename_images()
# Out:
# HBox(children=(IntProgress(value=0, max=625), HTML(value='')))

# %%
# 2.3 crop/rip from big spritesheet with multi images, copy single 96x96 images
from PIL import Image

# Testing - try crop one image first
img_path = 'data/FFRK_Devout_sprites.png'
img = Image.open(img_path)
plt.imshow(img)

# %%
crop_area_width = 96
crop_area_height = 96

img_width, img_height = img.size

print ('image width is %d' % (img_width))
print ('image height is %d' % (img_height))

start_x = 0
start_y = 0
box = (start_x, start_y, start_x+crop_area_width, start_y+crop_area_height)

print('box dimention is %s' % (str(box)))

# not saved yet, in memory only
img_crop = img.crop(box)
print (type(img_crop))
plt.imshow(img_crop)
# Out:
# image width is 576
# image height is 288
# box dimention is (0, 0, 96, 96)
# <class 'PIL.Image.Image'>

# %%
# crop all images in one large sprite sheet
crop_area_width = 96
crop_area_height = 96

img_width, img_height = img.size

def split_n_save_one_large_spritesheet(img_crop_path):

    crop_count = 0 # start on 1 in code below, not 0

    for h in range(0, img_height, crop_area_height): # ↓ second
        for w in range(0, img_width, crop_area_width): # → first
            start_x = w
            start_y = h
            box = (start_x, start_y, start_x+crop_area_width, start_y+crop_area_height)
            # print('box dimention is %s' % (str(box)))

            img = Image.open(img_crop_path)
            
            img_crop = img.crop(box)
            # plt.imshow(img_crop)
            # plt.show()

            filename = os.path.basename(img_crop_path)
            # e.g. 'data/FFRK_Devout_sprites.png'
            
            path_no_ext, ext = os.path.splitext(img_crop_path)
            # e.g. data/FFRK_Devout_sprites
            # e.g. .png

            save_no_ext = path_no_ext.replace('data/', '%s/'%img_folder)
            # e.g. img/FFRK_Devout_sprites

            crop_count += 1 # start on 1, not 0

            if (crop_count < 10):
                str_crop_count = '0%d' % crop_count
            else:
                str_crop_count = '%d' % crop_count

            img_crop_filename = os.path.join('%s%s%s'%(save_no_ext, str_crop_count, ext))

            if os.path.exists(img_crop_filename):
                print ('%s already exist.' % (img_crop_filename))
                continue

            print ('Saving image %s' % (img_crop_filename))

            img_crop.save(img_crop_filename)

# %%
# test run
# img_path = 'data/FFRK_Devout_sprites.png'
# split_n_save_one_large_spritesheet(img_path)

# %%
# crop all large sprite sheet into smaller 96x96 images

input_path = data_folder
output_path = img_folder

def crop_all_large_spritesheets(sprite_sheet_width=576, sprite_sheet_height=288):   
    
    #create folders if not exist
    if not os.path.exists(output_path):
        os.makedirs(output_path)

    for file in tqdm_notebook(os.listdir(input_path)):
        if not file.endswith('.png'):
            continue

        # check size
        img_path = os.path.join(input_path, file)
        img = Image.open(img_path)
        img_width, img_height = img.size

        if img_width == sprite_sheet_width and img_height == sprite_sheet_height:
#             print (img_path)
            split_n_save_one_large_spritesheet(img_path)

# %%
# crop sprite sheet of size w=576 x h=288
crop_all_large_spritesheets()
# Out:
# HBox(children=(IntProgress(value=0, max=625), HTML(value='')))
# Saving image img/FFRK_Jecht_sprites01.png
# Saving image img/FFRK_Jecht_sprites02.png
# Saving image img/FFRK_Jecht_sprites03.png
# Saving image img/FFRK_Jecht_sprites04.png
# Saving image img/FFRK_Jecht_sprites05.png
# Saving image img/FFRK_Jecht_sprites06.png
# Saving image img/FFRK_Jecht_sprites07.png
# Saving image img/FFRK_Jecht_sprites08.png
# Saving image img/FFRK_Jecht_sprites09.png
# Saving image img/FFRK_Jecht_sprites10.png
# Saving image img/FFRK_Jecht_sprites11.png
# Saving image img/FFRK_Jecht_sprites12.png
# Saving image img/FFRK_Jecht_sprites13.png
# Saving image img/FFRK_Jecht_sprites14.png
# Saving image img/FFRK_Jecht_sprites15.png
# Saving image img/FFRK_Jecht_sprites16.png
# Saving image img/FFRK_Jecht_sprites17.png
# Saving image img/FFRK_Jecht_sprites18.png
# Saving image img/FFRK_Ace_sprites01.png
# Saving image img/FFRK_Ace_sprites02.png
# Saving image img/FFRK_Ace_sprites03.png
# Saving image img/FFRK_Ace_sprites04.png
# Saving image img/FFRK_Ace_sprites05.png
# Saving image img/FFRK_Ace_sprites06.png
# Saving image img/FFRK_Ace_sprites07.png
# Saving image img/FFRK_Ace_sprites08.png
# Saving image img/FFRK_Ace_sprites09.png
# Saving image img/FFRK_Ace_sprites10.png
# Saving image img/FFRK_Ace_sprites11.png
# Saving image img/FFRK_Ace_sprites12.png
# Saving image img/FFRK_Ace_sprites13.png
# Saving image img/FFRK_Ace_sprites14.png
# Saving image img/FFRK_Ace_sprites15.png
# Saving image img/FFRK_Ace_sprites16.png
# Saving image img/FFRK_Ace_sprites17.png
# Saving image img/FFRK_Ace_sprites18.png
# Saving image img/FFRK_Adult_Rydia_sprites01.png
# Saving image img/FFRK_Adult_Rydia_sprites02.png
# Saving image img/FFRK_Adult_Rydia_sprites03.png
# Saving image img/FFRK_Adult_Rydia_sprites04.png
# Saving image img/FFRK_Adult_Rydia_sprites05.png
# Saving image img/FFRK_Adult_Rydia_sprites06.png
# Saving image img/FFRK_Adult_Rydia_sprites07.png
# Saving image img/FFRK_Adult_Rydia_sprites08.png
# Saving image img/FFRK_Adult_Rydia_sprites09.png
# Saving image img/FFRK_Adult_Rydia_sprites10.png
# Saving image img/FFRK_Adult_Rydia_sprites11.png
# Saving image img/FFRK_Adult_Rydia_sprites12.png
# Saving image img/FFRK_Adult_Rydia_sprites13.png
# Saving image img/FFRK_Adult_Rydia_sprites14.png
# Saving image img/FFRK_Adult_Rydia_sprites15.png
# Saving image img/FFRK_Adult_Rydia_sprites16.png
# Saving image img/FFRK_Adult_Rydia_sprites17.png
# Saving image img/FFRK_Adult_Rydia_sprites18.png
# Saving image img/FFRK_Aemo_sprites01.png
# Saving image img/FFRK_Aemo_sprites02.png
# Saving image img/FFRK_Aemo_sprites03.png
# Saving image img/FFRK_Aemo_sprites04.png
# Saving image img/FFRK_Aemo_sprites05.png
# Saving image img/FFRK_Aemo_sprites06.png
# Saving image img/FFRK_Aemo_sprites07.png
# Saving image img/FFRK_Aemo_sprites08.png
# Saving image img/FFRK_Aemo_sprites09.png
# Saving image img/FFRK_Aemo_sprites10.png
# Saving image img/FFRK_Aemo_sprites11.png
# Saving image img/FFRK_Aemo_sprites12.png
# Saving image img/FFRK_Aemo_sprites13.png
# Saving image img/FFRK_Aemo_sprites14.png
# Saving image img/FFRK_Aemo_sprites15.png
# Saving image img/FFRK_Aemo_sprites16.png
# Saving image img/FFRK_Aemo_sprites17.png
# Saving image img/FFRK_Aemo_sprites18.png
# Saving image img/FFRK_Aerith_sprites01.png
# Saving image img/FFRK_Aerith_sprites02.png
# Saving image img/FFRK_Aerith_sprites03.png
# Saving image img/FFRK_Aerith_sprites04.png
# Saving image img/FFRK_Aerith_sprites05.png
# Saving image img/FFRK_Aerith_sprites06.png
# Saving image img/FFRK_Aerith_sprites07.png
# Saving image img/FFRK_Aerith_sprites08.png
# Saving image img/FFRK_Aerith_sprites09.png
# Saving image img/FFRK_Aerith_sprites10.png
# Saving image img/FFRK_Aerith_sprites11.png
# Saving image img/FFRK_Aerith_sprites12.png
# Saving image img/FFRK_Aerith_sprites13.png
# Saving image img/FFRK_Aerith_sprites14.png
# Saving image img/FFRK_Aerith_sprites15.png
# Saving image img/FFRK_Aerith_sprites16.png
# Saving image img/FFRK_Aerith_sprites17.png
# Saving image img/FFRK_Aerith_sprites18.png
# Saving image img/FFRK_Agrias_sprites01.png
# Saving image img/FFRK_Agrias_sprites02.png
# Saving image img/FFRK_Agrias_sprites03.png
# Saving image img/FFRK_Agrias_sprites04.png
# Saving image img/FFRK_Agrias_sprites05.png
# Saving image img/FFRK_Agrias_sprites06.png
# Saving image img/FFRK_Agrias_sprites07.png
# Saving image img/FFRK_Agrias_sprites08.png
# Saving image img/FFRK_Agrias_sprites09.png
# Saving image img/FFRK_Agrias_sprites10.png
# Saving image img/FFRK_Agrias_sprites11.png
# Saving image img/FFRK_Agrias_sprites12.png
# Saving image img/FFRK_Agrias_sprites13.png
# Saving image img/FFRK_Agrias_sprites14.png
# Saving image img/FFRK_Agrias_sprites15.png
# Saving image img/FFRK_Agrias_sprites16.png
# Saving image img/FFRK_Agrias_sprites17.png
# Saving image img/FFRK_Agrias_sprites18.png
# Saving image img/FFRK_Alma_sprites01.png
# Saving image img/FFRK_Alma_sprites02.png
# Saving image img/FFRK_Alma_sprites03.png
# Saving image img/FFRK_Alma_sprites04.png
# Saving image img/FFRK_Alma_sprites05.png
# Saving image img/FFRK_Alma_sprites06.png
# Saving image img/FFRK_Alma_sprites07.png
# Saving image img/FFRK_Alma_sprites08.png
# Saving image img/FFRK_Alma_sprites09.png
# Saving image img/FFRK_Alma_sprites10.png
# Saving image img/FFRK_Alma_sprites11.png
# Saving image img/FFRK_Alma_sprites12.png
# Saving image img/FFRK_Alma_sprites13.png
# Saving image img/FFRK_Alma_sprites14.png
# Saving image img/FFRK_Alma_sprites15.png
# Saving image img/FFRK_Alma_sprites16.png
# Saving image img/FFRK_Alma_sprites17.png
# Saving image img/FFRK_Alma_sprites18.png
# Saving image img/FFRK_Alphinaud_sprites01.png
# Saving image img/FFRK_Alphinaud_sprites02.png
# Saving image img/FFRK_Alphinaud_sprites03.png
# Saving image img/FFRK_Alphinaud_sprites04.png
# Saving image img/FFRK_Alphinaud_sprites05.png
# Saving image img/FFRK_Alphinaud_sprites06.png
# Saving image img/FFRK_Alphinaud_sprites07.png
# Saving image img/FFRK_Alphinaud_sprites08.png
# Saving image img/FFRK_Alphinaud_sprites09.png
# Saving image img/FFRK_Alphinaud_sprites10.png
# Saving image img/FFRK_Alphinaud_sprites11.png
# Saving image img/FFRK_Alphinaud_sprites12.png
# Saving image img/FFRK_Alphinaud_sprites13.png
# Saving image img/FFRK_Alphinaud_sprites14.png
# Saving image img/FFRK_Alphinaud_sprites15.png
# Saving image img/FFRK_Alphinaud_sprites16.png
# Saving image img/FFRK_Alphinaud_sprites17.png
# Saving image img/FFRK_Alphinaud_sprites18.png
# Saving image img/FFRK_Amarant_sprites01.png
# Saving image img/FFRK_Amarant_sprites02.png
# Saving image img/FFRK_Amarant_sprites03.png
# Saving image img/FFRK_Amarant_sprites04.png
# Saving image img/FFRK_Amarant_sprites05.png
# Saving image img/FFRK_Amarant_sprites06.png
# Saving image img/FFRK_Amarant_sprites07.png
# Saving image img/FFRK_Amarant_sprites08.png
# Saving image img/FFRK_Amarant_sprites09.png
# Saving image img/FFRK_Amarant_sprites10.png
# Saving image img/FFRK_Amarant_sprites11.png
# Saving image img/FFRK_Amarant_sprites12.png
# Saving image img/FFRK_Amarant_sprites13.png
# Saving image img/FFRK_Amarant_sprites14.png
# Saving image img/FFRK_Amarant_sprites15.png
# Saving image img/FFRK_Amarant_sprites16.png
# Saving image img/FFRK_Amarant_sprites17.png
# Saving image img/FFRK_Amarant_sprites18.png
# Saving image img/FFRK_Angeal_sprites01.png
# Saving image img/FFRK_Angeal_sprites02.png
# Saving image img/FFRK_Angeal_sprites03.png
# Saving image img/FFRK_Angeal_sprites04.png
# Saving image img/FFRK_Angeal_sprites05.png
# Saving image img/FFRK_Angeal_sprites06.png
# Saving image img/FFRK_Angeal_sprites07.png
# Saving image img/FFRK_Angeal_sprites08.png
# Saving image img/FFRK_Angeal_sprites09.png
# Saving image img/FFRK_Angeal_sprites10.png
# Saving image img/FFRK_Angeal_sprites11.png
# Saving image img/FFRK_Angeal_sprites12.png
# Saving image img/FFRK_Angeal_sprites13.png
# Saving image img/FFRK_Angeal_sprites14.png
# Saving image img/FFRK_Angeal_sprites15.png
# Saving image img/FFRK_Angeal_sprites16.png
# Saving image img/FFRK_Angeal_sprites17.png
# Saving image img/FFRK_Angeal_sprites18.png
# Saving image img/FFRK_Aphmau_sprites01.png
# Saving image img/FFRK_Aphmau_sprites02.png
# Saving image img/FFRK_Aphmau_sprites03.png
# Saving image img/FFRK_Aphmau_sprites04.png
# Saving image img/FFRK_Aphmau_sprites05.png
# Saving image img/FFRK_Aphmau_sprites06.png
# Saving image img/FFRK_Aphmau_sprites07.png
# Saving image img/FFRK_Aphmau_sprites08.png
# Saving image img/FFRK_Aphmau_sprites09.png
# Saving image img/FFRK_Aphmau_sprites10.png
# Saving image img/FFRK_Aphmau_sprites11.png
# Saving image img/FFRK_Aphmau_sprites12.png
# Saving image img/FFRK_Aphmau_sprites13.png
# Saving image img/FFRK_Aphmau_sprites14.png
# Saving image img/FFRK_Aphmau_sprites15.png
# Saving image img/FFRK_Aphmau_sprites16.png
# Saving image img/FFRK_Aphmau_sprites17.png
# Saving image img/FFRK_Aphmau_sprites18.png
# Saving image img/FFRK_Aranea_FFXV_sprites01.png
# Saving image img/FFRK_Aranea_FFXV_sprites02.png
# Saving image img/FFRK_Aranea_FFXV_sprites03.png
# Saving image img/FFRK_Aranea_FFXV_sprites04.png
# Saving image img/FFRK_Aranea_FFXV_sprites05.png
# Saving image img/FFRK_Aranea_FFXV_sprites06.png
# Saving image img/FFRK_Aranea_FFXV_sprites07.png
# Saving image img/FFRK_Aranea_FFXV_sprites08.png
# Saving image img/FFRK_Aranea_FFXV_sprites09.png
# Saving image img/FFRK_Aranea_FFXV_sprites10.png
# Saving image img/FFRK_Aranea_FFXV_sprites11.png
# Saving image img/FFRK_Aranea_FFXV_sprites12.png
# Saving image img/FFRK_Aranea_FFXV_sprites13.png
# Saving image img/FFRK_Aranea_FFXV_sprites14.png
# Saving image img/FFRK_Aranea_FFXV_sprites15.png
# Saving image img/FFRK_Aranea_FFXV_sprites16.png
# Saving image img/FFRK_Aranea_FFXV_sprites17.png
# Saving image img/FFRK_Aranea_FFXV_sprites18.png
# Saving image img/FFRK_Aria_FFIII_sprites01.png
# Saving image img/FFRK_Aria_FFIII_sprites02.png
# Saving image img/FFRK_Aria_FFIII_sprites03.png
# Saving image img/FFRK_Aria_FFIII_sprites04.png
# Saving image img/FFRK_Aria_FFIII_sprites05.png
# Saving image img/FFRK_Aria_FFIII_sprites06.png
# Saving image img/FFRK_Aria_FFIII_sprites07.png
# Saving image img/FFRK_Aria_FFIII_sprites08.png
# Saving image img/FFRK_Aria_FFIII_sprites09.png
# Saving image img/FFRK_Aria_FFIII_sprites10.png
# Saving image img/FFRK_Aria_FFIII_sprites11.png
# Saving image img/FFRK_Aria_FFIII_sprites12.png
# Saving image img/FFRK_Aria_FFIII_sprites13.png
# Saving image img/FFRK_Aria_FFIII_sprites14.png
# Saving image img/FFRK_Aria_FFIII_sprites15.png
# Saving image img/FFRK_Aria_FFIII_sprites16.png
# Saving image img/FFRK_Aria_FFIII_sprites17.png
# Saving image img/FFRK_Aria_FFIII_sprites18.png
# Saving image img/FFRK_Ashe_sprites01.png
# Saving image img/FFRK_Ashe_sprites02.png
# Saving image img/FFRK_Ashe_sprites03.png
# Saving image img/FFRK_Ashe_sprites04.png
# Saving image img/FFRK_Ashe_sprites05.png
# Saving image img/FFRK_Ashe_sprites06.png
# Saving image img/FFRK_Ashe_sprites07.png
# Saving image img/FFRK_Ashe_sprites08.png
# Saving image img/FFRK_Ashe_sprites09.png
# Saving image img/FFRK_Ashe_sprites10.png
# Saving image img/FFRK_Ashe_sprites11.png
# Saving image img/FFRK_Ashe_sprites12.png
# Saving image img/FFRK_Ashe_sprites13.png
# Saving image img/FFRK_Ashe_sprites14.png
# Saving image img/FFRK_Ashe_sprites15.png
# Saving image img/FFRK_Ashe_sprites16.png
# Saving image img/FFRK_Ashe_sprites17.png
# Saving image img/FFRK_Ashe_sprites18.png
# Saving image img/FFRK_Auron_sprites01.png
# Saving image img/FFRK_Auron_sprites02.png
# Saving image img/FFRK_Auron_sprites03.png
# Saving image img/FFRK_Auron_sprites04.png
# Saving image img/FFRK_Auron_sprites05.png
# Saving image img/FFRK_Auron_sprites06.png
# Saving image img/FFRK_Auron_sprites07.png
# Saving image img/FFRK_Auron_sprites08.png
# Saving image img/FFRK_Auron_sprites09.png
# Saving image img/FFRK_Auron_sprites10.png
# Saving image img/FFRK_Auron_sprites11.png
# Saving image img/FFRK_Auron_sprites12.png
# Saving image img/FFRK_Auron_sprites13.png
# Saving image img/FFRK_Auron_sprites14.png
# Saving image img/FFRK_Auron_sprites15.png
# Saving image img/FFRK_Auron_sprites16.png
# Saving image img/FFRK_Auron_sprites17.png
# Saving image img/FFRK_Auron_sprites18.png
# Saving image img/FFRK_Ayame_sprites01.png
# Saving image img/FFRK_Ayame_sprites02.png
# Saving image img/FFRK_Ayame_sprites03.png
# Saving image img/FFRK_Ayame_sprites04.png
# Saving image img/FFRK_Ayame_sprites05.png
# Saving image img/FFRK_Ayame_sprites06.png
# Saving image img/FFRK_Ayame_sprites07.png
# Saving image img/FFRK_Ayame_sprites08.png
# Saving image img/FFRK_Ayame_sprites09.png
# Saving image img/FFRK_Ayame_sprites10.png
# Saving image img/FFRK_Ayame_sprites11.png
# Saving image img/FFRK_Ayame_sprites12.png
# Saving image img/FFRK_Ayame_sprites13.png
# Saving image img/FFRK_Ayame_sprites14.png
# Saving image img/FFRK_Ayame_sprites15.png
# Saving image img/FFRK_Ayame_sprites16.png
# Saving image img/FFRK_Ayame_sprites17.png
# Saving image img/FFRK_Ayame_sprites18.png
# Saving image img/FFRK_Balthier_sprites01.png
# Saving image img/FFRK_Balthier_sprites02.png
# Saving image img/FFRK_Balthier_sprites03.png
# Saving image img/FFRK_Balthier_sprites04.png
# Saving image img/FFRK_Balthier_sprites05.png
# Saving image img/FFRK_Balthier_sprites06.png
# Saving image img/FFRK_Balthier_sprites07.png
# Saving image img/FFRK_Balthier_sprites08.png
# Saving image img/FFRK_Balthier_sprites09.png
# Saving image img/FFRK_Balthier_sprites10.png
# Saving image img/FFRK_Balthier_sprites11.png
# Saving image img/FFRK_Balthier_sprites12.png
# Saving image img/FFRK_Balthier_sprites13.png
# Saving image img/FFRK_Balthier_sprites14.png
# Saving image img/FFRK_Balthier_sprites15.png
# Saving image img/FFRK_Balthier_sprites16.png
# Saving image img/FFRK_Balthier_sprites17.png
# Saving image img/FFRK_Balthier_sprites18.png
# Saving image img/FFRK_Barbariccia_sprites01.png
# Saving image img/FFRK_Barbariccia_sprites02.png
# Saving image img/FFRK_Barbariccia_sprites03.png
# Saving image img/FFRK_Barbariccia_sprites04.png
# Saving image img/FFRK_Barbariccia_sprites05.png
# Saving image img/FFRK_Barbariccia_sprites06.png
# Saving image img/FFRK_Barbariccia_sprites07.png
# Saving image img/FFRK_Barbariccia_sprites08.png
# Saving image img/FFRK_Barbariccia_sprites09.png
# Saving image img/FFRK_Barbariccia_sprites10.png
# Saving image img/FFRK_Barbariccia_sprites11.png
# Saving image img/FFRK_Barbariccia_sprites12.png
# Saving image img/FFRK_Barbariccia_sprites13.png
# Saving image img/FFRK_Barbariccia_sprites14.png
# Saving image img/FFRK_Barbariccia_sprites15.png
# Saving image img/FFRK_Barbariccia_sprites16.png
# Saving image img/FFRK_Barbariccia_sprites17.png
# Saving image img/FFRK_Barbariccia_sprites18.png
# Saving image img/FFRK_Bard_sprites01.png
# Saving image img/FFRK_Bard_sprites02.png
# Saving image img/FFRK_Bard_sprites03.png
# Saving image img/FFRK_Bard_sprites04.png
# Saving image img/FFRK_Bard_sprites05.png
# Saving image img/FFRK_Bard_sprites06.png
# Saving image img/FFRK_Bard_sprites07.png
# Saving image img/FFRK_Bard_sprites08.png
# Saving image img/FFRK_Bard_sprites09.png
# Saving image img/FFRK_Bard_sprites10.png
# Saving image img/FFRK_Bard_sprites11.png
# Saving image img/FFRK_Bard_sprites12.png
# Saving image img/FFRK_Bard_sprites13.png
# Saving image img/FFRK_Bard_sprites14.png
# Saving image img/FFRK_Bard_sprites15.png
# Saving image img/FFRK_Bard_sprites16.png
# Saving image img/FFRK_Bard_sprites17.png
# Saving image img/FFRK_Bard_sprites18.png
# Saving image img/FFRK_Bartz_Freelancer_sprites01.png
# Saving image img/FFRK_Bartz_Freelancer_sprites02.png
# Saving image img/FFRK_Bartz_Freelancer_sprites03.png
# Saving image img/FFRK_Bartz_Freelancer_sprites04.png
# Saving image img/FFRK_Bartz_Freelancer_sprites05.png
# Saving image img/FFRK_Bartz_Freelancer_sprites06.png
# Saving image img/FFRK_Bartz_Freelancer_sprites07.png
# Saving image img/FFRK_Bartz_Freelancer_sprites08.png
# Saving image img/FFRK_Bartz_Freelancer_sprites09.png
# Saving image img/FFRK_Bartz_Freelancer_sprites10.png
# Saving image img/FFRK_Bartz_Freelancer_sprites11.png
# Saving image img/FFRK_Bartz_Freelancer_sprites12.png
# Saving image img/FFRK_Bartz_Freelancer_sprites13.png
# Saving image img/FFRK_Bartz_Freelancer_sprites14.png
# Saving image img/FFRK_Bartz_Freelancer_sprites15.png
# Saving image img/FFRK_Bartz_Freelancer_sprites16.png
# Saving image img/FFRK_Bartz_Freelancer_sprites17.png
# Saving image img/FFRK_Bartz_Freelancer_sprites18.png
# Saving image img/FFRK_Bartz_Knight_sprites01.png
# Saving image img/FFRK_Bartz_Knight_sprites02.png
# Saving image img/FFRK_Bartz_Knight_sprites03.png
# Saving image img/FFRK_Bartz_Knight_sprites04.png
# Saving image img/FFRK_Bartz_Knight_sprites05.png
# Saving image img/FFRK_Bartz_Knight_sprites06.png
# Saving image img/FFRK_Bartz_Knight_sprites07.png
# Saving image img/FFRK_Bartz_Knight_sprites08.png
# Saving image img/FFRK_Bartz_Knight_sprites09.png
# Saving image img/FFRK_Bartz_Knight_sprites10.png
# Saving image img/FFRK_Bartz_Knight_sprites11.png
# Saving image img/FFRK_Bartz_Knight_sprites12.png
# Saving image img/FFRK_Bartz_Knight_sprites13.png
# Saving image img/FFRK_Bartz_Knight_sprites14.png
# Saving image img/FFRK_Bartz_Knight_sprites15.png
# Saving image img/FFRK_Bartz_Knight_sprites16.png
# Saving image img/FFRK_Bartz_Knight_sprites17.png
# Saving image img/FFRK_Bartz_Knight_sprites18.png
# Saving image img/FFRK_Basch_sprites01.png
# Saving image img/FFRK_Basch_sprites02.png
# Saving image img/FFRK_Basch_sprites03.png
# Saving image img/FFRK_Basch_sprites04.png
# Saving image img/FFRK_Basch_sprites05.png
# Saving image img/FFRK_Basch_sprites06.png
# Saving image img/FFRK_Basch_sprites07.png
# Saving image img/FFRK_Basch_sprites08.png
# Saving image img/FFRK_Basch_sprites09.png
# Saving image img/FFRK_Basch_sprites10.png
# Saving image img/FFRK_Basch_sprites11.png
# Saving image img/FFRK_Basch_sprites12.png
# Saving image img/FFRK_Basch_sprites13.png
# Saving image img/FFRK_Basch_sprites14.png
# Saving image img/FFRK_Basch_sprites15.png
# Saving image img/FFRK_Basch_sprites16.png
# Saving image img/FFRK_Basch_sprites17.png
# Saving image img/FFRK_Basch_sprites18.png
# Saving image img/FFRK_Beastmaster_sprites01.png
# Saving image img/FFRK_Beastmaster_sprites02.png
# Saving image img/FFRK_Beastmaster_sprites03.png
# Saving image img/FFRK_Beastmaster_sprites04.png
# Saving image img/FFRK_Beastmaster_sprites05.png
# Saving image img/FFRK_Beastmaster_sprites06.png
# Saving image img/FFRK_Beastmaster_sprites07.png
# Saving image img/FFRK_Beastmaster_sprites08.png
# Saving image img/FFRK_Beastmaster_sprites09.png
# Saving image img/FFRK_Beastmaster_sprites10.png
# Saving image img/FFRK_Beastmaster_sprites11.png
# Saving image img/FFRK_Beastmaster_sprites12.png
# Saving image img/FFRK_Beastmaster_sprites13.png
# Saving image img/FFRK_Beastmaster_sprites14.png
# Saving image img/FFRK_Beastmaster_sprites15.png
# Saving image img/FFRK_Beastmaster_sprites16.png
# Saving image img/FFRK_Beastmaster_sprites17.png
# Saving image img/FFRK_Beastmaster_sprites18.png
# Saving image img/FFRK_Beatrix_sprites01.png
# Saving image img/FFRK_Beatrix_sprites02.png
# Saving image img/FFRK_Beatrix_sprites03.png
# Saving image img/FFRK_Beatrix_sprites04.png
# Saving image img/FFRK_Beatrix_sprites05.png
# Saving image img/FFRK_Beatrix_sprites06.png
# Saving image img/FFRK_Beatrix_sprites07.png
# Saving image img/FFRK_Beatrix_sprites08.png
# Saving image img/FFRK_Beatrix_sprites09.png
# Saving image img/FFRK_Beatrix_sprites10.png
# Saving image img/FFRK_Beatrix_sprites11.png
# Saving image img/FFRK_Beatrix_sprites12.png
# Saving image img/FFRK_Beatrix_sprites13.png
# Saving image img/FFRK_Beatrix_sprites14.png
# Saving image img/FFRK_Beatrix_sprites15.png
# Saving image img/FFRK_Beatrix_sprites16.png
# Saving image img/FFRK_Beatrix_sprites17.png
# Saving image img/FFRK_Beatrix_sprites18.png
# Saving image img/FFRK_Berserker_sprites01.png
# Saving image img/FFRK_Berserker_sprites02.png
# Saving image img/FFRK_Berserker_sprites03.png
# Saving image img/FFRK_Berserker_sprites04.png
# Saving image img/FFRK_Berserker_sprites05.png
# Saving image img/FFRK_Berserker_sprites06.png
# Saving image img/FFRK_Berserker_sprites07.png
# Saving image img/FFRK_Berserker_sprites08.png
# Saving image img/FFRK_Berserker_sprites09.png
# Saving image img/FFRK_Berserker_sprites10.png
# Saving image img/FFRK_Berserker_sprites11.png
# Saving image img/FFRK_Berserker_sprites12.png
# Saving image img/FFRK_Berserker_sprites13.png
# Saving image img/FFRK_Berserker_sprites14.png
# Saving image img/FFRK_Berserker_sprites15.png
# Saving image img/FFRK_Berserker_sprites16.png
# Saving image img/FFRK_Berserker_sprites17.png
# Saving image img/FFRK_Berserker_sprites18.png
# Saving image img/FFRK_Arc_White_Mage_sprites01.png
# Saving image img/FFRK_Arc_White_Mage_sprites02.png
# Saving image img/FFRK_Arc_White_Mage_sprites03.png
# Saving image img/FFRK_Arc_White_Mage_sprites04.png
# Saving image img/FFRK_Arc_White_Mage_sprites05.png
# Saving image img/FFRK_Arc_White_Mage_sprites06.png
# Saving image img/FFRK_Arc_White_Mage_sprites07.png
# Saving image img/FFRK_Arc_White_Mage_sprites08.png
# Saving image img/FFRK_Arc_White_Mage_sprites09.png
# Saving image img/FFRK_Arc_White_Mage_sprites10.png
# Saving image img/FFRK_Arc_White_Mage_sprites11.png
# Saving image img/FFRK_Arc_White_Mage_sprites12.png
# Saving image img/FFRK_Arc_White_Mage_sprites13.png
# Saving image img/FFRK_Arc_White_Mage_sprites14.png
# Saving image img/FFRK_Arc_White_Mage_sprites15.png
# Saving image img/FFRK_Arc_White_Mage_sprites16.png
# Saving image img/FFRK_Arc_White_Mage_sprites17.png
# Saving image img/FFRK_Arc_White_Mage_sprites18.png
# Saving image img/FFRK_Barret_sprites01.png
# Saving image img/FFRK_Barret_sprites02.png
# Saving image img/FFRK_Barret_sprites03.png
# Saving image img/FFRK_Barret_sprites04.png
# Saving image img/FFRK_Barret_sprites05.png
# Saving image img/FFRK_Barret_sprites06.png
# Saving image img/FFRK_Barret_sprites07.png
# Saving image img/FFRK_Barret_sprites08.png
# Saving image img/FFRK_Barret_sprites09.png
# Saving image img/FFRK_Barret_sprites10.png
# Saving image img/FFRK_Barret_sprites11.png
# Saving image img/FFRK_Barret_sprites12.png
# Saving image img/FFRK_Barret_sprites13.png
# Saving image img/FFRK_Barret_sprites14.png
# Saving image img/FFRK_Barret_sprites15.png
# Saving image img/FFRK_Barret_sprites16.png
# Saving image img/FFRK_Barret_sprites17.png
# Saving image img/FFRK_Barret_sprites18.png
# Saving image img/FFRK_Black_Mage_sprites01.png
# Saving image img/FFRK_Black_Mage_sprites02.png
# Saving image img/FFRK_Black_Mage_sprites03.png
# Saving image img/FFRK_Black_Mage_sprites04.png
# Saving image img/FFRK_Black_Mage_sprites05.png
# Saving image img/FFRK_Black_Mage_sprites06.png
# Saving image img/FFRK_Black_Mage_sprites07.png
# Saving image img/FFRK_Black_Mage_sprites08.png
# Saving image img/FFRK_Black_Mage_sprites09.png
# Saving image img/FFRK_Black_Mage_sprites10.png
# Saving image img/FFRK_Black_Mage_sprites11.png
# Saving image img/FFRK_Black_Mage_sprites12.png
# Saving image img/FFRK_Black_Mage_sprites13.png
# Saving image img/FFRK_Black_Mage_sprites14.png
# Saving image img/FFRK_Black_Mage_sprites15.png
# Saving image img/FFRK_Black_Mage_sprites16.png
# Saving image img/FFRK_Black_Mage_sprites17.png
# Saving image img/FFRK_Black_Mage_sprites18.png
# Saving image img/FFRK_Cecil_Paladin_DFF_sprites01.png
# Saving image img/FFRK_Cecil_Paladin_DFF_sprites02.png
# Saving image img/FFRK_Cecil_Paladin_DFF_sprites03.png
# Saving image img/FFRK_Cecil_Paladin_DFF_sprites04.png
# Saving image img/FFRK_Cecil_Paladin_DFF_sprites05.png
# Saving image img/FFRK_Cecil_Paladin_DFF_sprites06.png
# Saving image img/FFRK_Cecil_Paladin_DFF_sprites07.png
# Saving image img/FFRK_Cecil_Paladin_DFF_sprites08.png
# Saving image img/FFRK_Cecil_Paladin_DFF_sprites09.png
# Saving image img/FFRK_Cecil_Paladin_DFF_sprites10.png
# Saving image img/FFRK_Cecil_Paladin_DFF_sprites11.png
# Saving image img/FFRK_Cecil_Paladin_DFF_sprites12.png
# Saving image img/FFRK_Cecil_Paladin_DFF_sprites13.png
# Saving image img/FFRK_Cecil_Paladin_DFF_sprites14.png
# Saving image img/FFRK_Cecil_Paladin_DFF_sprites15.png
# Saving image img/FFRK_Cecil_Paladin_DFF_sprites16.png
# Saving image img/FFRK_Cecil_Paladin_DFF_sprites17.png
# Saving image img/FFRK_Cecil_Paladin_DFF_sprites18.png
# Saving image img/FFRK_Fran_sprites01.png
# Saving image img/FFRK_Fran_sprites02.png
# Saving image img/FFRK_Fran_sprites03.png
# Saving image img/FFRK_Fran_sprites04.png
# Saving image img/FFRK_Fran_sprites05.png
# Saving image img/FFRK_Fran_sprites06.png
# Saving image img/FFRK_Fran_sprites07.png
# Saving image img/FFRK_Fran_sprites08.png
# Saving image img/FFRK_Fran_sprites09.png
# Saving image img/FFRK_Fran_sprites10.png
# Saving image img/FFRK_Fran_sprites11.png
# Saving image img/FFRK_Fran_sprites12.png
# Saving image img/FFRK_Fran_sprites13.png
# Saving image img/FFRK_Fran_sprites14.png
# Saving image img/FFRK_Fran_sprites15.png
# Saving image img/FFRK_Fran_sprites16.png
# Saving image img/FFRK_Fran_sprites17.png
# Saving image img/FFRK_Fran_sprites18.png
# Saving image img/FFRK_Garland_FFI_sprites01.png
# Saving image img/FFRK_Garland_FFI_sprites02.png
# Saving image img/FFRK_Garland_FFI_sprites03.png
# Saving image img/FFRK_Garland_FFI_sprites04.png
# Saving image img/FFRK_Garland_FFI_sprites05.png
# Saving image img/FFRK_Garland_FFI_sprites06.png
# Saving image img/FFRK_Garland_FFI_sprites07.png
# Saving image img/FFRK_Garland_FFI_sprites08.png
# Saving image img/FFRK_Garland_FFI_sprites09.png
# Saving image img/FFRK_Garland_FFI_sprites10.png
# Saving image img/FFRK_Garland_FFI_sprites11.png
# Saving image img/FFRK_Garland_FFI_sprites12.png
# Saving image img/FFRK_Garland_FFI_sprites13.png
# Saving image img/FFRK_Garland_FFI_sprites14.png
# Saving image img/FFRK_Garland_FFI_sprites15.png
# Saving image img/FFRK_Garland_FFI_sprites16.png
# Saving image img/FFRK_Garland_FFI_sprites17.png
# Saving image img/FFRK_Garland_FFI_sprites18.png
# Saving image img/FFRK_Gladiolus_sprites01.png
# Saving image img/FFRK_Gladiolus_sprites02.png
# Saving image img/FFRK_Gladiolus_sprites03.png
# Saving image img/FFRK_Gladiolus_sprites04.png
# Saving image img/FFRK_Gladiolus_sprites05.png
# Saving image img/FFRK_Gladiolus_sprites06.png
# Saving image img/FFRK_Gladiolus_sprites07.png
# Saving image img/FFRK_Gladiolus_sprites08.png
# Saving image img/FFRK_Gladiolus_sprites09.png
# Saving image img/FFRK_Gladiolus_sprites10.png
# Saving image img/FFRK_Gladiolus_sprites11.png
# Saving image img/FFRK_Gladiolus_sprites12.png
# Saving image img/FFRK_Gladiolus_sprites13.png
# Saving image img/FFRK_Gladiolus_sprites14.png
# Saving image img/FFRK_Gladiolus_sprites15.png
# Saving image img/FFRK_Gladiolus_sprites16.png
# Saving image img/FFRK_Gladiolus_sprites17.png
# Saving image img/FFRK_Gladiolus_sprites18.png
# Saving image img/FFRK_Blue_Mage_sprites01.png
# Saving image img/FFRK_Blue_Mage_sprites02.png
# Saving image img/FFRK_Blue_Mage_sprites03.png
# Saving image img/FFRK_Blue_Mage_sprites04.png
# Saving image img/FFRK_Blue_Mage_sprites05.png
# Saving image img/FFRK_Blue_Mage_sprites06.png
# Saving image img/FFRK_Blue_Mage_sprites07.png
# Saving image img/FFRK_Blue_Mage_sprites08.png
# Saving image img/FFRK_Blue_Mage_sprites09.png
# Saving image img/FFRK_Blue_Mage_sprites10.png
# Saving image img/FFRK_Blue_Mage_sprites11.png
# Saving image img/FFRK_Blue_Mage_sprites12.png
# Saving image img/FFRK_Blue_Mage_sprites13.png
# Saving image img/FFRK_Blue_Mage_sprites14.png
# Saving image img/FFRK_Blue_Mage_sprites15.png
# Saving image img/FFRK_Blue_Mage_sprites16.png
# Saving image img/FFRK_Blue_Mage_sprites17.png
# Saving image img/FFRK_Blue_Mage_sprites18.png
# Saving image img/FFRK_Braska_sprites01.png
# Saving image img/FFRK_Braska_sprites02.png
# Saving image img/FFRK_Braska_sprites03.png
# Saving image img/FFRK_Braska_sprites04.png
# Saving image img/FFRK_Braska_sprites05.png
# Saving image img/FFRK_Braska_sprites06.png
# Saving image img/FFRK_Braska_sprites07.png
# Saving image img/FFRK_Braska_sprites08.png
# Saving image img/FFRK_Braska_sprites09.png
# Saving image img/FFRK_Braska_sprites10.png
# Saving image img/FFRK_Braska_sprites11.png
# Saving image img/FFRK_Braska_sprites12.png
# Saving image img/FFRK_Braska_sprites13.png
# Saving image img/FFRK_Braska_sprites14.png
# Saving image img/FFRK_Braska_sprites15.png
# Saving image img/FFRK_Braska_sprites16.png
# Saving image img/FFRK_Braska_sprites17.png
# Saving image img/FFRK_Braska_sprites18.png
# Saving image img/FFRK_Cater_sprites01.png
# Saving image img/FFRK_Cater_sprites02.png
# Saving image img/FFRK_Cater_sprites03.png
# Saving image img/FFRK_Cater_sprites04.png
# Saving image img/FFRK_Cater_sprites05.png
# Saving image img/FFRK_Cater_sprites06.png
# Saving image img/FFRK_Cater_sprites07.png
# Saving image img/FFRK_Cater_sprites08.png
# Saving image img/FFRK_Cater_sprites09.png
# Saving image img/FFRK_Cater_sprites10.png
# Saving image img/FFRK_Cater_sprites11.png
# Saving image img/FFRK_Cater_sprites12.png
# Saving image img/FFRK_Cater_sprites13.png
# Saving image img/FFRK_Cater_sprites14.png
# Saving image img/FFRK_Cater_sprites15.png
# Saving image img/FFRK_Cater_sprites16.png
# Saving image img/FFRK_Cater_sprites17.png
# Saving image img/FFRK_Cater_sprites18.png
# Saving image img/FFRK_Celes_Actress_sprites01.png
# Saving image img/FFRK_Celes_Actress_sprites02.png
# Saving image img/FFRK_Celes_Actress_sprites03.png
# Saving image img/FFRK_Celes_Actress_sprites04.png
# Saving image img/FFRK_Celes_Actress_sprites05.png
# Saving image img/FFRK_Celes_Actress_sprites06.png
# Saving image img/FFRK_Celes_Actress_sprites07.png
# Saving image img/FFRK_Celes_Actress_sprites08.png
# Saving image img/FFRK_Celes_Actress_sprites09.png
# Saving image img/FFRK_Celes_Actress_sprites10.png
# Saving image img/FFRK_Celes_Actress_sprites11.png
# Saving image img/FFRK_Celes_Actress_sprites12.png
# Saving image img/FFRK_Celes_Actress_sprites13.png
# Saving image img/FFRK_Celes_Actress_sprites14.png
# Saving image img/FFRK_Celes_Actress_sprites15.png
# Saving image img/FFRK_Celes_Actress_sprites16.png
# Saving image img/FFRK_Celes_Actress_sprites17.png
# Saving image img/FFRK_Celes_Actress_sprites18.png
# Saving image img/FFRK_Celes_sprites01.png
# Saving image img/FFRK_Celes_sprites02.png
# Saving image img/FFRK_Celes_sprites03.png
# Saving image img/FFRK_Celes_sprites04.png
# Saving image img/FFRK_Celes_sprites05.png
# Saving image img/FFRK_Celes_sprites06.png
# Saving image img/FFRK_Celes_sprites07.png
# Saving image img/FFRK_Celes_sprites08.png
# Saving image img/FFRK_Celes_sprites09.png
# Saving image img/FFRK_Celes_sprites10.png
# Saving image img/FFRK_Celes_sprites11.png
# Saving image img/FFRK_Celes_sprites12.png
# Saving image img/FFRK_Celes_sprites13.png
# Saving image img/FFRK_Celes_sprites14.png
# Saving image img/FFRK_Celes_sprites15.png
# Saving image img/FFRK_Celes_sprites16.png
# Saving image img/FFRK_Celes_sprites17.png
# Saving image img/FFRK_Celes_sprites18.png
# Saving image img/FFRK_Ceodore_sprites01.png
# Saving image img/FFRK_Ceodore_sprites02.png
# Saving image img/FFRK_Ceodore_sprites03.png
# Saving image img/FFRK_Ceodore_sprites04.png
# Saving image img/FFRK_Ceodore_sprites05.png
# Saving image img/FFRK_Ceodore_sprites06.png
# Saving image img/FFRK_Ceodore_sprites07.png
# Saving image img/FFRK_Ceodore_sprites08.png
# Saving image img/FFRK_Ceodore_sprites09.png
# Saving image img/FFRK_Ceodore_sprites10.png
# Saving image img/FFRK_Ceodore_sprites11.png
# Saving image img/FFRK_Ceodore_sprites12.png
# Saving image img/FFRK_Ceodore_sprites13.png
# Saving image img/FFRK_Ceodore_sprites14.png
# Saving image img/FFRK_Ceodore_sprites15.png
# Saving image img/FFRK_Ceodore_sprites16.png
# Saving image img/FFRK_Ceodore_sprites17.png
# Saving image img/FFRK_Ceodore_sprites18.png
# Saving image img/FFRK_Child_Rydia_sprites01.png
# Saving image img/FFRK_Child_Rydia_sprites02.png
# Saving image img/FFRK_Child_Rydia_sprites03.png
# Saving image img/FFRK_Child_Rydia_sprites04.png
# Saving image img/FFRK_Child_Rydia_sprites05.png
# Saving image img/FFRK_Child_Rydia_sprites06.png
# Saving image img/FFRK_Child_Rydia_sprites07.png
# Saving image img/FFRK_Child_Rydia_sprites08.png
# Saving image img/FFRK_Child_Rydia_sprites09.png
# Saving image img/FFRK_Child_Rydia_sprites10.png
# Saving image img/FFRK_Child_Rydia_sprites11.png
# Saving image img/FFRK_Child_Rydia_sprites12.png
# Saving image img/FFRK_Child_Rydia_sprites13.png
# Saving image img/FFRK_Child_Rydia_sprites14.png
# Saving image img/FFRK_Child_Rydia_sprites15.png
# Saving image img/FFRK_Child_Rydia_sprites16.png
# Saving image img/FFRK_Child_Rydia_sprites17.png
# Saving image img/FFRK_Child_Rydia_sprites18.png
# Saving image img/FFRK_Cidolfus_Orlandeau_sprites01.png
# Saving image img/FFRK_Cidolfus_Orlandeau_sprites02.png
# Saving image img/FFRK_Cidolfus_Orlandeau_sprites03.png
# Saving image img/FFRK_Cidolfus_Orlandeau_sprites04.png
# Saving image img/FFRK_Cidolfus_Orlandeau_sprites05.png
# Saving image img/FFRK_Cidolfus_Orlandeau_sprites06.png
# Saving image img/FFRK_Cidolfus_Orlandeau_sprites07.png
# Saving image img/FFRK_Cidolfus_Orlandeau_sprites08.png
# Saving image img/FFRK_Cidolfus_Orlandeau_sprites09.png
# Saving image img/FFRK_Cidolfus_Orlandeau_sprites10.png
# Saving image img/FFRK_Cidolfus_Orlandeau_sprites11.png
# Saving image img/FFRK_Cidolfus_Orlandeau_sprites12.png
# Saving image img/FFRK_Cidolfus_Orlandeau_sprites13.png
# Saving image img/FFRK_Cidolfus_Orlandeau_sprites14.png
# Saving image img/FFRK_Cidolfus_Orlandeau_sprites15.png
# Saving image img/FFRK_Cidolfus_Orlandeau_sprites16.png
# Saving image img/FFRK_Cidolfus_Orlandeau_sprites17.png
# Saving image img/FFRK_Cidolfus_Orlandeau_sprites18.png
# Saving image img/FFRK_Cid_Highwind_sprites01.png
# Saving image img/FFRK_Cid_Highwind_sprites02.png
# Saving image img/FFRK_Cid_Highwind_sprites03.png
# Saving image img/FFRK_Cid_Highwind_sprites04.png
# Saving image img/FFRK_Cid_Highwind_sprites05.png
# Saving image img/FFRK_Cid_Highwind_sprites06.png
# Saving image img/FFRK_Cid_Highwind_sprites07.png
# Saving image img/FFRK_Cid_Highwind_sprites08.png
# Saving image img/FFRK_Cid_Highwind_sprites09.png
# Saving image img/FFRK_Cid_Highwind_sprites10.png
# Saving image img/FFRK_Cid_Highwind_sprites11.png
# Saving image img/FFRK_Cid_Highwind_sprites12.png
# Saving image img/FFRK_Cid_Highwind_sprites13.png
# Saving image img/FFRK_Cid_Highwind_sprites14.png
# Saving image img/FFRK_Cid_Highwind_sprites15.png
# Saving image img/FFRK_Cid_Highwind_sprites16.png
# Saving image img/FFRK_Cid_Highwind_sprites17.png
# Saving image img/FFRK_Cid_Highwind_sprites18.png
# Saving image img/FFRK_Cid_nan_Garlond_sprites01.png
# Saving image img/FFRK_Cid_nan_Garlond_sprites02.png
# Saving image img/FFRK_Cid_nan_Garlond_sprites03.png
# Saving image img/FFRK_Cid_nan_Garlond_sprites04.png
# Saving image img/FFRK_Cid_nan_Garlond_sprites05.png
# Saving image img/FFRK_Cid_nan_Garlond_sprites06.png
# Saving image img/FFRK_Cid_nan_Garlond_sprites07.png
# Saving image img/FFRK_Cid_nan_Garlond_sprites08.png
# Saving image img/FFRK_Cid_nan_Garlond_sprites09.png
# Saving image img/FFRK_Cid_nan_Garlond_sprites10.png
# Saving image img/FFRK_Cid_nan_Garlond_sprites11.png
# Saving image img/FFRK_Cid_nan_Garlond_sprites12.png
# Saving image img/FFRK_Cid_nan_Garlond_sprites13.png
# Saving image img/FFRK_Cid_nan_Garlond_sprites14.png
# Saving image img/FFRK_Cid_nan_Garlond_sprites15.png
# Saving image img/FFRK_Cid_nan_Garlond_sprites16.png
# Saving image img/FFRK_Cid_nan_Garlond_sprites17.png
# Saving image img/FFRK_Cid_nan_Garlond_sprites18.png
# Saving image img/FFRK_Cid_Pollendina_sprites01.png
# Saving image img/FFRK_Cid_Pollendina_sprites02.png
# Saving image img/FFRK_Cid_Pollendina_sprites03.png
# Saving image img/FFRK_Cid_Pollendina_sprites04.png
# Saving image img/FFRK_Cid_Pollendina_sprites05.png
# Saving image img/FFRK_Cid_Pollendina_sprites06.png
# Saving image img/FFRK_Cid_Pollendina_sprites07.png
# Saving image img/FFRK_Cid_Pollendina_sprites08.png
# Saving image img/FFRK_Cid_Pollendina_sprites09.png
# Saving image img/FFRK_Cid_Pollendina_sprites10.png
# Saving image img/FFRK_Cid_Pollendina_sprites11.png
# Saving image img/FFRK_Cid_Pollendina_sprites12.png
# Saving image img/FFRK_Cid_Pollendina_sprites13.png
# Saving image img/FFRK_Cid_Pollendina_sprites14.png
# Saving image img/FFRK_Cid_Pollendina_sprites15.png
# Saving image img/FFRK_Cid_Pollendina_sprites16.png
# Saving image img/FFRK_Cid_Pollendina_sprites17.png
# Saving image img/FFRK_Cid_Pollendina_sprites18.png
# Saving image img/FFRK_Cid_Raines_sprites01.png
# Saving image img/FFRK_Cid_Raines_sprites02.png
# Saving image img/FFRK_Cid_Raines_sprites03.png
# Saving image img/FFRK_Cid_Raines_sprites04.png
# Saving image img/FFRK_Cid_Raines_sprites05.png
# Saving image img/FFRK_Cid_Raines_sprites06.png
# Saving image img/FFRK_Cid_Raines_sprites07.png
# Saving image img/FFRK_Cid_Raines_sprites08.png
# Saving image img/FFRK_Cid_Raines_sprites09.png
# Saving image img/FFRK_Cid_Raines_sprites10.png
# Saving image img/FFRK_Cid_Raines_sprites11.png
# Saving image img/FFRK_Cid_Raines_sprites12.png
# Saving image img/FFRK_Cid_Raines_sprites13.png
# Saving image img/FFRK_Cid_Raines_sprites14.png
# Saving image img/FFRK_Cid_Raines_sprites15.png
# Saving image img/FFRK_Cid_Raines_sprites16.png
# Saving image img/FFRK_Cid_Raines_sprites17.png
# Saving image img/FFRK_Cid_Raines_sprites18.png
# Saving image img/FFRK_Cinque_sprites01.png
# Saving image img/FFRK_Cinque_sprites02.png
# Saving image img/FFRK_Cinque_sprites03.png
# Saving image img/FFRK_Cinque_sprites04.png
# Saving image img/FFRK_Cinque_sprites05.png
# Saving image img/FFRK_Cinque_sprites06.png
# Saving image img/FFRK_Cinque_sprites07.png
# Saving image img/FFRK_Cinque_sprites08.png
# Saving image img/FFRK_Cinque_sprites09.png
# Saving image img/FFRK_Cinque_sprites10.png
# Saving image img/FFRK_Cinque_sprites11.png
# Saving image img/FFRK_Cinque_sprites12.png
# Saving image img/FFRK_Cinque_sprites13.png
# Saving image img/FFRK_Cinque_sprites14.png
# Saving image img/FFRK_Cinque_sprites15.png
# Saving image img/FFRK_Cinque_sprites16.png
# Saving image img/FFRK_Cinque_sprites17.png
# Saving image img/FFRK_Cinque_sprites18.png
# Saving image img/FFRK_Cloud_(Festival)_sprites01.png
# Saving image img/FFRK_Cloud_(Festival)_sprites02.png
# Saving image img/FFRK_Cloud_(Festival)_sprites03.png
# Saving image img/FFRK_Cloud_(Festival)_sprites04.png
# Saving image img/FFRK_Cloud_(Festival)_sprites05.png
# Saving image img/FFRK_Cloud_(Festival)_sprites06.png
# Saving image img/FFRK_Cloud_(Festival)_sprites07.png
# Saving image img/FFRK_Cloud_(Festival)_sprites08.png
# Saving image img/FFRK_Cloud_(Festival)_sprites09.png
# Saving image img/FFRK_Cloud_(Festival)_sprites10.png
# Saving image img/FFRK_Cloud_(Festival)_sprites11.png
# Saving image img/FFRK_Cloud_(Festival)_sprites12.png
# Saving image img/FFRK_Cloud_(Festival)_sprites13.png
# Saving image img/FFRK_Cloud_(Festival)_sprites14.png
# Saving image img/FFRK_Cloud_(Festival)_sprites15.png
# Saving image img/FFRK_Cloud_(Festival)_sprites16.png
# Saving image img/FFRK_Cloud_(Festival)_sprites17.png
# Saving image img/FFRK_Cloud_(Festival)_sprites18.png
# Saving image img/FFRK_Cloud_FFVII_sprites01.png
# Saving image img/FFRK_Cloud_FFVII_sprites02.png
# Saving image img/FFRK_Cloud_FFVII_sprites03.png
# Saving image img/FFRK_Cloud_FFVII_sprites04.png
# Saving image img/FFRK_Cloud_FFVII_sprites05.png
# Saving image img/FFRK_Cloud_FFVII_sprites06.png
# Saving image img/FFRK_Cloud_FFVII_sprites07.png
# Saving image img/FFRK_Cloud_FFVII_sprites08.png
# Saving image img/FFRK_Cloud_FFVII_sprites09.png
# Saving image img/FFRK_Cloud_FFVII_sprites10.png
# Saving image img/FFRK_Cloud_FFVII_sprites11.png
# Saving image img/FFRK_Cloud_FFVII_sprites12.png
# Saving image img/FFRK_Cloud_FFVII_sprites13.png
# Saving image img/FFRK_Cloud_FFVII_sprites14.png
# Saving image img/FFRK_Cloud_FFVII_sprites15.png
# Saving image img/FFRK_Cloud_FFVII_sprites16.png
# Saving image img/FFRK_Cloud_FFVII_sprites17.png
# Saving image img/FFRK_Cloud_FFVII_sprites18.png
# Saving image img/FFRK_Cloud_KH_sprites01.png
# Saving image img/FFRK_Cloud_KH_sprites02.png
# Saving image img/FFRK_Cloud_KH_sprites03.png
# Saving image img/FFRK_Cloud_KH_sprites04.png
# Saving image img/FFRK_Cloud_KH_sprites05.png
# Saving image img/FFRK_Cloud_KH_sprites06.png
# Saving image img/FFRK_Cloud_KH_sprites07.png
# Saving image img/FFRK_Cloud_KH_sprites08.png
# Saving image img/FFRK_Cloud_KH_sprites09.png
# Saving image img/FFRK_Cloud_KH_sprites10.png
# Saving image img/FFRK_Cloud_KH_sprites11.png
# Saving image img/FFRK_Cloud_KH_sprites12.png
# Saving image img/FFRK_Cloud_KH_sprites13.png
# Saving image img/FFRK_Cloud_KH_sprites14.png
# Saving image img/FFRK_Cloud_KH_sprites15.png
# Saving image img/FFRK_Cloud_KH_sprites16.png
# Saving image img/FFRK_Cloud_KH_sprites17.png
# Saving image img/FFRK_Cloud_KH_sprites18.png
# Saving image img/FFRK_Cloud_of_Darkness_sprites01.png
# Saving image img/FFRK_Cloud_of_Darkness_sprites02.png
# Saving image img/FFRK_Cloud_of_Darkness_sprites03.png
# Saving image img/FFRK_Cloud_of_Darkness_sprites04.png
# Saving image img/FFRK_Cloud_of_Darkness_sprites05.png
# Saving image img/FFRK_Cloud_of_Darkness_sprites06.png
# Saving image img/FFRK_Cloud_of_Darkness_sprites07.png
# Saving image img/FFRK_Cloud_of_Darkness_sprites08.png
# Saving image img/FFRK_Cloud_of_Darkness_sprites09.png
# Saving image img/FFRK_Cloud_of_Darkness_sprites10.png
# Saving image img/FFRK_Cloud_of_Darkness_sprites11.png
# Saving image img/FFRK_Cloud_of_Darkness_sprites12.png
# Saving image img/FFRK_Cloud_of_Darkness_sprites13.png
# Saving image img/FFRK_Cloud_of_Darkness_sprites14.png
# Saving image img/FFRK_Cloud_of_Darkness_sprites15.png
# Saving image img/FFRK_Cloud_of_Darkness_sprites16.png
# Saving image img/FFRK_Cloud_of_Darkness_sprites17.png
# Saving image img/FFRK_Cloud_of_Darkness_sprites18.png
# Saving image img/FFRK_Cloud_VIIAC_sprites01.png
# Saving image img/FFRK_Cloud_VIIAC_sprites02.png
# Saving image img/FFRK_Cloud_VIIAC_sprites03.png
# Saving image img/FFRK_Cloud_VIIAC_sprites04.png
# Saving image img/FFRK_Cloud_VIIAC_sprites05.png
# Saving image img/FFRK_Cloud_VIIAC_sprites06.png
# Saving image img/FFRK_Cloud_VIIAC_sprites07.png
# Saving image img/FFRK_Cloud_VIIAC_sprites08.png
# Saving image img/FFRK_Cloud_VIIAC_sprites09.png
# Saving image img/FFRK_Cloud_VIIAC_sprites10.png
# Saving image img/FFRK_Cloud_VIIAC_sprites11.png
# Saving image img/FFRK_Cloud_VIIAC_sprites12.png
# Saving image img/FFRK_Cloud_VIIAC_sprites13.png
# Saving image img/FFRK_Cloud_VIIAC_sprites14.png
# Saving image img/FFRK_Cloud_VIIAC_sprites15.png
# Saving image img/FFRK_Cloud_VIIAC_sprites16.png
# Saving image img/FFRK_Cloud_VIIAC_sprites17.png
# Saving image img/FFRK_Cloud_VIIAC_sprites18.png
# Saving image img/FFRK_Curilla_sprites01.png
# Saving image img/FFRK_Curilla_sprites02.png
# Saving image img/FFRK_Curilla_sprites03.png
# Saving image img/FFRK_Curilla_sprites04.png
# Saving image img/FFRK_Curilla_sprites05.png
# Saving image img/FFRK_Curilla_sprites06.png
# Saving image img/FFRK_Curilla_sprites07.png
# Saving image img/FFRK_Curilla_sprites08.png
# Saving image img/FFRK_Curilla_sprites09.png
# Saving image img/FFRK_Curilla_sprites10.png
# Saving image img/FFRK_Curilla_sprites11.png
# Saving image img/FFRK_Curilla_sprites12.png
# Saving image img/FFRK_Curilla_sprites13.png
# Saving image img/FFRK_Curilla_sprites14.png
# Saving image img/FFRK_Curilla_sprites15.png
# Saving image img/FFRK_Curilla_sprites16.png
# Saving image img/FFRK_Curilla_sprites17.png
# Saving image img/FFRK_Curilla_sprites18.png
# Saving image img/FFRK_Cyan_sprites01.png
# Saving image img/FFRK_Cyan_sprites02.png
# Saving image img/FFRK_Cyan_sprites03.png
# Saving image img/FFRK_Cyan_sprites04.png
# Saving image img/FFRK_Cyan_sprites05.png
# Saving image img/FFRK_Cyan_sprites06.png
# Saving image img/FFRK_Cyan_sprites07.png
# Saving image img/FFRK_Cyan_sprites08.png
# Saving image img/FFRK_Cyan_sprites09.png
# Saving image img/FFRK_Cyan_sprites10.png
# Saving image img/FFRK_Cyan_sprites11.png
# Saving image img/FFRK_Cyan_sprites12.png
# Saving image img/FFRK_Cyan_sprites13.png
# Saving image img/FFRK_Cyan_sprites14.png
# Saving image img/FFRK_Cyan_sprites15.png
# Saving image img/FFRK_Cyan_sprites16.png
# Saving image img/FFRK_Cyan_sprites17.png
# Saving image img/FFRK_Cyan_sprites18.png
# Saving image img/FFRK_Dark_Knight_Cecil_sprites01.png
# Saving image img/FFRK_Dark_Knight_Cecil_sprites02.png
# Saving image img/FFRK_Dark_Knight_Cecil_sprites03.png
# Saving image img/FFRK_Dark_Knight_Cecil_sprites04.png
# Saving image img/FFRK_Dark_Knight_Cecil_sprites05.png
# Saving image img/FFRK_Dark_Knight_Cecil_sprites06.png
# Saving image img/FFRK_Dark_Knight_Cecil_sprites07.png
# Saving image img/FFRK_Dark_Knight_Cecil_sprites08.png
# Saving image img/FFRK_Dark_Knight_Cecil_sprites09.png
# Saving image img/FFRK_Dark_Knight_Cecil_sprites10.png
# Saving image img/FFRK_Dark_Knight_Cecil_sprites11.png
# Saving image img/FFRK_Dark_Knight_Cecil_sprites12.png
# Saving image img/FFRK_Dark_Knight_Cecil_sprites13.png
# Saving image img/FFRK_Dark_Knight_Cecil_sprites14.png
# Saving image img/FFRK_Dark_Knight_Cecil_sprites15.png
# Saving image img/FFRK_Dark_Knight_Cecil_sprites16.png
# Saving image img/FFRK_Dark_Knight_Cecil_sprites17.png
# Saving image img/FFRK_Dark_Knight_Cecil_sprites18.png
# Saving image img/FFRK_Delita_Holy_Knight_sprites01.png
# Saving image img/FFRK_Delita_Holy_Knight_sprites02.png
# Saving image img/FFRK_Delita_Holy_Knight_sprites03.png
# Saving image img/FFRK_Delita_Holy_Knight_sprites04.png
# Saving image img/FFRK_Delita_Holy_Knight_sprites05.png
# Saving image img/FFRK_Delita_Holy_Knight_sprites06.png
# Saving image img/FFRK_Delita_Holy_Knight_sprites07.png
# Saving image img/FFRK_Delita_Holy_Knight_sprites08.png
# Saving image img/FFRK_Delita_Holy_Knight_sprites09.png
# Saving image img/FFRK_Delita_Holy_Knight_sprites10.png
# Saving image img/FFRK_Delita_Holy_Knight_sprites11.png
# Saving image img/FFRK_Delita_Holy_Knight_sprites12.png
# Saving image img/FFRK_Delita_Holy_Knight_sprites13.png
# Saving image img/FFRK_Delita_Holy_Knight_sprites14.png
# Saving image img/FFRK_Delita_Holy_Knight_sprites15.png
# Saving image img/FFRK_Delita_Holy_Knight_sprites16.png
# Saving image img/FFRK_Delita_Holy_Knight_sprites17.png
# Saving image img/FFRK_Delita_Holy_Knight_sprites18.png
# Saving image img/FFRK_Desch_sprites01.png
# Saving image img/FFRK_Desch_sprites02.png
# Saving image img/FFRK_Desch_sprites03.png
# Saving image img/FFRK_Desch_sprites04.png
# Saving image img/FFRK_Desch_sprites05.png
# Saving image img/FFRK_Desch_sprites06.png
# Saving image img/FFRK_Desch_sprites07.png
# Saving image img/FFRK_Desch_sprites08.png
# Saving image img/FFRK_Desch_sprites09.png
# Saving image img/FFRK_Desch_sprites10.png
# Saving image img/FFRK_Desch_sprites11.png
# Saving image img/FFRK_Desch_sprites12.png
# Saving image img/FFRK_Desch_sprites13.png
# Saving image img/FFRK_Desch_sprites14.png
# Saving image img/FFRK_Desch_sprites15.png
# Saving image img/FFRK_Desch_sprites16.png
# Saving image img/FFRK_Desch_sprites17.png
# Saving image img/FFRK_Desch_sprites18.png
# Saving image img/FFRK_Deuce_sprites01.png
# Saving image img/FFRK_Deuce_sprites02.png
# Saving image img/FFRK_Deuce_sprites03.png
# Saving image img/FFRK_Deuce_sprites04.png
# Saving image img/FFRK_Deuce_sprites05.png
# Saving image img/FFRK_Deuce_sprites06.png
# Saving image img/FFRK_Deuce_sprites07.png
# Saving image img/FFRK_Deuce_sprites08.png
# Saving image img/FFRK_Deuce_sprites09.png
# Saving image img/FFRK_Deuce_sprites10.png
# Saving image img/FFRK_Deuce_sprites11.png
# Saving image img/FFRK_Deuce_sprites12.png
# Saving image img/FFRK_Deuce_sprites13.png
# Saving image img/FFRK_Deuce_sprites14.png
# Saving image img/FFRK_Deuce_sprites15.png
# Saving image img/FFRK_Deuce_sprites16.png
# Saving image img/FFRK_Deuce_sprites17.png
# Saving image img/FFRK_Deuce_sprites18.png
# Saving image img/FFRK_Devout_sprites01.png
# Saving image img/FFRK_Devout_sprites02.png
# Saving image img/FFRK_Devout_sprites03.png
# Saving image img/FFRK_Devout_sprites04.png
# Saving image img/FFRK_Devout_sprites05.png
# Saving image img/FFRK_Devout_sprites06.png
# Saving image img/FFRK_Devout_sprites07.png
# Saving image img/FFRK_Devout_sprites08.png
# Saving image img/FFRK_Devout_sprites09.png
# Saving image img/FFRK_Devout_sprites10.png
# Saving image img/FFRK_Devout_sprites11.png
# Saving image img/FFRK_Devout_sprites12.png
# Saving image img/FFRK_Devout_sprites13.png
# Saving image img/FFRK_Devout_sprites14.png
# Saving image img/FFRK_Devout_sprites15.png
# Saving image img/FFRK_Devout_sprites16.png
# Saving image img/FFRK_Devout_sprites17.png
# Saving image img/FFRK_Devout_sprites18.png
# Saving image img/FFRK_Dorgann_sprites01.png
# Saving image img/FFRK_Dorgann_sprites02.png
# Saving image img/FFRK_Dorgann_sprites03.png
# Saving image img/FFRK_Dorgann_sprites04.png
# Saving image img/FFRK_Dorgann_sprites05.png
# Saving image img/FFRK_Dorgann_sprites06.png
# Saving image img/FFRK_Dorgann_sprites07.png
# Saving image img/FFRK_Dorgann_sprites08.png
# Saving image img/FFRK_Dorgann_sprites09.png
# Saving image img/FFRK_Dorgann_sprites10.png
# Saving image img/FFRK_Dorgann_sprites11.png
# Saving image img/FFRK_Dorgann_sprites12.png
# Saving image img/FFRK_Dorgann_sprites13.png
# Saving image img/FFRK_Dorgann_sprites14.png
# Saving image img/FFRK_Dorgann_sprites15.png
# Saving image img/FFRK_Dorgann_sprites16.png
# Saving image img/FFRK_Dorgann_sprites17.png
# ...
# Saving image img/FFRK_Warrior_of_Light_sprites05.png
# Saving image img/FFRK_Warrior_of_Light_sprites06.png
# Saving image img/FFRK_Warrior_of_Light_sprites07.png
# Saving image img/FFRK_Warrior_of_Light_sprites08.png
# Saving image img/FFRK_Warrior_of_Light_sprites09.png
# Saving image img/FFRK_Warrior_of_Light_sprites10.png
# Saving image img/FFRK_Warrior_of_Light_sprites11.png
# Saving image img/FFRK_Warrior_of_Light_sprites12.png
# Saving image img/FFRK_Warrior_of_Light_sprites13.png
# Saving image img/FFRK_Warrior_of_Light_sprites14.png
# Saving image img/FFRK_Warrior_of_Light_sprites15.png
# Saving image img/FFRK_Warrior_of_Light_sprites16.png
# Saving image img/FFRK_Warrior_of_Light_sprites17.png
# Saving image img/FFRK_Warrior_of_Light_sprites18.png
# Saving image img/FFRK_Warrior_sprites01.png
# Saving image img/FFRK_Warrior_sprites02.png
# Saving image img/FFRK_Warrior_sprites03.png
# Saving image img/FFRK_Warrior_sprites04.png
# Saving image img/FFRK_Warrior_sprites05.png
# Saving image img/FFRK_Warrior_sprites06.png
# Saving image img/FFRK_Warrior_sprites07.png
# Saving image img/FFRK_Warrior_sprites08.png
# Saving image img/FFRK_Warrior_sprites09.png
# Saving image img/FFRK_Warrior_sprites10.png
# Saving image img/FFRK_Warrior_sprites11.png
# Saving image img/FFRK_Warrior_sprites12.png
# Saving image img/FFRK_Warrior_sprites13.png
# Saving image img/FFRK_Warrior_sprites14.png
# Saving image img/FFRK_Warrior_sprites15.png
# Saving image img/FFRK_Warrior_sprites16.png
# Saving image img/FFRK_Warrior_sprites17.png
# Saving image img/FFRK_Warrior_sprites18.png
# Saving image img/FFRK_White_Mage_sprites01.png
# Saving image img/FFRK_White_Mage_sprites02.png
# Saving image img/FFRK_White_Mage_sprites03.png
# Saving image img/FFRK_White_Mage_sprites04.png
# Saving image img/FFRK_White_Mage_sprites05.png
# Saving image img/FFRK_White_Mage_sprites06.png
# Saving image img/FFRK_White_Mage_sprites07.png
# Saving image img/FFRK_White_Mage_sprites08.png
# Saving image img/FFRK_White_Mage_sprites09.png
# Saving image img/FFRK_White_Mage_sprites10.png
# Saving image img/FFRK_White_Mage_sprites11.png
# Saving image img/FFRK_White_Mage_sprites12.png
# Saving image img/FFRK_White_Mage_sprites13.png
# Saving image img/FFRK_White_Mage_sprites14.png
# Saving image img/FFRK_White_Mage_sprites15.png
# Saving image img/FFRK_White_Mage_sprites16.png
# Saving image img/FFRK_White_Mage_sprites17.png
# Saving image img/FFRK_White_Mage_sprites18.png
# Saving image img/FFRK_Wol_sprites01.png
# Saving image img/FFRK_Wol_sprites02.png
# Saving image img/FFRK_Wol_sprites03.png
# Saving image img/FFRK_Wol_sprites04.png
# Saving image img/FFRK_Wol_sprites05.png
# Saving image img/FFRK_Wol_sprites06.png
# Saving image img/FFRK_Wol_sprites07.png
# Saving image img/FFRK_Wol_sprites08.png
# Saving image img/FFRK_Wol_sprites09.png
# Saving image img/FFRK_Wol_sprites10.png
# Saving image img/FFRK_Wol_sprites11.png
# Saving image img/FFRK_Wol_sprites12.png
# Saving image img/FFRK_Wol_sprites13.png
# Saving image img/FFRK_Wol_sprites14.png
# Saving image img/FFRK_Wol_sprites15.png
# Saving image img/FFRK_Wol_sprites16.png
# Saving image img/FFRK_Wol_sprites17.png
# Saving image img/FFRK_Wol_sprites18.png
# Saving image img/FFRK_Xezat_sprites01.png
# Saving image img/FFRK_Xezat_sprites02.png
# Saving image img/FFRK_Xezat_sprites03.png
# Saving image img/FFRK_Xezat_sprites04.png
# Saving image img/FFRK_Xezat_sprites05.png
# Saving image img/FFRK_Xezat_sprites06.png
# Saving image img/FFRK_Xezat_sprites07.png
# Saving image img/FFRK_Xezat_sprites08.png
# Saving image img/FFRK_Xezat_sprites09.png
# Saving image img/FFRK_Xezat_sprites10.png
# Saving image img/FFRK_Xezat_sprites11.png
# Saving image img/FFRK_Xezat_sprites12.png
# Saving image img/FFRK_Xezat_sprites13.png
# Saving image img/FFRK_Xezat_sprites14.png
# Saving image img/FFRK_Xezat_sprites15.png
# Saving image img/FFRK_Xezat_sprites16.png
# Saving image img/FFRK_Xezat_sprites17.png
# Saving image img/FFRK_Xezat_sprites18.png
# Saving image img/FFRK_Y%27shtola_sprites01.png
# Saving image img/FFRK_Y%27shtola_sprites02.png
# Saving image img/FFRK_Y%27shtola_sprites03.png
# Saving image img/FFRK_Y%27shtola_sprites04.png
# Saving image img/FFRK_Y%27shtola_sprites05.png
# Saving image img/FFRK_Y%27shtola_sprites06.png
# Saving image img/FFRK_Y%27shtola_sprites07.png
# Saving image img/FFRK_Y%27shtola_sprites08.png
# Saving image img/FFRK_Y%27shtola_sprites09.png
# Saving image img/FFRK_Y%27shtola_sprites10.png
# Saving image img/FFRK_Y%27shtola_sprites11.png
# Saving image img/FFRK_Y%27shtola_sprites12.png
# Saving image img/FFRK_Y%27shtola_sprites13.png
# Saving image img/FFRK_Y%27shtola_sprites14.png
# Saving image img/FFRK_Y%27shtola_sprites15.png
# Saving image img/FFRK_Y%27shtola_sprites16.png
# Saving image img/FFRK_Y%27shtola_sprites17.png
# Saving image img/FFRK_Y%27shtola_sprites18.png
# Saving image img/FFRK_Yang_sprites01.png
# Saving image img/FFRK_Yang_sprites02.png
# Saving image img/FFRK_Yang_sprites03.png
# Saving image img/FFRK_Yang_sprites04.png
# Saving image img/FFRK_Yang_sprites05.png
# Saving image img/FFRK_Yang_sprites06.png
# Saving image img/FFRK_Yang_sprites07.png
# Saving image img/FFRK_Yang_sprites08.png
# Saving image img/FFRK_Yang_sprites09.png
# Saving image img/FFRK_Yang_sprites10.png
# Saving image img/FFRK_Yang_sprites11.png
# Saving image img/FFRK_Yang_sprites12.png
# Saving image img/FFRK_Yang_sprites13.png
# Saving image img/FFRK_Yang_sprites14.png
# Saving image img/FFRK_Yang_sprites15.png
# Saving image img/FFRK_Yang_sprites16.png
# Saving image img/FFRK_Yang_sprites17.png
# Saving image img/FFRK_Yang_sprites18.png
# Saving image img/FFRK_Yda_sprites01.png
# Saving image img/FFRK_Yda_sprites02.png
# Saving image img/FFRK_Yda_sprites03.png
# Saving image img/FFRK_Yda_sprites04.png
# Saving image img/FFRK_Yda_sprites05.png
# Saving image img/FFRK_Yda_sprites06.png
# Saving image img/FFRK_Yda_sprites07.png
# Saving image img/FFRK_Yda_sprites08.png
# Saving image img/FFRK_Yda_sprites09.png
# Saving image img/FFRK_Yda_sprites10.png
# Saving image img/FFRK_Yda_sprites11.png
# Saving image img/FFRK_Yda_sprites12.png
# Saving image img/FFRK_Yda_sprites13.png
# Saving image img/FFRK_Yda_sprites14.png
# Saving image img/FFRK_Yda_sprites15.png
# Saving image img/FFRK_Yda_sprites16.png
# Saving image img/FFRK_Yda_sprites17.png
# Saving image img/FFRK_Yda_sprites18.png
# Saving image img/FFRK_Young_Auron_sprites01.png
# Saving image img/FFRK_Young_Auron_sprites02.png
# Saving image img/FFRK_Young_Auron_sprites03.png
# Saving image img/FFRK_Young_Auron_sprites04.png
# Saving image img/FFRK_Young_Auron_sprites05.png
# Saving image img/FFRK_Young_Auron_sprites06.png
# Saving image img/FFRK_Young_Auron_sprites07.png
# Saving image img/FFRK_Young_Auron_sprites08.png
# Saving image img/FFRK_Young_Auron_sprites09.png
# Saving image img/FFRK_Young_Auron_sprites10.png
# Saving image img/FFRK_Young_Auron_sprites11.png
# Saving image img/FFRK_Young_Auron_sprites12.png
# Saving image img/FFRK_Young_Auron_sprites13.png
# Saving image img/FFRK_Young_Auron_sprites14.png
# Saving image img/FFRK_Young_Auron_sprites15.png
# Saving image img/FFRK_Young_Auron_sprites16.png
# Saving image img/FFRK_Young_Auron_sprites17.png
# Saving image img/FFRK_Young_Auron_sprites18.png
# Saving image img/FFRK_Ysayle_sprites01.png
# Saving image img/FFRK_Ysayle_sprites02.png
# Saving image img/FFRK_Ysayle_sprites03.png
# Saving image img/FFRK_Ysayle_sprites04.png
# Saving image img/FFRK_Ysayle_sprites05.png
# Saving image img/FFRK_Ysayle_sprites06.png
# Saving image img/FFRK_Ysayle_sprites07.png
# Saving image img/FFRK_Ysayle_sprites08.png
# Saving image img/FFRK_Ysayle_sprites09.png
# Saving image img/FFRK_Ysayle_sprites10.png
# Saving image img/FFRK_Ysayle_sprites11.png
# Saving image img/FFRK_Ysayle_sprites12.png
# Saving image img/FFRK_Ysayle_sprites13.png
# Saving image img/FFRK_Ysayle_sprites14.png
# Saving image img/FFRK_Ysayle_sprites15.png
# Saving image img/FFRK_Ysayle_sprites16.png
# Saving image img/FFRK_Ysayle_sprites17.png
# Saving image img/FFRK_Ysayle_sprites18.png
# Saving image img/FFRK_Yuffie_sprites01.png
# Saving image img/FFRK_Yuffie_sprites02.png
# Saving image img/FFRK_Yuffie_sprites03.png
# Saving image img/FFRK_Yuffie_sprites04.png
# Saving image img/FFRK_Yuffie_sprites05.png
# Saving image img/FFRK_Yuffie_sprites06.png
# Saving image img/FFRK_Yuffie_sprites07.png
# Saving image img/FFRK_Yuffie_sprites08.png
# Saving image img/FFRK_Yuffie_sprites09.png
# Saving image img/FFRK_Yuffie_sprites10.png
# Saving image img/FFRK_Yuffie_sprites11.png
# Saving image img/FFRK_Yuffie_sprites12.png
# Saving image img/FFRK_Yuffie_sprites13.png
# Saving image img/FFRK_Yuffie_sprites14.png
# Saving image img/FFRK_Yuffie_sprites15.png
# Saving image img/FFRK_Yuffie_sprites16.png
# Saving image img/FFRK_Yuffie_sprites17.png
# Saving image img/FFRK_Yuffie_sprites18.png
# Saving image img/FFRK_Yuna_False_Bride_sprites01.png
# Saving image img/FFRK_Yuna_False_Bride_sprites02.png
# Saving image img/FFRK_Yuna_False_Bride_sprites03.png
# Saving image img/FFRK_Yuna_False_Bride_sprites04.png
# Saving image img/FFRK_Yuna_False_Bride_sprites05.png
# Saving image img/FFRK_Yuna_False_Bride_sprites06.png
# Saving image img/FFRK_Yuna_False_Bride_sprites07.png
# Saving image img/FFRK_Yuna_False_Bride_sprites08.png
# Saving image img/FFRK_Yuna_False_Bride_sprites09.png
# Saving image img/FFRK_Yuna_False_Bride_sprites10.png
# Saving image img/FFRK_Yuna_False_Bride_sprites11.png
# Saving image img/FFRK_Yuna_False_Bride_sprites12.png
# Saving image img/FFRK_Yuna_False_Bride_sprites13.png
# Saving image img/FFRK_Yuna_False_Bride_sprites14.png
# Saving image img/FFRK_Yuna_False_Bride_sprites15.png
# Saving image img/FFRK_Yuna_False_Bride_sprites16.png
# Saving image img/FFRK_Yuna_False_Bride_sprites17.png
# Saving image img/FFRK_Yuna_False_Bride_sprites18.png
# Saving image img/FFRK_Yuna_sprites01.png
# Saving image img/FFRK_Yuna_sprites02.png
# Saving image img/FFRK_Yuna_sprites03.png
# Saving image img/FFRK_Yuna_sprites04.png
# Saving image img/FFRK_Yuna_sprites05.png
# Saving image img/FFRK_Yuna_sprites06.png
# Saving image img/FFRK_Yuna_sprites07.png
# Saving image img/FFRK_Yuna_sprites08.png
# Saving image img/FFRK_Yuna_sprites09.png
# Saving image img/FFRK_Yuna_sprites10.png
# Saving image img/FFRK_Yuna_sprites11.png
# Saving image img/FFRK_Yuna_sprites12.png
# Saving image img/FFRK_Yuna_sprites13.png
# Saving image img/FFRK_Yuna_sprites14.png
# Saving image img/FFRK_Yuna_sprites15.png
# Saving image img/FFRK_Yuna_sprites16.png
# Saving image img/FFRK_Yuna_sprites17.png
# Saving image img/FFRK_Yuna_sprites18.png
# Saving image img/FFRK_Yuna_X2_sprites01.png
# Saving image img/FFRK_Yuna_X2_sprites02.png
# Saving image img/FFRK_Yuna_X2_sprites03.png
# Saving image img/FFRK_Yuna_X2_sprites04.png
# Saving image img/FFRK_Yuna_X2_sprites05.png
# Saving image img/FFRK_Yuna_X2_sprites06.png
# Saving image img/FFRK_Yuna_X2_sprites07.png
# Saving image img/FFRK_Yuna_X2_sprites08.png
# Saving image img/FFRK_Yuna_X2_sprites09.png
# Saving image img/FFRK_Yuna_X2_sprites10.png
# Saving image img/FFRK_Yuna_X2_sprites11.png
# Saving image img/FFRK_Yuna_X2_sprites12.png
# Saving image img/FFRK_Yuna_X2_sprites13.png
# Saving image img/FFRK_Yuna_X2_sprites14.png
# Saving image img/FFRK_Yuna_X2_sprites15.png
# Saving image img/FFRK_Yuna_X2_sprites16.png
# Saving image img/FFRK_Yuna_X2_sprites17.png
# Saving image img/FFRK_Yuna_X2_sprites18.png
# Saving image img/FFRK_Zack_sprites01.png
# Saving image img/FFRK_Zack_sprites02.png
# Saving image img/FFRK_Zack_sprites03.png
# Saving image img/FFRK_Zack_sprites04.png
# Saving image img/FFRK_Zack_sprites05.png
# Saving image img/FFRK_Zack_sprites06.png
# Saving image img/FFRK_Zack_sprites07.png
# Saving image img/FFRK_Zack_sprites08.png
# Saving image img/FFRK_Zack_sprites09.png
# Saving image img/FFRK_Zack_sprites10.png
# Saving image img/FFRK_Zack_sprites11.png
# Saving image img/FFRK_Zack_sprites12.png
# Saving image img/FFRK_Zack_sprites13.png
# Saving image img/FFRK_Zack_sprites14.png
# Saving image img/FFRK_Zack_sprites15.png
# Saving image img/FFRK_Zack_sprites16.png
# Saving image img/FFRK_Zack_sprites17.png
# Saving image img/FFRK_Zack_sprites18.png
# Saving image img/FFRK_Zeid_sprites01.png
# Saving image img/FFRK_Zeid_sprites02.png
# Saving image img/FFRK_Zeid_sprites03.png
# Saving image img/FFRK_Zeid_sprites04.png
# Saving image img/FFRK_Zeid_sprites05.png
# Saving image img/FFRK_Zeid_sprites06.png
# Saving image img/FFRK_Zeid_sprites07.png
# Saving image img/FFRK_Zeid_sprites08.png
# Saving image img/FFRK_Zeid_sprites09.png
# Saving image img/FFRK_Zeid_sprites10.png
# Saving image img/FFRK_Zeid_sprites11.png
# Saving image img/FFRK_Zeid_sprites12.png
# Saving image img/FFRK_Zeid_sprites13.png
# Saving image img/FFRK_Zeid_sprites14.png
# Saving image img/FFRK_Zeid_sprites15.png
# Saving image img/FFRK_Zeid_sprites16.png
# Saving image img/FFRK_Zeid_sprites17.png
# Saving image img/FFRK_Zeid_sprites18.png
# Saving image img/FFRK_Zell_Garden_Uniform_sprites01.png
# Saving image img/FFRK_Zell_Garden_Uniform_sprites02.png
# Saving image img/FFRK_Zell_Garden_Uniform_sprites03.png
# Saving image img/FFRK_Zell_Garden_Uniform_sprites04.png
# Saving image img/FFRK_Zell_Garden_Uniform_sprites05.png
# Saving image img/FFRK_Zell_Garden_Uniform_sprites06.png
# Saving image img/FFRK_Zell_Garden_Uniform_sprites07.png
# Saving image img/FFRK_Zell_Garden_Uniform_sprites08.png
# Saving image img/FFRK_Zell_Garden_Uniform_sprites09.png
# Saving image img/FFRK_Zell_Garden_Uniform_sprites10.png
# Saving image img/FFRK_Zell_Garden_Uniform_sprites11.png
# Saving image img/FFRK_Zell_Garden_Uniform_sprites12.png
# Saving image img/FFRK_Zell_Garden_Uniform_sprites13.png
# Saving image img/FFRK_Zell_Garden_Uniform_sprites14.png
# Saving image img/FFRK_Zell_Garden_Uniform_sprites15.png
# Saving image img/FFRK_Zell_Garden_Uniform_sprites16.png
# Saving image img/FFRK_Zell_Garden_Uniform_sprites17.png
# Saving image img/FFRK_Zell_Garden_Uniform_sprites18.png
# Saving image img/FFRK_Zell_sprites01.png
# Saving image img/FFRK_Zell_sprites02.png
# Saving image img/FFRK_Zell_sprites03.png
# Saving image img/FFRK_Zell_sprites04.png
# Saving image img/FFRK_Zell_sprites05.png
# Saving image img/FFRK_Zell_sprites06.png
# Saving image img/FFRK_Zell_sprites07.png
# Saving image img/FFRK_Zell_sprites08.png
# Saving image img/FFRK_Zell_sprites09.png
# Saving image img/FFRK_Zell_sprites10.png
# Saving image img/FFRK_Zell_sprites11.png
# Saving image img/FFRK_Zell_sprites12.png
# Saving image img/FFRK_Zell_sprites13.png
# Saving image img/FFRK_Zell_sprites14.png
# Saving image img/FFRK_Zell_sprites15.png
# Saving image img/FFRK_Zell_sprites16.png
# Saving image img/FFRK_Zell_sprites17.png
# Saving image img/FFRK_Zell_sprites18.png
# Saving image img/FFRK_Zidane_sprites01.png
# Saving image img/FFRK_Zidane_sprites02.png
# Saving image img/FFRK_Zidane_sprites03.png
# Saving image img/FFRK_Zidane_sprites04.png
# Saving image img/FFRK_Zidane_sprites05.png
# Saving image img/FFRK_Zidane_sprites06.png
# Saving image img/FFRK_Zidane_sprites07.png
# Saving image img/FFRK_Zidane_sprites08.png
# Saving image img/FFRK_Zidane_sprites09.png
# Saving image img/FFRK_Zidane_sprites10.png
# Saving image img/FFRK_Zidane_sprites11.png
# Saving image img/FFRK_Zidane_sprites12.png
# Saving image img/FFRK_Zidane_sprites13.png
# Saving image img/FFRK_Zidane_sprites14.png
# Saving image img/FFRK_Zidane_sprites15.png
# Saving image img/FFRK_Zidane_sprites16.png
# Saving image img/FFRK_Zidane_sprites17.png
# Saving image img/FFRK_Zidane_sprites18.png
# Saving image img/FFRK_Zidane_Trance_sprites01.png
# Saving image img/FFRK_Zidane_Trance_sprites02.png
# Saving image img/FFRK_Zidane_Trance_sprites03.png
# Saving image img/FFRK_Zidane_Trance_sprites04.png
# Saving image img/FFRK_Zidane_Trance_sprites05.png
# Saving image img/FFRK_Zidane_Trance_sprites06.png
# Saving image img/FFRK_Zidane_Trance_sprites07.png
# Saving image img/FFRK_Zidane_Trance_sprites08.png
# Saving image img/FFRK_Zidane_Trance_sprites09.png
# Saving image img/FFRK_Zidane_Trance_sprites10.png
# Saving image img/FFRK_Zidane_Trance_sprites11.png
# Saving image img/FFRK_Zidane_Trance_sprites12.png
# Saving image img/FFRK_Zidane_Trance_sprites13.png
# Saving image img/FFRK_Zidane_Trance_sprites14.png
# Saving image img/FFRK_Zidane_Trance_sprites15.png
# Saving image img/FFRK_Zidane_Trance_sprites16.png
# Saving image img/FFRK_Zidane_Trance_sprites17.png
# Saving image img/FFRK_Zidane_Trance_sprites18.png

# %%
# crop sprite sheet of size w=480 x h=96
crop_all_large_spritesheets(480, 96)
# result 16 images
# Out:
# HBox(children=(IntProgress(value=0, max=625), HTML(value='')))
# Saving image img/FFRK_Dancer_sprites01.png
# Saving image img/FFRK_Dancer_sprites02.png
# Saving image img/FFRK_Dancer_sprites03.png
# Saving image img/FFRK_Dancer_sprites04.png
# Saving image img/FFRK_Dancer_sprites05.png
# Saving image img/FFRK_Dancer_sprites06.png
# Saving image img/FFRK_Dancer_sprites07.png
# Saving image img/FFRK_Dancer_sprites08.png
# Saving image img/FFRK_Dancer_sprites09.png
# Saving image img/FFRK_Dancer_sprites10.png
# Saving image img/FFRK_Dancer_sprites11.png
# Saving image img/FFRK_Dancer_sprites12.png
# Saving image img/FFRK_Dancer_sprites13.png
# Saving image img/FFRK_Dancer_sprites14.png
# Saving image img/FFRK_Dancer_sprites15.png
# Saving image img/FFRK_Dancer_sprites16.png
# Saving image img/FFRK_Dancer_sprites17.png
# Saving image img/FFRK_Dancer_sprites18.png
# Saving image img/FFRK_Geomancer_sprites01.png
# Saving image img/FFRK_Geomancer_sprites02.png
# Saving image img/FFRK_Geomancer_sprites03.png
# Saving image img/FFRK_Geomancer_sprites04.png
# Saving image img/FFRK_Geomancer_sprites05.png
# Saving image img/FFRK_Geomancer_sprites06.png
# Saving image img/FFRK_Geomancer_sprites07.png
# Saving image img/FFRK_Geomancer_sprites08.png
# Saving image img/FFRK_Geomancer_sprites09.png
# Saving image img/FFRK_Geomancer_sprites10.png
# Saving image img/FFRK_Geomancer_sprites11.png
# Saving image img/FFRK_Geomancer_sprites12.png
# Saving image img/FFRK_Geomancer_sprites13.png
# Saving image img/FFRK_Geomancer_sprites14.png
# Saving image img/FFRK_Geomancer_sprites15.png
# Saving image img/FFRK_Geomancer_sprites16.png
# Saving image img/FFRK_Geomancer_sprites17.png
# Saving image img/FFRK_Geomancer_sprites18.png
# Saving image img/FFRK_Sage_sprites01.png
# Saving image img/FFRK_Sage_sprites02.png
# Saving image img/FFRK_Sage_sprites03.png
# Saving image img/FFRK_Sage_sprites04.png
# Saving image img/FFRK_Sage_sprites05.png
# Saving image img/FFRK_Sage_sprites06.png
# Saving image img/FFRK_Sage_sprites07.png
# Saving image img/FFRK_Sage_sprites08.png
# Saving image img/FFRK_Sage_sprites09.png
# Saving image img/FFRK_Sage_sprites10.png
# Saving image img/FFRK_Sage_sprites11.png
# Saving image img/FFRK_Sage_sprites12.png
# Saving image img/FFRK_Sage_sprites13.png
# Saving image img/FFRK_Sage_sprites14.png
# Saving image img/FFRK_Sage_sprites15.png
# Saving image img/FFRK_Sage_sprites16.png
# Saving image img/FFRK_Sage_sprites17.png
# Saving image img/FFRK_Sage_sprites18.png
# Saving image img/FFRK_Time_Mage_sprites01.png
# Saving image img/FFRK_Time_Mage_sprites02.png
# Saving image img/FFRK_Time_Mage_sprites03.png
# Saving image img/FFRK_Time_Mage_sprites04.png
# Saving image img/FFRK_Time_Mage_sprites05.png
# Saving image img/FFRK_Time_Mage_sprites06.png
# Saving image img/FFRK_Time_Mage_sprites07.png
# Saving image img/FFRK_Time_Mage_sprites08.png
# Saving image img/FFRK_Time_Mage_sprites09.png
# Saving image img/FFRK_Time_Mage_sprites10.png
# Saving image img/FFRK_Time_Mage_sprites11.png
# Saving image img/FFRK_Time_Mage_sprites12.png
# Saving image img/FFRK_Time_Mage_sprites13.png
# Saving image img/FFRK_Time_Mage_sprites14.png
# Saving image img/FFRK_Time_Mage_sprites15.png
# Saving image img/FFRK_Time_Mage_sprites16.png
# Saving image img/FFRK_Time_Mage_sprites17.png
# Saving image img/FFRK_Time_Mage_sprites18.png

# %%
# copy any single 96x96 images from data folder to img folder
from shutil import copyfile

copy_from_path = data_folder
copy_to_path = img_folder

def copy_single_sprites(sprite_sheet_width=96, sprite_sheet_height=96):    
    for file in tqdm_notebook(os.listdir(copy_from_path)):
        if not file.endswith('.png'):
            continue
            
        # check size
        copy_img_from_path = os.path.join(copy_from_path, file)
        copy_img_to_path = os.path.join(copy_to_path, file)
        img = Image.open(copy_img_from_path)
        img_width, img_height = img.size

        if img_width == sprite_sheet_width and img_height == sprite_sheet_height:
            copyfile(copy_img_from_path, copy_img_to_path)

# %%
copy_single_sprites(96, 96)

# there will be duplicates 
# as some single image sprite 96x96 already included inside larger sprite sheets 576x288
# Out:
# HBox(children=(IntProgress(value=0, max=625), HTML(value='')))

# %%
# result analysis
# there are 272 large spitesheets 576x288, each with 18 smaller images 96x96 inside
# result is 4896 cropped images, all images size are 96x96

# also 4 larger spritesheets 480x96 = 5 smaller images in each spritesheet =result 20 images

# there are some single images 96x96 downloaded, not original in any large sprite sheet
# i just copied them from data folder to img folder

# there are a total of 5183 images extracted to img folder
# see if you already have enough data for the deep learning GAN model on part 3

# %%
# 2.4 detect and delete blank + mini character images
#   there are some blank image cropped from large spritesheet empty area - to delete
#   there are mini version of the characters cropped from large spritesheet - to delete

import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from tqdm import tqdm
from PIL import Image

# view blank image
def view_img(img_blank_path):
    img = Image.open(img_blank_path)
    plt.imshow(img)
    plt.show()
        
img_blank_path = 'img/FFRK_Ace_sprites15.png'
view_img(img_blank_path)
# file no longer exist if deleted

img_mini_character_path = 'img/FFRK_Adult_Rydia_sprites16.png'
view_img(img_mini_character_path)
# file no longer exist if deleted

# %%
# detect blank image, all black or all white
# Python PIL Detect if an image is completely black or white
#   https://stackoverflow.com/questions/14041562/python-pil-detect-if-an-image-is-completely-black-or-white

from PIL import ImageChops

def detect_black_img(img_path):
    img = Image.open(img_path)
    
    isblack = not img.getbbox()
    if isblack:
        print ('%s - Image is all black' % (img_path))
    return isblack
            
def detect_white_img(img_path):
    img = Image.open(img_path)
    
    iswhite = not ImageChops.invert(img).getbbox()
    if iswhite:
        print ('%s - Image is all white' % (img_path))
    return iswhite

def detect_empty_img(img_path):
    if detect_black_img(img_path) or detect_black_img(img_path):
        return True
    else:
        return False

# %%
# test detect an empty image
img_path = 'img/FFRK_Ace_sprites15.png'
detect_empty_img(img_path)
# Out:
# img/FFRK_Ace_sprites15.png - Image is all black
# True

# %%
# test detect a normal image
img_path = 'img/FFRK_Ace_sprites10.png'
detect_empty_img(img_path)
# Out:
# False

# %%
# test delete an image

img_path = 'img/FFRK_Ace_sprites11.png'
print ('before delete %s - file exist = %s' % (img_path, os.path.exists(img_path)))

os.remove(img_path)
print ('after delete %s - file exist = %s' % (img_path, os.path.exists(img_path)))
# Out:
# before delete img/FFRK_Ace_sprites11.png - file exist = True
# after delete img/FFRK_Ace_sprites11.png - file exist = False

# %%
# delete all blank images
def delete_all_blank_img(img_path):    
    for file in tqdm_notebook(os.listdir(img_path)):
        if not file.endswith('.png'):
            continue
            
        next_img_from_path = os.path.join(img_path, file)
        if detect_empty_img(next_img_from_path):
            print ('Deleting image %s' % (next_img_from_path))
            os.remove(next_img_from_path)

# %%
delete_all_blank_img(img_folder)
# Out:
# HBox(children=(IntProgress(value=0, max=5250), HTML(value='')))
# img/FFRK_Ace_sprites14.png - Image is all black
# Deleting image img/FFRK_Ace_sprites14.png
# img/FFRK_Ace_sprites15.png - Image is all black
# Deleting image img/FFRK_Ace_sprites15.png
# img/FFRK_Ace_sprites17.png - Image is all black
# Deleting image img/FFRK_Ace_sprites17.png
# img/FFRK_Ace_sprites18.png - Image is all black
# Deleting image img/FFRK_Ace_sprites18.png
# img/FFRK_Ace_sprites16.png - Image is all black
# Deleting image img/FFRK_Ace_sprites16.png
# img/FFRK_Alma_sprites18.png - Image is all black
# Deleting image img/FFRK_Alma_sprites18.png
# img/FFRK_Aranea_FFXV_sprites18.png - Image is all black
# Deleting image img/FFRK_Aranea_FFXV_sprites18.png
# img/FFRK_Aemo_sprites14.png - Image is all black
# Deleting image img/FFRK_Aemo_sprites14.png
# img/FFRK_Aemo_sprites15.png - Image is all black
# Deleting image img/FFRK_Aemo_sprites15.png
# img/FFRK_Aemo_sprites16.png - Image is all black
# Deleting image img/FFRK_Aemo_sprites16.png
# img/FFRK_Aemo_sprites17.png - Image is all black
# Deleting image img/FFRK_Aemo_sprites17.png
# img/FFRK_Aemo_sprites18.png - Image is all black
# Deleting image img/FFRK_Aemo_sprites18.png
# img/FFRK_Alma_sprites14.png - Image is all black
# Deleting image img/FFRK_Alma_sprites14.png
# img/FFRK_Alma_sprites15.png - Image is all black
# Deleting image img/FFRK_Alma_sprites15.png
# img/FFRK_Alma_sprites16.png - Image is all black
# Deleting image img/FFRK_Alma_sprites16.png
# img/FFRK_Alma_sprites17.png - Image is all black
# Deleting image img/FFRK_Alma_sprites17.png
# img/FFRK_Aphmau_sprites14.png - Image is all black
# Deleting image img/FFRK_Aphmau_sprites14.png
# img/FFRK_Aphmau_sprites15.png - Image is all black
# Deleting image img/FFRK_Aphmau_sprites15.png
# img/FFRK_Aphmau_sprites16.png - Image is all black
# Deleting image img/FFRK_Aphmau_sprites16.png
# img/FFRK_Aphmau_sprites17.png - Image is all black
# Deleting image img/FFRK_Aphmau_sprites17.png
# img/FFRK_Aphmau_sprites18.png - Image is all black
# Deleting image img/FFRK_Aphmau_sprites18.png
# img/FFRK_Aranea_FFXV_sprites14.png - Image is all black
# Deleting image img/FFRK_Aranea_FFXV_sprites14.png
# img/FFRK_Aranea_FFXV_sprites15.png - Image is all black
# Deleting image img/FFRK_Aranea_FFXV_sprites15.png
# img/FFRK_Aranea_FFXV_sprites16.png - Image is all black
# Deleting image img/FFRK_Aranea_FFXV_sprites16.png
# img/FFRK_Aranea_FFXV_sprites17.png - Image is all black
# Deleting image img/FFRK_Aranea_FFXV_sprites17.png
# img/FFRK_Aria_FFIII_sprites16.png - Image is all black
# Deleting image img/FFRK_Aria_FFIII_sprites16.png
# img/FFRK_Aria_FFIII_sprites17.png - Image is all black
# Deleting image img/FFRK_Aria_FFIII_sprites17.png
# img/FFRK_Aria_FFIII_sprites18.png - Image is all black
# Deleting image img/FFRK_Aria_FFIII_sprites18.png
# img/FFRK_Barbariccia_sprites14.png - Image is all black
# Deleting image img/FFRK_Barbariccia_sprites14.png
# img/FFRK_Barbariccia_sprites15.png - Image is all black
# Deleting image img/FFRK_Barbariccia_sprites15.png
# img/FFRK_Barbariccia_sprites17.png - Image is all black
# Deleting image img/FFRK_Barbariccia_sprites17.png
# img/FFRK_Barbariccia_sprites18.png - Image is all black
# Deleting image img/FFRK_Barbariccia_sprites18.png
# img/FFRK_Barbariccia_sprites16.png - Image is all black
# Deleting image img/FFRK_Barbariccia_sprites16.png
# img/FFRK_Aria_FFIII_sprites14.png - Image is all black
# Deleting image img/FFRK_Aria_FFIII_sprites14.png
# img/FFRK_Cecil_Paladin_DFF_sprites14.png - Image is all black
# Deleting image img/FFRK_Cecil_Paladin_DFF_sprites14.png
# img/FFRK_Cecil_Paladin_DFF_sprites16.png - Image is all black
# Deleting image img/FFRK_Cecil_Paladin_DFF_sprites16.png
# img/FFRK_Cecil_Paladin_DFF_sprites17.png - Image is all black
# Deleting image img/FFRK_Cecil_Paladin_DFF_sprites17.png
# img/FFRK_Cecil_Paladin_DFF_sprites18.png - Image is all black
# Deleting image img/FFRK_Cecil_Paladin_DFF_sprites18.png
# img/FFRK_Gladiolus_sprites14.png - Image is all black
# Deleting image img/FFRK_Gladiolus_sprites14.png
# img/FFRK_Gladiolus_sprites15.png - Image is all black
# Deleting image img/FFRK_Gladiolus_sprites15.png
# img/FFRK_Gladiolus_sprites16.png - Image is all black
# Deleting image img/FFRK_Gladiolus_sprites16.png
# img/FFRK_Gladiolus_sprites17.png - Image is all black
# Deleting image img/FFRK_Gladiolus_sprites17.png
# img/FFRK_Gladiolus_sprites18.png - Image is all black
# Deleting image img/FFRK_Gladiolus_sprites18.png
# img/FFRK_Cater_sprites14.png - Image is all black
# Deleting image img/FFRK_Cater_sprites14.png
# img/FFRK_Cater_sprites15.png - Image is all black
# Deleting image img/FFRK_Cater_sprites15.png
# img/FFRK_Cater_sprites16.png - Image is all black
# Deleting image img/FFRK_Cater_sprites16.png
# img/FFRK_Cater_sprites17.png - Image is all black
# Deleting image img/FFRK_Cater_sprites17.png
# img/FFRK_Cater_sprites18.png - Image is all black
# Deleting image img/FFRK_Cater_sprites18.png
# img/FFRK_Cecil_Paladin_DFF_sprites15.png - Image is all black
# Deleting image img/FFRK_Cecil_Paladin_DFF_sprites15.png
# img/FFRK_Ceodore_sprites14.png - Image is all black
# Deleting image img/FFRK_Ceodore_sprites14.png
# img/FFRK_Ceodore_sprites15.png - Image is all black
# Deleting image img/FFRK_Ceodore_sprites15.png
# img/FFRK_Ceodore_sprites16.png - Image is all black
# Deleting image img/FFRK_Ceodore_sprites16.png
# img/FFRK_Ceodore_sprites17.png - Image is all black
# Deleting image img/FFRK_Ceodore_sprites17.png
# img/FFRK_Ceodore_sprites18.png - Image is all black
# Deleting image img/FFRK_Ceodore_sprites18.png
# img/FFRK_Cid_nan_Garlond_sprites14.png - Image is all black
# Deleting image img/FFRK_Cid_nan_Garlond_sprites14.png
# img/FFRK_Cid_nan_Garlond_sprites15.png - Image is all black
# Deleting image img/FFRK_Cid_nan_Garlond_sprites15.png
# img/FFRK_Cid_nan_Garlond_sprites16.png - Image is all black
# Deleting image img/FFRK_Cid_nan_Garlond_sprites16.png
# img/FFRK_Cid_nan_Garlond_sprites17.png - Image is all black
# Deleting image img/FFRK_Cid_nan_Garlond_sprites17.png
# img/FFRK_Cid_nan_Garlond_sprites18.png - Image is all black
# Deleting image img/FFRK_Cid_nan_Garlond_sprites18.png
# img/FFRK_Cinque_sprites14.png - Image is all black
# Deleting image img/FFRK_Cinque_sprites14.png
# img/FFRK_Cinque_sprites15.png - Image is all black
# Deleting image img/FFRK_Cinque_sprites15.png
# img/FFRK_Cinque_sprites17.png - Image is all black
# Deleting image img/FFRK_Cinque_sprites17.png
# img/FFRK_Cinque_sprites18.png - Image is all black
# Deleting image img/FFRK_Cinque_sprites18.png
# img/FFRK_Cloud_(Festival)_sprites14.png - Image is all black
# Deleting image img/FFRK_Cloud_(Festival)_sprites14.png
# img/FFRK_Cloud_(Festival)_sprites15.png - Image is all black
# Deleting image img/FFRK_Cloud_(Festival)_sprites15.png
# img/FFRK_Cloud_(Festival)_sprites16.png - Image is all black
# Deleting image img/FFRK_Cloud_(Festival)_sprites16.png
# img/FFRK_Cloud_(Festival)_sprites17.png - Image is all black
# Deleting image img/FFRK_Cloud_(Festival)_sprites17.png
# img/FFRK_Cloud_(Festival)_sprites18.png - Image is all black
# Deleting image img/FFRK_Cloud_(Festival)_sprites18.png
# img/FFRK_Cloud_KH_sprites14.png - Image is all black
# Deleting image img/FFRK_Cloud_KH_sprites14.png
# img/FFRK_Cloud_KH_sprites15.png - Image is all black
# Deleting image img/FFRK_Cloud_KH_sprites15.png
# img/FFRK_Cloud_KH_sprites16.png - Image is all black
# Deleting image img/FFRK_Cloud_KH_sprites16.png
# img/FFRK_Cloud_KH_sprites17.png - Image is all black
# Deleting image img/FFRK_Cloud_KH_sprites17.png
# img/FFRK_Cloud_KH_sprites18.png - Image is all black
# Deleting image img/FFRK_Cloud_KH_sprites18.png
# img/FFRK_Cinque_sprites16.png - Image is all black
# Deleting image img/FFRK_Cinque_sprites16.png
# img/FFRK_Dancer_sprites08.png - Image is all black
# Deleting image img/FFRK_Dancer_sprites08.png
# img/FFRK_Aria_FFIII_sprites15.png - Image is all black
# Deleting image img/FFRK_Aria_FFIII_sprites15.png
# img/FFRK_Garnet_(Trance)_sprites18.png - Image is all black
# Deleting image img/FFRK_Garnet_(Trance)_sprites18.png
# img/FFRK_Palom_IVTAY_sprites16.png - Image is all black
# Deleting image img/FFRK_Palom_IVTAY_sprites16.png
# img/FFRK_Rude_sprites17.png - Image is all black
# Deleting image img/FFRK_Rude_sprites17.png
# img/FFRK_Dancer_sprites06.png - Image is all black
# Deleting image img/FFRK_Dancer_sprites06.png
# img/FFRK_Dancer_sprites07.png - Image is all black
# Deleting image img/FFRK_Dancer_sprites07.png
# img/FFRK_Delita_Holy_Knight_sprites14.png - Image is all black
# Deleting image img/FFRK_Delita_Holy_Knight_sprites14.png
# img/FFRK_Delita_Holy_Knight_sprites15.png - Image is all black
# Deleting image img/FFRK_Delita_Holy_Knight_sprites15.png
# img/FFRK_Delita_Holy_Knight_sprites16.png - Image is all black
# Deleting image img/FFRK_Delita_Holy_Knight_sprites16.png
# img/FFRK_Delita_Holy_Knight_sprites17.png - Image is all black
# Deleting image img/FFRK_Delita_Holy_Knight_sprites17.png
# img/FFRK_Deuce_sprites15.png - Image is all black
# Deleting image img/FFRK_Deuce_sprites15.png
# img/FFRK_Deuce_sprites16.png - Image is all black
# Deleting image img/FFRK_Deuce_sprites16.png
# img/FFRK_Deuce_sprites17.png - Image is all black
# Deleting image img/FFRK_Deuce_sprites17.png
# img/FFRK_Deuce_sprites18.png - Image is all black
# Deleting image img/FFRK_Deuce_sprites18.png
# img/FFRK_Dr._Mog_sprites14.png - Image is all black
# Deleting image img/FFRK_Dr._Mog_sprites14.png
# img/FFRK_Dr._Mog_sprites15.png - Image is all black
# Deleting image img/FFRK_Dr._Mog_sprites15.png
# img/FFRK_Dr._Mog_sprites16.png - Image is all black
# Deleting image img/FFRK_Dr._Mog_sprites16.png
# img/FFRK_Dr._Mog_sprites17.png - Image is all black
# Deleting image img/FFRK_Dr._Mog_sprites17.png
# img/FFRK_Dr._Mog_sprites18.png - Image is all black
# Deleting image img/FFRK_Dr._Mog_sprites18.png
# img/FFRK_Delita_Holy_Knight_sprites18.png - Image is all black
# Deleting image img/FFRK_Delita_Holy_Knight_sprites18.png
# img/FFRK_Deuce_sprites14.png - Image is all black
# Deleting image img/FFRK_Deuce_sprites14.png
# img/FFRK_Eight_sprites14.png - Image is all black
# Deleting image img/FFRK_Eight_sprites14.png
# img/FFRK_Eight_sprites15.png - Image is all black
# Deleting image img/FFRK_Eight_sprites15.png
# img/FFRK_Eight_sprites16.png - Image is all black
# Deleting image img/FFRK_Eight_sprites16.png
# img/FFRK_Eight_sprites17.png - Image is all black
# Deleting image img/FFRK_Eight_sprites17.png
# img/FFRK_Eight_sprites18.png - Image is all black
# Deleting image img/FFRK_Eight_sprites18.png
# img/FFRK_Eiko_(Trance)_sprites14.png - Image is all black
# Deleting image img/FFRK_Eiko_(Trance)_sprites14.png
# img/FFRK_Eiko_(Trance)_sprites15.png - Image is all black
# Deleting image img/FFRK_Eiko_(Trance)_sprites15.png
# img/FFRK_Eiko_(Trance)_sprites16.png - Image is all black
# Deleting image img/FFRK_Eiko_(Trance)_sprites16.png
# img/FFRK_Eiko_(Trance)_sprites17.png - Image is all black
# Deleting image img/FFRK_Eiko_(Trance)_sprites17.png
# img/FFRK_Eiko_(Trance)_sprites18.png - Image is all black
# Deleting image img/FFRK_Eiko_(Trance)_sprites18.png
# img/FFRK_Elarra_sprites14.png - Image is all black
# Deleting image img/FFRK_Elarra_sprites14.png
# img/FFRK_Elarra_sprites15.png - Image is all black
# Deleting image img/FFRK_Elarra_sprites15.png
# img/FFRK_Elarra_sprites16.png - Image is all black
# Deleting image img/FFRK_Elarra_sprites16.png
# img/FFRK_Elarra_sprites17.png - Image is all black
# Deleting image img/FFRK_Elarra_sprites17.png
# img/FFRK_Elena_sprites14.png - Image is all black
# Deleting image img/FFRK_Elena_sprites14.png
# img/FFRK_Elena_sprites15.png - Image is all black
# Deleting image img/FFRK_Elena_sprites15.png
# img/FFRK_Elena_sprites17.png - Image is all black
# Deleting image img/FFRK_Elena_sprites17.png
# img/FFRK_Elena_sprites18.png - Image is all black
# Deleting image img/FFRK_Elena_sprites18.png
# img/FFRK_Enna_Kros_sprites14.png - Image is all black
# Deleting image img/FFRK_Enna_Kros_sprites14.png
# img/FFRK_Enna_Kros_sprites15.png - Image is all black
# Deleting image img/FFRK_Enna_Kros_sprites15.png
# img/FFRK_Enna_Kros_sprites16.png - Image is all black
# Deleting image img/FFRK_Enna_Kros_sprites16.png
# img/FFRK_Enna_Kros_sprites17.png - Image is all black
# Deleting image img/FFRK_Enna_Kros_sprites17.png
# img/FFRK_Enna_Kros_sprites18.png - Image is all black
# Deleting image img/FFRK_Enna_Kros_sprites18.png
# img/FFRK_Estinien_sprites14.png - Image is all black
# Deleting image img/FFRK_Estinien_sprites14.png
# img/FFRK_Estinien_sprites15.png - Image is all black
# Deleting image img/FFRK_Estinien_sprites15.png
# img/FFRK_Estinien_sprites16.png - Image is all black
# Deleting image img/FFRK_Estinien_sprites16.png
# img/FFRK_Estinien_sprites17.png - Image is all black
# Deleting image img/FFRK_Estinien_sprites17.png
# img/FFRK_Estinien_sprites18.png - Image is all black
# Deleting image img/FFRK_Estinien_sprites18.png
# img/FFRK_Elarra_sprites18.png - Image is all black
# Deleting image img/FFRK_Elarra_sprites18.png
# img/FFRK_Elena_sprites16.png - Image is all black
# Deleting image img/FFRK_Elena_sprites16.png
# img/FFRK_Garnet_(Trance)_sprites14.png - Image is all black
# Deleting image img/FFRK_Garnet_(Trance)_sprites14.png
# img/FFRK_Garnet_(Trance)_sprites15.png - Image is all black
# Deleting image img/FFRK_Garnet_(Trance)_sprites15.png
# img/FFRK_Garnet_(Trance)_sprites16.png - Image is all black
# Deleting image img/FFRK_Garnet_(Trance)_sprites16.png
# img/FFRK_Garnet_(Trance)_sprites17.png - Image is all black
# Deleting image img/FFRK_Garnet_(Trance)_sprites17.png
# img/FFRK_Gogo_FFVI_sprites14.png - Image is all black
# Deleting image img/FFRK_Gogo_FFVI_sprites14.png
# img/FFRK_Gogo_FFVI_sprites15.png - Image is all black
# Deleting image img/FFRK_Gogo_FFVI_sprites15.png
# img/FFRK_Gogo_FFVI_sprites16.png - Image is all black
# Deleting image img/FFRK_Gogo_FFVI_sprites16.png
# img/FFRK_Gogo_FFVI_sprites17.png - Image is all black
# Deleting image img/FFRK_Gogo_FFVI_sprites17.png
# img/FFRK_Gogo_FFVI_sprites18.png - Image is all black
# Deleting image img/FFRK_Gogo_FFVI_sprites18.png
# img/FFRK_Haurchefant_sprites14.png - Image is all black
# Deleting image img/FFRK_Haurchefant_sprites14.png
# img/FFRK_Haurchefant_sprites15.png - Image is all black
# Deleting image img/FFRK_Haurchefant_sprites15.png
# img/FFRK_Haurchefant_sprites16.png - Image is all black
# Deleting image img/FFRK_Haurchefant_sprites16.png
# img/FFRK_Haurchefant_sprites17.png - Image is all black
# Deleting image img/FFRK_Haurchefant_sprites17.png
# img/FFRK_Haurchefant_sprites18.png - Image is all black
# Deleting image img/FFRK_Haurchefant_sprites18.png
# img/FFRK_Hilda_sprites14.png - Image is all black
# Deleting image img/FFRK_Hilda_sprites14.png
# img/FFRK_Hilda_sprites15.png - Image is all black
# Deleting image img/FFRK_Hilda_sprites15.png
# img/FFRK_Hilda_sprites16.png - Image is all black
# Deleting image img/FFRK_Hilda_sprites16.png
# img/FFRK_Hilda_sprites18.png - Image is all black
# Deleting image img/FFRK_Hilda_sprites18.png
# img/FFRK_Ignis_sprites14.png - Image is all black
# Deleting image img/FFRK_Ignis_sprites14.png
# img/FFRK_Ignis_sprites15.png - Image is all black
# Deleting image img/FFRK_Ignis_sprites15.png
# img/FFRK_Ignis_sprites16.png - Image is all black
# Deleting image img/FFRK_Ignis_sprites16.png
# img/FFRK_Ignis_sprites17.png - Image is all black
# Deleting image img/FFRK_Ignis_sprites17.png
# img/FFRK_Ignis_sprites18.png - Image is all black
# Deleting image img/FFRK_Ignis_sprites18.png
# img/FFRK_Iris_sprites14.png - Image is all black
# Deleting image img/FFRK_Iris_sprites14.png
# img/FFRK_Iris_sprites15.png - Image is all black
# Deleting image img/FFRK_Iris_sprites15.png
# img/FFRK_Iris_sprites16.png - Image is all black
# Deleting image img/FFRK_Iris_sprites16.png
# img/FFRK_Iris_sprites17.png - Image is all black
# Deleting image img/FFRK_Iris_sprites17.png
# img/FFRK_Iris_sprites18.png - Image is all black
# Deleting image img/FFRK_Iris_sprites18.png
# img/FFRK_Jack_T0_sprites14.png - Image is all black
# Deleting image img/FFRK_Jack_T0_sprites14.png
# img/FFRK_Jack_T0_sprites15.png - Image is all black
# Deleting image img/FFRK_Jack_T0_sprites15.png
# img/FFRK_Jack_T0_sprites16.png - Image is all black
# Deleting image img/FFRK_Jack_T0_sprites16.png
# img/FFRK_Jack_T0_sprites17.png - Image is all black
# Deleting image img/FFRK_Jack_T0_sprites17.png
# img/FFRK_Jack_T0_sprites18.png - Image is all black
# Deleting image img/FFRK_Jack_T0_sprites18.png
# img/FFRK_Kain_IVTAY_sprites14.png - Image is all black
# Deleting image img/FFRK_Kain_IVTAY_sprites14.png
# img/FFRK_Kain_IVTAY_sprites15.png - Image is all black
# Deleting image img/FFRK_Kain_IVTAY_sprites15.png
# img/FFRK_Kain_IVTAY_sprites16.png - Image is all black
# Deleting image img/FFRK_Kain_IVTAY_sprites16.png
# img/FFRK_Kain_IVTAY_sprites17.png - Image is all black
# Deleting image img/FFRK_Kain_IVTAY_sprites17.png
# img/FFRK_Kain_IVTAY_sprites18.png - Image is all black
# Deleting image img/FFRK_Kain_IVTAY_sprites18.png
# img/FFRK_Hilda_sprites17.png - Image is all black
# Deleting image img/FFRK_Hilda_sprites17.png
# img/FFRK_Kelger_sprites14.png - Image is all black
# Deleting image img/FFRK_Kelger_sprites14.png
# img/FFRK_Kelger_sprites15.png - Image is all black
# Deleting image img/FFRK_Kelger_sprites15.png
# img/FFRK_Kelger_sprites16.png - Image is all black
# Deleting image img/FFRK_Kelger_sprites16.png
# img/FFRK_Kelger_sprites17.png - Image is all black
# Deleting image img/FFRK_Kelger_sprites17.png
# img/FFRK_Kelger_sprites18.png - Image is all black
# Deleting image img/FFRK_Kelger_sprites18.png
# img/FFRK_King_sprites14.png - Image is all black
# Deleting image img/FFRK_King_sprites14.png
# img/FFRK_Kiros_sprites15.png - Image is all black
# Deleting image img/FFRK_Kiros_sprites15.png
# img/FFRK_Kiros_sprites16.png - Image is all black
# Deleting image img/FFRK_Kiros_sprites16.png
# img/FFRK_Kiros_sprites17.png - Image is all black
# Deleting image img/FFRK_Kiros_sprites17.png
# img/FFRK_Kiros_sprites18.png - Image is all black
# Deleting image img/FFRK_Kiros_sprites18.png
# img/FFRK_King_sprites15.png - Image is all black
# Deleting image img/FFRK_King_sprites15.png
# img/FFRK_Kiros_sprites14.png - Image is all black
# Deleting image img/FFRK_Kiros_sprites14.png
# img/FFRK_Machina_sprites14.png - Image is all black
# Deleting image img/FFRK_Machina_sprites14.png
# img/FFRK_Machina_sprites15.png - Image is all black
# Deleting image img/FFRK_Machina_sprites15.png
# img/FFRK_Machina_sprites16.png - Image is all black
# Deleting image img/FFRK_Machina_sprites16.png
# img/FFRK_Machina_sprites17.png - Image is all black
# Deleting image img/FFRK_Machina_sprites17.png
# img/FFRK_Machina_sprites18.png - Image is all black
# Deleting image img/FFRK_Machina_sprites18.png
# img/FFRK_Marche_sprites14.png - Image is all black
# Deleting image img/FFRK_Marche_sprites14.png
# img/FFRK_Marche_sprites15.png - Image is all black
# Deleting image img/FFRK_Marche_sprites15.png
# img/FFRK_Marche_sprites16.png - Image is all black
# Deleting image img/FFRK_Marche_sprites16.png
# img/FFRK_Marche_sprites17.png - Image is all black
# Deleting image img/FFRK_Marche_sprites17.png
# img/FFRK_Marcus_sprites14.png - Image is all black
# Deleting image img/FFRK_Marcus_sprites14.png
# img/FFRK_Marcus_sprites16.png - Image is all black
# Deleting image img/FFRK_Marcus_sprites16.png
# img/FFRK_Marcus_sprites17.png - Image is all black
# Deleting image img/FFRK_Marcus_sprites17.png
# img/FFRK_Marcus_sprites18.png - Image is all black
# Deleting image img/FFRK_Marcus_sprites18.png
# img/FFRK_Meia_sprites14.png - Image is all black
# Deleting image img/FFRK_Meia_sprites14.png
# img/FFRK_Meia_sprites15.png - Image is all black
# Deleting image img/FFRK_Meia_sprites15.png
# img/FFRK_Meia_sprites17.png - Image is all black
# Deleting image img/FFRK_Meia_sprites17.png
# img/FFRK_Meia_sprites18.png - Image is all black
# Deleting image img/FFRK_Meia_sprites18.png
# img/FFRK_Meliadoul_sprites14.png - Image is all black
# Deleting image img/FFRK_Meliadoul_sprites14.png
# img/FFRK_Meliadoul_sprites15.png - Image is all black
# Deleting image img/FFRK_Meliadoul_sprites15.png
# img/FFRK_Meliadoul_sprites16.png - Image is all black
# Deleting image img/FFRK_Meliadoul_sprites16.png
# img/FFRK_Meliadoul_sprites17.png - Image is all black
# Deleting image img/FFRK_Meliadoul_sprites17.png
# img/FFRK_Meliadoul_sprites18.png - Image is all black
# Deleting image img/FFRK_Meliadoul_sprites18.png
# img/FFRK_Marche_sprites18.png - Image is all black
# Deleting image img/FFRK_Marche_sprites18.png
# img/FFRK_Marcus_sprites15.png - Image is all black
# Deleting image img/FFRK_Marcus_sprites15.png
# img/FFRK_Meia_sprites16.png - Image is all black
# Deleting image img/FFRK_Meia_sprites16.png
# img/FFRK_Montblanc_sprites14.png - Image is all black
# Deleting image img/FFRK_Montblanc_sprites14.png
# img/FFRK_Montblanc_sprites16.png - Image is all black
# Deleting image img/FFRK_Montblanc_sprites16.png
# img/FFRK_Montblanc_sprites17.png - Image is all black
# Deleting image img/FFRK_Montblanc_sprites17.png
# img/FFRK_Montblanc_sprites18.png - Image is all black
# Deleting image img/FFRK_Montblanc_sprites18.png
# img/FFRK_Morrow_sprites14.png - Image is all black
# Deleting image img/FFRK_Morrow_sprites14.png
# img/FFRK_Morrow_sprites15.png - Image is all black
# Deleting image img/FFRK_Morrow_sprites15.png
# img/FFRK_Morrow_sprites16.png - Image is all black
# Deleting image img/FFRK_Morrow_sprites16.png
# img/FFRK_Morrow_sprites17.png - Image is all black
# Deleting image img/FFRK_Morrow_sprites17.png
# img/FFRK_Morrow_sprites18.png - Image is all black
# Deleting image img/FFRK_Morrow_sprites18.png
# img/FFRK_Nabaat_sprites14.png - Image is all black
# Deleting image img/FFRK_Nabaat_sprites14.png
# img/FFRK_Nabaat_sprites15.png - Image is all black
# Deleting image img/FFRK_Nabaat_sprites15.png
# img/FFRK_Nabaat_sprites16.png - Image is all black
# Deleting image img/FFRK_Nabaat_sprites16.png
# img/FFRK_Nabaat_sprites17.png - Image is all black
# Deleting image img/FFRK_Nabaat_sprites17.png
# img/FFRK_Nabaat_sprites18.png - Image is all black
# Deleting image img/FFRK_Nabaat_sprites18.png
# img/FFRK_Nine_sprites14.png - Image is all black
# Deleting image img/FFRK_Nine_sprites14.png
# img/FFRK_Nine_sprites15.png - Image is all black
# Deleting image img/FFRK_Nine_sprites15.png
# img/FFRK_Nine_sprites16.png - Image is all black
# Deleting image img/FFRK_Nine_sprites16.png
# img/FFRK_Nine_sprites17.png - Image is all black
# Deleting image img/FFRK_Nine_sprites17.png
# img/FFRK_Nine_sprites18.png - Image is all black
# Deleting image img/FFRK_Nine_sprites18.png
# img/FFRK_Noctis_sprites14.png - Image is all black
# Deleting image img/FFRK_Noctis_sprites14.png
# img/FFRK_Noctis_sprites15.png - Image is all black
# Deleting image img/FFRK_Noctis_sprites15.png
# img/FFRK_Noctis_sprites16.png - Image is all black
# Deleting image img/FFRK_Noctis_sprites16.png
# img/FFRK_Noctis_sprites17.png - Image is all black
# Deleting image img/FFRK_Noctis_sprites17.png
# img/FFRK_Orran_sprites14.png - Image is all black
# Deleting image img/FFRK_Orran_sprites14.png
# img/FFRK_Orran_sprites15.png - Image is all black
# Deleting image img/FFRK_Orran_sprites15.png
# img/FFRK_Orran_sprites16.png - Image is all black
# Deleting image img/FFRK_Orran_sprites16.png
# img/FFRK_Orran_sprites17.png - Image is all black
# Deleting image img/FFRK_Orran_sprites17.png
# img/FFRK_Orran_sprites18.png - Image is all black
# Deleting image img/FFRK_Orran_sprites18.png
# img/FFRK_Palom_IVTAY_sprites14.png - Image is all black
# Deleting image img/FFRK_Palom_IVTAY_sprites14.png
# img/FFRK_Palom_IVTAY_sprites15.png - Image is all black
# Deleting image img/FFRK_Palom_IVTAY_sprites15.png
# img/FFRK_Palom_IVTAY_sprites17.png - Image is all black
# Deleting image img/FFRK_Palom_IVTAY_sprites17.png
# img/FFRK_Palom_IVTAY_sprites18.png - Image is all black
# Deleting image img/FFRK_Palom_IVTAY_sprites18.png
# img/FFRK_Montblanc_sprites15.png - Image is all black
# Deleting image img/FFRK_Montblanc_sprites15.png
# img/FFRK_Noctis_sprites18.png - Image is all black
# Deleting image img/FFRK_Noctis_sprites18.png
# img/FFRK_Porom_IVTAY_sprites14.png - Image is all black
# Deleting image img/FFRK_Porom_IVTAY_sprites14.png
# img/FFRK_Porom_IVTAY_sprites15.png - Image is all black
# Deleting image img/FFRK_Porom_IVTAY_sprites15.png
# img/FFRK_Porom_IVTAY_sprites16.png - Image is all black
# Deleting image img/FFRK_Porom_IVTAY_sprites16.png
# img/FFRK_Porom_IVTAY_sprites17.png - Image is all black
# Deleting image img/FFRK_Porom_IVTAY_sprites17.png
# img/FFRK_Porom_IVTAY_sprites18.png - Image is all black
# Deleting image img/FFRK_Porom_IVTAY_sprites18.png
# img/FFRK_Princess_Sarisa_sprites14.png - Image is all black
# Deleting image img/FFRK_Princess_Sarisa_sprites14.png
# img/FFRK_Princess_Sarisa_sprites15.png - Image is all black
# Deleting image img/FFRK_Princess_Sarisa_sprites15.png
# img/FFRK_Princess_Sarisa_sprites16.png - Image is all black
# Deleting image img/FFRK_Princess_Sarisa_sprites16.png
# img/FFRK_Princess_Sarisa_sprites17.png - Image is all black
# Deleting image img/FFRK_Princess_Sarisa_sprites17.png
# img/FFRK_Princess_Sarisa_sprites18.png - Image is all black
# Deleting image img/FFRK_Princess_Sarisa_sprites18.png
# img/FFRK_Prompto_sprites14.png - Image is all black
# Deleting image img/FFRK_Prompto_sprites14.png
# img/FFRK_Prompto_sprites15.png - Image is all black
# Deleting image img/FFRK_Prompto_sprites15.png
# img/FFRK_Prompto_sprites16.png - Image is all black
# Deleting image img/FFRK_Prompto_sprites16.png
# img/FFRK_Prompto_sprites17.png - Image is all black
# Deleting image img/FFRK_Prompto_sprites17.png
# img/FFRK_Prompto_sprites18.png - Image is all black
# Deleting image img/FFRK_Prompto_sprites18.png
# img/FFRK_Queen_(updated)_sprites14.png - Image is all black
# Deleting image img/FFRK_Queen_(updated)_sprites14.png
# img/FFRK_Queen_(updated)_sprites15.png - Image is all black
# Deleting image img/FFRK_Queen_(updated)_sprites15.png
# img/FFRK_Queen_(updated)_sprites17.png - Image is all black
# Deleting image img/FFRK_Queen_(updated)_sprites17.png
# img/FFRK_Queen_(updated)_sprites18.png - Image is all black
# Deleting image img/FFRK_Queen_(updated)_sprites18.png
# img/FFRK_Queen_sprites14.png - Image is all black
# Deleting image img/FFRK_Queen_sprites14.png
# img/FFRK_Queen_sprites15.png - Image is all black
# Deleting image img/FFRK_Queen_sprites15.png
# img/FFRK_Queen_sprites16.png - Image is all black
# Deleting image img/FFRK_Queen_sprites16.png
# img/FFRK_Queen_sprites17.png - Image is all black
# Deleting image img/FFRK_Queen_sprites17.png
# img/FFRK_Queen_sprites18.png - Image is all black
# Deleting image img/FFRK_Queen_sprites18.png
# img/FFRK_Queen_(updated)_sprites16.png - Image is all black
# Deleting image img/FFRK_Queen_(updated)_sprites16.png
# img/FFRK_Ramza_Mercenary_sprites14.png - Image is all black
# Deleting image img/FFRK_Ramza_Mercenary_sprites14.png
# img/FFRK_Ramza_Mercenary_sprites15.png - Image is all black
# Deleting image img/FFRK_Ramza_Mercenary_sprites15.png
# img/FFRK_Ramza_Mercenary_sprites16.png - Image is all black
# Deleting image img/FFRK_Ramza_Mercenary_sprites16.png
# img/FFRK_Ramza_Mercenary_sprites17.png - Image is all black
# Deleting image img/FFRK_Ramza_Mercenary_sprites17.png
# img/FFRK_Ramza_Mercenary_sprites18.png - Image is all black
# Deleting image img/FFRK_Ramza_Mercenary_sprites18.png
# img/FFRK_Rapha_sprites14.png - Image is all black
# Deleting image img/FFRK_Rapha_sprites14.png
# img/FFRK_Rapha_sprites15.png - Image is all black
# Deleting image img/FFRK_Rapha_sprites15.png
# img/FFRK_Rapha_sprites16.png - Image is all black
# Deleting image img/FFRK_Rapha_sprites16.png
# img/FFRK_Rapha_sprites17.png - Image is all black
# Deleting image img/FFRK_Rapha_sprites17.png
# img/FFRK_Rapha_sprites18.png - Image is all black
# Deleting image img/FFRK_Rapha_sprites18.png
# img/FFRK_Reks_sprites14.png - Image is all black
# Deleting image img/FFRK_Reks_sprites14.png
# img/FFRK_Reks_sprites15.png - Image is all black
# Deleting image img/FFRK_Reks_sprites15.png
# img/FFRK_Reks_sprites16.png - Image is all black
# Deleting image img/FFRK_Reks_sprites16.png
# img/FFRK_Reks_sprites17.png - Image is all black
# Deleting image img/FFRK_Reks_sprites17.png
# img/FFRK_Reks_sprites18.png - Image is all black
# Deleting image img/FFRK_Reks_sprites18.png
# img/FFRK_Rem_sprites14.png - Image is all black
# Deleting image img/FFRK_Rem_sprites14.png
# img/FFRK_Rem_sprites15.png - Image is all black
# Deleting image img/FFRK_Rem_sprites15.png
# img/FFRK_Rem_sprites16.png - Image is all black
# Deleting image img/FFRK_Rem_sprites16.png
# img/FFRK_Rem_sprites17.png - Image is all black
# Deleting image img/FFRK_Rem_sprites17.png
# img/FFRK_Rem_sprites18.png - Image is all black
# Deleting image img/FFRK_Rem_sprites18.png
# img/FFRK_Rikku_Divesuit_sprites14.png - Image is all black
# Deleting image img/FFRK_Rikku_Divesuit_sprites14.png
# img/FFRK_Rikku_Divesuit_sprites15.png - Image is all black
# Deleting image img/FFRK_Rikku_Divesuit_sprites15.png
# img/FFRK_Rikku_Divesuit_sprites16.png - Image is all black
# Deleting image img/FFRK_Rikku_Divesuit_sprites16.png
# img/FFRK_Rikku_Divesuit_sprites17.png - Image is all black
# Deleting image img/FFRK_Rikku_Divesuit_sprites17.png
# img/FFRK_Rikku_Divesuit_sprites18.png - Image is all black
# Deleting image img/FFRK_Rikku_Divesuit_sprites18.png
# img/FFRK_Riku_sprites14.png - Image is all black
# Deleting image img/FFRK_Riku_sprites14.png
# img/FFRK_Riku_sprites16.png - Image is all black
# Deleting image img/FFRK_Riku_sprites16.png
# img/FFRK_Riku_sprites17.png - Image is all black
# Deleting image img/FFRK_Riku_sprites17.png
# img/FFRK_Riku_sprites18.png - Image is all black
# Deleting image img/FFRK_Riku_sprites18.png
# img/FFRK_Rinoa_Dress_sprites14.png - Image is all black
# Deleting image img/FFRK_Rinoa_Dress_sprites14.png
# img/FFRK_Rinoa_Dress_sprites15.png - Image is all black
# Deleting image img/FFRK_Rinoa_Dress_sprites15.png
# img/FFRK_Rinoa_Dress_sprites16.png - Image is all black
# Deleting image img/FFRK_Rinoa_Dress_sprites16.png
# img/FFRK_Rinoa_Dress_sprites17.png - Image is all black
# Deleting image img/FFRK_Rinoa_Dress_sprites17.png
# img/FFRK_Rinoa_Dress_sprites18.png - Image is all black
# Deleting image img/FFRK_Rinoa_Dress_sprites18.png
# img/FFRK_Rubicante_sprites14.png - Image is all black
# Deleting image img/FFRK_Rubicante_sprites14.png
# img/FFRK_Rubicante_sprites15.png - Image is all black
# Deleting image img/FFRK_Rubicante_sprites15.png
# img/FFRK_Rubicante_sprites16.png - Image is all black
# Deleting image img/FFRK_Rubicante_sprites16.png
# img/FFRK_Rubicante_sprites17.png - Image is all black
# Deleting image img/FFRK_Rubicante_sprites17.png
# img/FFRK_Rubicante_sprites18.png - Image is all black
# Deleting image img/FFRK_Rubicante_sprites18.png
# img/FFRK_Rude_sprites14.png - Image is all black
# Deleting image img/FFRK_Rude_sprites14.png
# img/FFRK_Rude_sprites15.png - Image is all black
# Deleting image img/FFRK_Rude_sprites15.png
# img/FFRK_Rude_sprites16.png - Image is all black
# Deleting image img/FFRK_Rude_sprites16.png
# img/FFRK_Rude_sprites18.png - Image is all black
# Deleting image img/FFRK_Rude_sprites18.png
# img/FFRK_Riku_sprites15.png - Image is all black
# Deleting image img/FFRK_Riku_sprites15.png
# img/FFRK_Sage_sprites06.png - Image is all black
# Deleting image img/FFRK_Sage_sprites06.png
# img/FFRK_Sage_sprites07.png - Image is all black
# Deleting image img/FFRK_Sage_sprites07.png
# img/FFRK_Sage_sprites08.png - Image is all black
# Deleting image img/FFRK_Sage_sprites08.png
# img/FFRK_Scott_sprites14.png - Image is all black
# Deleting image img/FFRK_Scott_sprites14.png
# img/FFRK_Scott_sprites15.png - Image is all black
# Deleting image img/FFRK_Scott_sprites15.png
# img/FFRK_Scott_sprites16.png - Image is all black
# Deleting image img/FFRK_Scott_sprites16.png
# img/FFRK_Scott_sprites18.png - Image is all black
# Deleting image img/FFRK_Scott_sprites18.png
# img/FFRK_Selphie_Garden_Uniform_sprites14.png - Image is all black
# Deleting image img/FFRK_Selphie_Garden_Uniform_sprites14.png
# img/FFRK_Selphie_Garden_Uniform_sprites15.png - Image is all black
# Deleting image img/FFRK_Selphie_Garden_Uniform_sprites15.png
# img/FFRK_Selphie_Garden_Uniform_sprites16.png - Image is all black
# Deleting image img/FFRK_Selphie_Garden_Uniform_sprites16.png
# img/FFRK_Selphie_Garden_Uniform_sprites17.png - Image is all black
# Deleting image img/FFRK_Selphie_Garden_Uniform_sprites17.png
# img/FFRK_Selphie_Garden_Uniform_sprites18.png - Image is all black
# Deleting image img/FFRK_Selphie_Garden_Uniform_sprites18.png
# img/FFRK_Sephiroth_Executioner_sprites14.png - Image is all black
# Deleting image img/FFRK_Sephiroth_Executioner_sprites14.png
# img/FFRK_Sephiroth_Executioner_sprites15.png - Image is all black
# Deleting image img/FFRK_Sephiroth_Executioner_sprites15.png
# img/FFRK_Sephiroth_Executioner_sprites16.png - Image is all black
# Deleting image img/FFRK_Sephiroth_Executioner_sprites16.png
# img/FFRK_Sephiroth_Executioner_sprites17.png - Image is all black
# Deleting image img/FFRK_Sephiroth_Executioner_sprites17.png
# img/FFRK_Sephiroth_Executioner_sprites18.png - Image is all black
# Deleting image img/FFRK_Sephiroth_Executioner_sprites18.png
# img/FFRK_Sage_sprites09.png - Image is all black
# Deleting image img/FFRK_Sage_sprites09.png
# img/FFRK_Scott_sprites17.png - Image is all black
# Deleting image img/FFRK_Scott_sprites17.png
# img/FFRK_Seven_sprites14.png - Image is all black
# Deleting image img/FFRK_Seven_sprites14.png
# img/FFRK_Shelke_sprites14.png - Image is all black
# Deleting image img/FFRK_Shelke_sprites14.png
# img/FFRK_Shelke_sprites15.png - Image is all black
# Deleting image img/FFRK_Shelke_sprites15.png
# img/FFRK_Shelke_sprites16.png - Image is all black
# Deleting image img/FFRK_Shelke_sprites16.png
# img/FFRK_Shelke_sprites17.png - Image is all black
# Deleting image img/FFRK_Shelke_sprites17.png
# img/FFRK_Shelke_sprites18.png - Image is all black
# Deleting image img/FFRK_Shelke_sprites18.png
# img/FFRK_Sice_sprites14.png - Image is all black
# Deleting image img/FFRK_Sice_sprites14.png
# img/FFRK_Sice_sprites15.png - Image is all black
# Deleting image img/FFRK_Sice_sprites15.png
# img/FFRK_Sice_sprites16.png - Image is all black
# Deleting image img/FFRK_Sice_sprites16.png
# img/FFRK_Sice_sprites17.png - Image is all black
# Deleting image img/FFRK_Sice_sprites17.png
# img/FFRK_Sice_sprites18.png - Image is all black
# Deleting image img/FFRK_Sice_sprites18.png
# img/FFRK_King_sprites16.png - Image is all black
# Deleting image img/FFRK_King_sprites16.png
# img/FFRK_King_sprites17.png - Image is all black
# Deleting image img/FFRK_King_sprites17.png
# img/FFRK_King_sprites18.png - Image is all black
# Deleting image img/FFRK_King_sprites18.png
# img/FFRK_Lilisette_sprites14.png - Image is all black
# Deleting image img/FFRK_Lilisette_sprites14.png
# img/FFRK_Lilisette_sprites15.png - Image is all black
# Deleting image img/FFRK_Lilisette_sprites15.png
# img/FFRK_Lilisette_sprites16.png - Image is all black
# Deleting image img/FFRK_Lilisette_sprites16.png
# img/FFRK_Lilisette_sprites17.png - Image is all black
# Deleting image img/FFRK_Lilisette_sprites17.png
# img/FFRK_Lilisette_sprites18.png - Image is all black
# Deleting image img/FFRK_Lilisette_sprites18.png
# img/FFRK_Marach_sprites14.png - Image is all black
# Deleting image img/FFRK_Marach_sprites14.png
# img/FFRK_Marach_sprites15.png - Image is all black
# Deleting image img/FFRK_Marach_sprites15.png
# img/FFRK_Marach_sprites16.png - Image is all black
# Deleting image img/FFRK_Marach_sprites16.png
# img/FFRK_Marach_sprites17.png - Image is all black
# Deleting image img/FFRK_Marach_sprites17.png
# img/FFRK_Marach_sprites18.png - Image is all black
# Deleting image img/FFRK_Marach_sprites18.png
# img/FFRK_Seven_sprites16.png - Image is all black
# Deleting image img/FFRK_Seven_sprites16.png
# img/FFRK_Seven_sprites17.png - Image is all black
# Deleting image img/FFRK_Seven_sprites17.png
# img/FFRK_Seven_sprites18.png - Image is all black
# Deleting image img/FFRK_Seven_sprites18.png
# img/FFRK_Sora_sprites14.png - Image is all black
# Deleting image img/FFRK_Sora_sprites14.png
# img/FFRK_Sora_sprites15.png - Image is all black
# Deleting image img/FFRK_Sora_sprites15.png
# img/FFRK_Sora_sprites16.png - Image is all black
# Deleting image img/FFRK_Sora_sprites16.png
# img/FFRK_Sora_sprites17.png - Image is all black
# Deleting image img/FFRK_Sora_sprites17.png
# img/FFRK_Sora_sprites18.png - Image is all black
# Deleting image img/FFRK_Sora_sprites18.png
# img/FFRK_Squall_KH_sprites14.png - Image is all black
# Deleting image img/FFRK_Squall_KH_sprites14.png
# img/FFRK_Squall_KH_sprites15.png - Image is all black
# Deleting image img/FFRK_Squall_KH_sprites15.png
# img/FFRK_Squall_KH_sprites16.png - Image is all black
# Deleting image img/FFRK_Squall_KH_sprites16.png
# img/FFRK_Squall_KH_sprites17.png - Image is all black
# Deleting image img/FFRK_Squall_KH_sprites17.png
# img/FFRK_Squall_KH_sprites18.png - Image is all black
# Deleting image img/FFRK_Squall_KH_sprites18.png
# img/FFRK_Seven_sprites15.png - Image is all black
# Deleting image img/FFRK_Seven_sprites15.png
# img/FFRK_Wrieg_sprites14.png - Image is all black
# Deleting image img/FFRK_Wrieg_sprites14.png
# img/FFRK_Wrieg_sprites15.png - Image is all black
# Deleting image img/FFRK_Wrieg_sprites15.png
# img/FFRK_Wrieg_sprites16.png - Image is all black
# Deleting image img/FFRK_Wrieg_sprites16.png
# img/FFRK_Wrieg_sprites17.png - Image is all black
# Deleting image img/FFRK_Wrieg_sprites17.png
# img/FFRK_Xezat_sprites14.png - Image is all black
# Deleting image img/FFRK_Xezat_sprites14.png
# img/FFRK_Squall_Garden_Uniform_sprites14.png - Image is all black
# Deleting image img/FFRK_Squall_Garden_Uniform_sprites14.png
# img/FFRK_Squall_Garden_Uniform_sprites15.png - Image is all black
# Deleting image img/FFRK_Squall_Garden_Uniform_sprites15.png
# img/FFRK_Squall_Garden_Uniform_sprites16.png - Image is all black
# Deleting image img/FFRK_Squall_Garden_Uniform_sprites16.png
# img/FFRK_Squall_Garden_Uniform_sprites17.png - Image is all black
# Deleting image img/FFRK_Squall_Garden_Uniform_sprites17.png
# img/FFRK_Squall_Garden_Uniform_sprites18.png - Image is all black
# Deleting image img/FFRK_Squall_Garden_Uniform_sprites18.png
# img/FFRK_Tama_sprites14.png - Image is all black
# Deleting image img/FFRK_Tama_sprites14.png
# img/FFRK_Tama_sprites15.png - Image is all black
# Deleting image img/FFRK_Tama_sprites15.png
# img/FFRK_Tama_sprites16.png - Image is all black
# Deleting image img/FFRK_Tama_sprites16.png
# img/FFRK_Tama_sprites17.png - Image is all black
# Deleting image img/FFRK_Tama_sprites17.png
# img/FFRK_Tama_sprites18.png - Image is all black
# Deleting image img/FFRK_Tama_sprites18.png
# img/FFRK_Terra_DFF_sprites14.png - Image is all black
# Deleting image img/FFRK_Terra_DFF_sprites14.png
# img/FFRK_Terra_DFF_sprites15.png - Image is all black
# Deleting image img/FFRK_Terra_DFF_sprites15.png
# img/FFRK_Terra_DFF_sprites16.png - Image is all black
# Deleting image img/FFRK_Terra_DFF_sprites16.png
# img/FFRK_Terra_DFF_sprites17.png - Image is all black
# Deleting image img/FFRK_Terra_DFF_sprites17.png
# img/FFRK_Terra_DFF_sprites18.png - Image is all black
# Deleting image img/FFRK_Terra_DFF_sprites18.png
# img/FFRK_Thief_FFI_sprites15.png - Image is all black
# Deleting image img/FFRK_Thief_FFI_sprites15.png
# img/FFRK_Thief_FFI_sprites14.png - Image is all black
# Deleting image img/FFRK_Thief_FFI_sprites14.png
# img/FFRK_Thief_FFI_sprites16.png - Image is all black
# Deleting image img/FFRK_Thief_FFI_sprites16.png
# img/FFRK_Thief_FFI_sprites17.png - Image is all black
# Deleting image img/FFRK_Thief_FFI_sprites17.png
# img/FFRK_Thief_FFI_sprites18.png - Image is all black
# Deleting image img/FFRK_Thief_FFI_sprites18.png
# img/FFRK_Time_Mage_sprites06.png - Image is all black
# Deleting image img/FFRK_Time_Mage_sprites06.png
# img/FFRK_Time_Mage_sprites07.png - Image is all black
# Deleting image img/FFRK_Time_Mage_sprites07.png
# img/FFRK_Time_Mage_sprites08.png - Image is all black
# Deleting image img/FFRK_Time_Mage_sprites08.png
# img/FFRK_Time_Mage_sprites09.png - Image is all black
# Deleting image img/FFRK_Time_Mage_sprites09.png
# img/FFRK_Time_Mage_sprites10.png - Image is all black
# Deleting image img/FFRK_Time_Mage_sprites10.png
# img/FFRK_Tyro_Black-Robed_Keeper_sprites14.png - Image is all black
# Deleting image img/FFRK_Tyro_Black-Robed_Keeper_sprites14.png
# img/FFRK_Tyro_Black-Robed_Keeper_sprites15.png - Image is all black
# Deleting image img/FFRK_Tyro_Black-Robed_Keeper_sprites15.png
# img/FFRK_Tyro_Black-Robed_Keeper_sprites16.png - Image is all black
# Deleting image img/FFRK_Tyro_Black-Robed_Keeper_sprites16.png
# img/FFRK_Tyro_Black-Robed_Keeper_sprites17.png - Image is all black
# Deleting image img/FFRK_Tyro_Black-Robed_Keeper_sprites17.png
# img/FFRK_Tyro_Black-Robed_Keeper_sprites18.png - Image is all black
# Deleting image img/FFRK_Tyro_Black-Robed_Keeper_sprites18.png
# img/FFRK_Ultimecia_sprites14.png - Image is all black
# Deleting image img/FFRK_Ultimecia_sprites14.png
# img/FFRK_Ultimecia_sprites15.png - Image is all black
# Deleting image img/FFRK_Ultimecia_sprites15.png
# img/FFRK_Ultimecia_sprites16.png - Image is all black
# Deleting image img/FFRK_Ultimecia_sprites16.png
# img/FFRK_Ultimecia_sprites17.png - Image is all black
# Deleting image img/FFRK_Ultimecia_sprites17.png
# img/FFRK_Ultimecia_sprites18.png - Image is all black
# Deleting image img/FFRK_Ultimecia_sprites18.png
# img/FFRK_Umaro_sprites14.png - Image is all black
# Deleting image img/FFRK_Umaro_sprites14.png
# img/FFRK_Umaro_sprites15.png - Image is all black
# Deleting image img/FFRK_Umaro_sprites15.png
# img/FFRK_Umaro_sprites17.png - Image is all black
# Deleting image img/FFRK_Umaro_sprites17.png
# img/FFRK_Umaro_sprites18.png - Image is all black
# Deleting image img/FFRK_Umaro_sprites18.png
# img/FFRK_Ursula_sprites15.png - Image is all black
# Deleting image img/FFRK_Ursula_sprites15.png
# img/FFRK_Ursula_sprites16.png - Image is all black
# Deleting image img/FFRK_Ursula_sprites16.png
# img/FFRK_Ursula_sprites17.png - Image is all black
# Deleting image img/FFRK_Ursula_sprites17.png
# img/FFRK_Ursula_sprites18.png - Image is all black
# Deleting image img/FFRK_Ursula_sprites18.png
# img/FFRK_Time_Mage_sprites11.png - Image is all black
# Deleting image img/FFRK_Time_Mage_sprites11.png
# img/FFRK_Umaro_sprites16.png - Image is all black
# Deleting image img/FFRK_Umaro_sprites16.png
# img/FFRK_Ursula_sprites14.png - Image is all black
# Deleting image img/FFRK_Ursula_sprites14.png
# img/FFRK_Ward_sprites14.png - Image is all black
# Deleting image img/FFRK_Ward_sprites14.png
# img/FFRK_Ward_sprites15.png - Image is all black
# Deleting image img/FFRK_Ward_sprites15.png
# img/FFRK_Ward_sprites16.png - Image is all black
# Deleting image img/FFRK_Ward_sprites16.png
# img/FFRK_Ward_sprites17.png - Image is all black
# Deleting image img/FFRK_Ward_sprites17.png
# img/FFRK_Warrior_of_Light_Classic_Red_sprites14.png - Image is all black
# Deleting image img/FFRK_Warrior_of_Light_Classic_Red_sprites14.png
# img/FFRK_Warrior_of_Light_Classic_Red_sprites15.png - Image is all black
# Deleting image img/FFRK_Warrior_of_Light_Classic_Red_sprites15.png
# img/FFRK_Warrior_of_Light_Classic_Red_sprites16.png - Image is all black
# Deleting image img/FFRK_Warrior_of_Light_Classic_Red_sprites16.png
# img/FFRK_Warrior_of_Light_Classic_Red_sprites17.png - Image is all black
# Deleting image img/FFRK_Warrior_of_Light_Classic_Red_sprites17.png
# img/FFRK_Warrior_of_Light_Classic_Red_sprites18.png - Image is all black
# Deleting image img/FFRK_Warrior_of_Light_Classic_Red_sprites18.png
# img/FFRK_Ward_sprites18.png - Image is all black
# Deleting image img/FFRK_Ward_sprites18.png
# img/FFRK_Yuna_(Swimsuit)_sprites14.png - Image is all black
# Deleting image img/FFRK_Yuna_(Swimsuit)_sprites14.png
# img/FFRK_Yuna_(Swimsuit)_sprites15.png - Image is all black
# Deleting image img/FFRK_Yuna_(Swimsuit)_sprites15.png
# img/FFRK_Yuna_(Swimsuit)_sprites16.png - Image is all black
# Deleting image img/FFRK_Yuna_(Swimsuit)_sprites16.png
# img/FFRK_Yuna_(Swimsuit)_sprites17.png - Image is all black
# Deleting image img/FFRK_Yuna_(Swimsuit)_sprites17.png
# img/FFRK_Yuna_(Swimsuit)_sprites18.png - Image is all black
# Deleting image img/FFRK_Yuna_(Swimsuit)_sprites18.png
# img/FFRK_Xezat_sprites16.png - Image is all black
# Deleting image img/FFRK_Xezat_sprites16.png
# img/FFRK_Xezat_sprites17.png - Image is all black
# Deleting image img/FFRK_Xezat_sprites17.png
# img/FFRK_Xezat_sprites18.png - Image is all black
# Deleting image img/FFRK_Xezat_sprites18.png
# img/FFRK_Ysayle_sprites14.png - Image is all black
# Deleting image img/FFRK_Ysayle_sprites14.png
# img/FFRK_Ysayle_sprites15.png - Image is all black
# Deleting image img/FFRK_Ysayle_sprites15.png
# img/FFRK_Ysayle_sprites17.png - Image is all black
# Deleting image img/FFRK_Ysayle_sprites17.png
# img/FFRK_Ysayle_sprites18.png - Image is all black
# Deleting image img/FFRK_Ysayle_sprites18.png
# img/FFRK_Wrieg_sprites18.png - Image is all black
# Deleting image img/FFRK_Wrieg_sprites18.png
# img/FFRK_Xezat_sprites15.png - Image is all black
# Deleting image img/FFRK_Xezat_sprites15.png
# img/FFRK_Ysayle_sprites16.png - Image is all black
# Deleting image img/FFRK_Ysayle_sprites16.png
# img/FFRK_Zell_Garden_Uniform_sprites18.png - Image is all black
# Deleting image img/FFRK_Zell_Garden_Uniform_sprites18.png
# img/FFRK_Zeid_sprites14.png - Image is all black
# Deleting image img/FFRK_Zeid_sprites14.png
# img/FFRK_Zeid_sprites15.png - Image is all black
# Deleting image img/FFRK_Zeid_sprites15.png
# img/FFRK_Zeid_sprites16.png - Image is all black
# Deleting image img/FFRK_Zeid_sprites16.png
# img/FFRK_Zeid_sprites17.png - Image is all black
# Deleting image img/FFRK_Zeid_sprites17.png
# img/FFRK_Zeid_sprites18.png - Image is all black
# Deleting image img/FFRK_Zeid_sprites18.png
# img/FFRK_Zell_Garden_Uniform_sprites14.png - Image is all black
# Deleting image img/FFRK_Zell_Garden_Uniform_sprites14.png
# img/FFRK_Zell_Garden_Uniform_sprites15.png - Image is all black
# Deleting image img/FFRK_Zell_Garden_Uniform_sprites15.png
# img/FFRK_Zell_Garden_Uniform_sprites16.png - Image is all black
# Deleting image img/FFRK_Zell_Garden_Uniform_sprites16.png
# img/FFRK_Zell_Garden_Uniform_sprites17.png - Image is all black
# Deleting image img/FFRK_Zell_Garden_Uniform_sprites17.png
# img/FFRK_Dancer_sprites09.png - Image is all black
# Deleting image img/FFRK_Dancer_sprites09.png
# img/FFRK_Dancer_sprites10.png - Image is all black
# Deleting image img/FFRK_Dancer_sprites10.png
# img/FFRK_Dancer_sprites11.png - Image is all black
# Deleting image img/FFRK_Dancer_sprites11.png
# img/FFRK_Dancer_sprites12.png - Image is all black
# Deleting image img/FFRK_Dancer_sprites12.png
# img/FFRK_Dancer_sprites13.png - Image is all black
# Deleting image img/FFRK_Dancer_sprites13.png
# img/FFRK_Dancer_sprites14.png - Image is all black
# Deleting image img/FFRK_Dancer_sprites14.png
# img/FFRK_Dancer_sprites15.png - Image is all black
# Deleting image img/FFRK_Dancer_sprites15.png
# img/FFRK_Dancer_sprites16.png - Image is all black
# Deleting image img/FFRK_Dancer_sprites16.png
# img/FFRK_Dancer_sprites17.png - Image is all black
# Deleting image img/FFRK_Dancer_sprites17.png
# img/FFRK_Dancer_sprites18.png - Image is all black
# Deleting image img/FFRK_Dancer_sprites18.png
# img/FFRK_Geomancer_sprites06.png - Image is all black
# Deleting image img/FFRK_Geomancer_sprites06.png
# img/FFRK_Geomancer_sprites07.png - Image is all black
# Deleting image img/FFRK_Geomancer_sprites07.png
# img/FFRK_Geomancer_sprites08.png - Image is all black
# Deleting image img/FFRK_Geomancer_sprites08.png
# img/FFRK_Geomancer_sprites09.png - Image is all black
# Deleting image img/FFRK_Geomancer_sprites09.png
# img/FFRK_Geomancer_sprites10.png - Image is all black
# Deleting image img/FFRK_Geomancer_sprites10.png
# img/FFRK_Geomancer_sprites11.png - Image is all black
# Deleting image img/FFRK_Geomancer_sprites11.png
# img/FFRK_Geomancer_sprites12.png - Image is all black
# Deleting image img/FFRK_Geomancer_sprites12.png
# img/FFRK_Geomancer_sprites13.png - Image is all black
# Deleting image img/FFRK_Geomancer_sprites13.png
# img/FFRK_Geomancer_sprites14.png - Image is all black
# Deleting image img/FFRK_Geomancer_sprites14.png
# img/FFRK_Geomancer_sprites15.png - Image is all black
# Deleting image img/FFRK_Geomancer_sprites15.png
# img/FFRK_Geomancer_sprites16.png - Image is all black
# Deleting image img/FFRK_Geomancer_sprites16.png
# img/FFRK_Geomancer_sprites17.png - Image is all black
# Deleting image img/FFRK_Geomancer_sprites17.png
# img/FFRK_Geomancer_sprites18.png - Image is all black
# Deleting image img/FFRK_Geomancer_sprites18.png
# img/FFRK_Sage_sprites10.png - Image is all black
# Deleting image img/FFRK_Sage_sprites10.png
# img/FFRK_Sage_sprites11.png - Image is all black
# Deleting image img/FFRK_Sage_sprites11.png
# img/FFRK_Sage_sprites12.png - Image is all black
# Deleting image img/FFRK_Sage_sprites12.png
# img/FFRK_Sage_sprites13.png - Image is all black
# Deleting image img/FFRK_Sage_sprites13.png
# img/FFRK_Sage_sprites14.png - Image is all black
# Deleting image img/FFRK_Sage_sprites14.png
# img/FFRK_Sage_sprites15.png - Image is all black
# Deleting image img/FFRK_Sage_sprites15.png
# img/FFRK_Sage_sprites16.png - Image is all black
# Deleting image img/FFRK_Sage_sprites16.png
# img/FFRK_Sage_sprites17.png - Image is all black
# Deleting image img/FFRK_Sage_sprites17.png
# img/FFRK_Sage_sprites18.png - Image is all black
# Deleting image img/FFRK_Sage_sprites18.png
# img/FFRK_Time_Mage_sprites12.png - Image is all black
# Deleting image img/FFRK_Time_Mage_sprites12.png
# img/FFRK_Time_Mage_sprites13.png - Image is all black
# Deleting image img/FFRK_Time_Mage_sprites13.png
# img/FFRK_Time_Mage_sprites14.png - Image is all black
# Deleting image img/FFRK_Time_Mage_sprites14.png
# img/FFRK_Time_Mage_sprites15.png - Image is all black
# Deleting image img/FFRK_Time_Mage_sprites15.png
# img/FFRK_Time_Mage_sprites16.png - Image is all black
# Deleting image img/FFRK_Time_Mage_sprites16.png
# img/FFRK_Time_Mage_sprites17.png - Image is all black
# Deleting image img/FFRK_Time_Mage_sprites17.png
# img/FFRK_Time_Mage_sprites18.png - Image is all black
# Deleting image img/FFRK_Time_Mage_sprites18.png

# %%
# 4763 images left after deleted blank images

# %%
# Delete mini character images

# view
img_small_character_paths = []
img_small_character_paths.append('img/FFRK_Adult_Rydia_sprites14.png')
img_small_character_paths.append('img/FFRK_Adult_Rydia_sprites15.png')
img_small_character_paths.append('img/FFRK_Adult_Rydia_sprites16.png')
img_small_character_paths.append('img/FFRK_Adult_Rydia_sprites17.png')

img_small_character_paths.append('img/FFRK_Aerith_sprites14.png')
img_small_character_paths.append('img/FFRK_Aerith_sprites15.png')
img_small_character_paths.append('img/FFRK_Aerith_sprites16.png')
img_small_character_paths.append('img/FFRK_Aerith_sprites17.png')

img_small_character_paths.append('img/FFRK_Terra_Esper_sprites14.png')
img_small_character_paths.append('img/FFRK_Terra_Esper_sprites15.png')
img_small_character_paths.append('img/FFRK_Terra_Esper_sprites16.png')
img_small_character_paths.append('img/FFRK_Terra_Esper_sprites17.png')

view_img(img_small_character_paths[0])
view_img(img_small_character_paths[4])
view_img(img_small_character_paths[8])

# %%
img_normal_character_paths = []
img_normal_character_paths.append('img/FFRK_Adult_Rydia_sprites04.png')
img_normal_character_paths.append('img/FFRK_Adult_Rydia_sprites05.png')
img_normal_character_paths.append('img/FFRK_Adult_Rydia_sprites06.png')
img_normal_character_paths.append('img/FFRK_Adult_Rydia_sprites07.png')

img_normal_character_paths.append('img/FFRK_Aerith_sprites04.png')
img_normal_character_paths.append('img/FFRK_Aerith_sprites05.png')
img_normal_character_paths.append('img/FFRK_Aerith_sprites06.png')
img_normal_character_paths.append('img/FFRK_Aerith_sprites07.png')

img_normal_character_paths.append('img/FFRK_Terra_Esper_sprites04.png')
img_normal_character_paths.append('img/FFRK_Terra_Esper_sprites05.png')
img_normal_character_paths.append('img/FFRK_Terra_Esper_sprites06.png')
img_normal_character_paths.append('img/FFRK_Terra_Esper_sprites07.png')

view_img(img_normal_character_paths[0])
view_img(img_normal_character_paths[4])
view_img(img_normal_character_paths[8])

# %%
import cv2
import numpy as np

def check_white_black_color_pixels(img_path):
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    num_white_pixel = np.sum(img == 255)
    num_black_pixel = np.sum(img == 0)
    
    img_no_black = img[img != 0]
    img_no_white_n_black = img_no_black[img_no_black != 255]
    num_color_pixel = len(img_no_white_n_black)
    
    # print ('white pixels=%d, black pixels=%d, color pixels=%d' % (num_white_pixel, num_black_pixel, num_color_pixel))

    return (num_white_pixel, num_black_pixel, num_color_pixel)

# %%
# check roughly how many white pixels in small character image
for i in range(len(img_small_character_paths)):
    print (check_white_black_color_pixels(img_small_character_paths[i]))
# Out:
# (2592, 5958, 666)
# (2592, 5886, 738)
# (2592, 5886, 738)
# (2592, 6021, 603)
# (2592, 5877, 747)
# (2592, 5805, 819)
# (2592, 5805, 819)
# (2592, 5994, 630)
# (2304, 6210, 702)
# (2304, 6156, 756)
# (2304, 6156, 756)
# (2304, 6273, 639)

# %%
# check roughly how many white pixels in norma; character image
for i in range(len(img_normal_character_paths)):
    print (check_white_black_color_pixels(img_normal_character_paths[i]))
# Out:
# (2304, 4599, 2313)
# (2304, 4617, 2295)
# (3384, 3672, 2160)
# (4104, 2673, 2439)
# (2304, 4707, 2205)
# (2304, 4680, 2232)
# (3168, 3609, 2439)
# (3888, 2907, 2421)
# (2304, 4464, 2448)
# (2304, 4671, 2241)
# (3168, 3843, 2205)
# (4032, 3087, 2097)

# %%
# if color pixels is less than 1000, assume it is a mini character image
# delete if less than 1000, captured most mini character images, but not all

def delete_all_mini_character_img(img_path): 
    
    min_color_pixels = 1000
    
    for file in tqdm_notebook(os.listdir(img_path)):
        if not file.endswith('.png'):
            continue
            
        next_img_from_path = os.path.join(img_path, file)
        
        _, _, color_pixels = check_white_black_color_pixels(next_img_from_path)
        if color_pixels < min_color_pixels:
            print ('Image have only %d pixels' % (color_pixels))
            print ('Deleting image %s' % (next_img_from_path))
            os.remove(next_img_from_path)

# %%
img_path = 'img'
delete_all_mini_character_img(img_path)
# Out:
# HBox(children=(IntProgress(value=0, max=4763), HTML(value='')))
# Image have only 684 pixels
# Deleting image img/FFRK_Jecht_sprites14.png
# Image have only 747 pixels
# Deleting image img/FFRK_Jecht_sprites15.png
# Image have only 747 pixels
# Deleting image img/FFRK_Jecht_sprites16.png
# Image have only 639 pixels
# Deleting image img/FFRK_Jecht_sprites17.png
# Image have only 729 pixels
# Deleting image img/FFRK_Jecht_sprites18.png
# Image have only 666 pixels
# Deleting image img/FFRK_Adult_Rydia_sprites14.png
# Image have only 738 pixels
# Deleting image img/FFRK_Adult_Rydia_sprites15.png
# Image have only 738 pixels
# Deleting image img/FFRK_Adult_Rydia_sprites16.png
# Image have only 603 pixels
# Deleting image img/FFRK_Adult_Rydia_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Adult_Rydia_sprites18.png
# Image have only 819 pixels
# Deleting image img/FFRK_Alphinaud_sprites15.png
# Image have only 747 pixels
# Deleting image img/FFRK_Aerith_sprites14.png
# Image have only 819 pixels
# Deleting image img/FFRK_Aerith_sprites15.png
# Image have only 819 pixels
# Deleting image img/FFRK_Aerith_sprites16.png
# Image have only 630 pixels
# Deleting image img/FFRK_Aerith_sprites17.png
# Image have only 756 pixels
# Deleting image img/FFRK_Aerith_sprites18.png
# Image have only 684 pixels
# Deleting image img/FFRK_Agrias_sprites14.png
# Image have only 729 pixels
# Deleting image img/FFRK_Agrias_sprites15.png
# Image have only 729 pixels
# Deleting image img/FFRK_Agrias_sprites16.png
# Image have only 621 pixels
# Deleting image img/FFRK_Agrias_sprites17.png
# Image have only 729 pixels
# Deleting image img/FFRK_Agrias_sprites18.png
# Image have only 747 pixels
# Deleting image img/FFRK_Alphinaud_sprites14.png
# Image have only 819 pixels
# Deleting image img/FFRK_Alphinaud_sprites16.png
# Image have only 684 pixels
# Deleting image img/FFRK_Alphinaud_sprites17.png
# Image have only 801 pixels
# Deleting image img/FFRK_Alphinaud_sprites18.png
# Image have only 774 pixels
# Deleting image img/FFRK_Amarant_sprites14.png
# Image have only 855 pixels
# Deleting image img/FFRK_Amarant_sprites15.png
# Image have only 855 pixels
# Deleting image img/FFRK_Amarant_sprites16.png
# Image have only 720 pixels
# Deleting image img/FFRK_Amarant_sprites17.png
# Image have only 837 pixels
# Deleting image img/FFRK_Amarant_sprites18.png
# Image have only 639 pixels
# Deleting image img/FFRK_Angeal_sprites14.png
# Image have only 720 pixels
# Deleting image img/FFRK_Angeal_sprites15.png
# Image have only 720 pixels
# Deleting image img/FFRK_Angeal_sprites16.png
# Image have only 603 pixels
# Deleting image img/FFRK_Angeal_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Angeal_sprites18.png
# Image have only 639 pixels
# Deleting image img/FFRK_Arc_White_Mage_sprites14.png
# Image have only 720 pixels
# Deleting image img/FFRK_Arc_White_Mage_sprites15.png
# Image have only 720 pixels
# Deleting image img/FFRK_Arc_White_Mage_sprites16.png
# Image have only 594 pixels
# Deleting image img/FFRK_Arc_White_Mage_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Arc_White_Mage_sprites18.png
# Image have only 648 pixels
# Deleting image img/FFRK_Ashe_sprites14.png
# Image have only 711 pixels
# Deleting image img/FFRK_Ashe_sprites15.png
# Image have only 711 pixels
# Deleting image img/FFRK_Ashe_sprites16.png
# Image have only 585 pixels
# Deleting image img/FFRK_Ashe_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Ashe_sprites18.png
# Image have only 639 pixels
# Deleting image img/FFRK_Auron_sprites14.png
# Image have only 720 pixels
# Deleting image img/FFRK_Auron_sprites15.png
# Image have only 720 pixels
# Deleting image img/FFRK_Auron_sprites16.png
# Image have only 594 pixels
# Deleting image img/FFRK_Auron_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Auron_sprites18.png
# Image have only 702 pixels
# Deleting image img/FFRK_Ayame_sprites14.png
# Image have only 774 pixels
# Deleting image img/FFRK_Ayame_sprites15.png
# Image have only 774 pixels
# Deleting image img/FFRK_Ayame_sprites16.png
# Image have only 657 pixels
# Deleting image img/FFRK_Ayame_sprites17.png
# Image have only 765 pixels
# Deleting image img/FFRK_Ayame_sprites18.png
# Image have only 630 pixels
# Deleting image img/FFRK_Balthier_sprites14.png
# Image have only 711 pixels
# Deleting image img/FFRK_Balthier_sprites15.png
# Image have only 711 pixels
# Deleting image img/FFRK_Balthier_sprites16.png
# Image have only 585 pixels
# Deleting image img/FFRK_Balthier_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Balthier_sprites18.png
# Image have only 639 pixels
# Deleting image img/FFRK_Bard_sprites14.png
# Image have only 720 pixels
# Deleting image img/FFRK_Bard_sprites15.png
# Image have only 720 pixels
# Deleting image img/FFRK_Bard_sprites16.png
# Image have only 594 pixels
# Deleting image img/FFRK_Bard_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Bard_sprites18.png
# Image have only 639 pixels
# Deleting image img/FFRK_Bartz_Freelancer_sprites14.png
# Image have only 720 pixels
# Deleting image img/FFRK_Bartz_Freelancer_sprites15.png
# Image have only 720 pixels
# Deleting image img/FFRK_Bartz_Freelancer_sprites16.png
# Image have only 594 pixels
# Deleting image img/FFRK_Bartz_Freelancer_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Bartz_Freelancer_sprites18.png
# Image have only 639 pixels
# Deleting image img/FFRK_Bartz_Knight_sprites14.png
# Image have only 720 pixels
# Deleting image img/FFRK_Bartz_Knight_sprites15.png
# Image have only 720 pixels
# Deleting image img/FFRK_Bartz_Knight_sprites16.png
# Image have only 594 pixels
# Deleting image img/FFRK_Bartz_Knight_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Bartz_Knight_sprites18.png
# Image have only 666 pixels
# Deleting image img/FFRK_Basch_sprites14.png
# Image have only 729 pixels
# Deleting image img/FFRK_Basch_sprites15.png
# Image have only 729 pixels
# Deleting image img/FFRK_Basch_sprites16.png
# Image have only 720 pixels
# Deleting image img/FFRK_Basch_sprites18.png
# Image have only 720 pixels
# Deleting image img/FFRK_Beastmaster_sprites15.png
# Image have only 720 pixels
# Deleting image img/FFRK_Beastmaster_sprites16.png
# Image have only 594 pixels
# Deleting image img/FFRK_Beastmaster_sprites17.png
# Image have only 684 pixels
# Deleting image img/FFRK_Beastmaster_sprites18.png
# Image have only 774 pixels
# Deleting image img/FFRK_Beatrix_sprites14.png
# Image have only 810 pixels
# Deleting image img/FFRK_Beatrix_sprites15.png
# Image have only 810 pixels
# Deleting image img/FFRK_Beatrix_sprites16.png
# Image have only 711 pixels
# Deleting image img/FFRK_Beatrix_sprites17.png
# Image have only 792 pixels
# Deleting image img/FFRK_Beatrix_sprites18.png
# Image have only 603 pixels
# Deleting image img/FFRK_Basch_sprites17.png
# Image have only 639 pixels
# Deleting image img/FFRK_Beastmaster_sprites14.png
# Image have only 621 pixels
# Deleting image img/FFRK_Barret_sprites14.png
# Image have only 711 pixels
# Deleting image img/FFRK_Barret_sprites15.png
# Image have only 711 pixels
# Deleting image img/FFRK_Barret_sprites16.png
# Image have only 585 pixels
# Deleting image img/FFRK_Barret_sprites17.png
# Image have only 675 pixels
# Deleting image img/FFRK_Barret_sprites18.png
# Image have only 675 pixels
# Deleting image img/FFRK_Berserker_sprites14.png
# Image have only 756 pixels
# Deleting image img/FFRK_Berserker_sprites15.png
# Image have only 756 pixels
# Deleting image img/FFRK_Berserker_sprites16.png
# Image have only 630 pixels
# Deleting image img/FFRK_Berserker_sprites17.png
# Image have only 720 pixels
# Deleting image img/FFRK_Berserker_sprites18.png
# Image have only 693 pixels
# Deleting image img/FFRK_Black_Mage_sprites14.png
# Image have only 783 pixels
# Deleting image img/FFRK_Black_Mage_sprites15.png
# Image have only 783 pixels
# Deleting image img/FFRK_Black_Mage_sprites16.png
# Image have only 675 pixels
# Deleting image img/FFRK_Black_Mage_sprites17.png
# Image have only 738 pixels
# Deleting image img/FFRK_Black_Mage_sprites18.png
# Image have only 900 pixels
# Deleting image img/FFRK_Fran_sprites14.png
# Image have only 927 pixels
# Deleting image img/FFRK_Fran_sprites15.png
# Image have only 927 pixels
# Deleting image img/FFRK_Fran_sprites16.png
# Image have only 774 pixels
# Deleting image img/FFRK_Fran_sprites17.png
# Image have only 891 pixels
# Deleting image img/FFRK_Fran_sprites18.png
# Image have only 729 pixels
# Deleting image img/FFRK_Garland_FFI_sprites14.png
# Image have only 810 pixels
# Deleting image img/FFRK_Garland_FFI_sprites15.png
# Image have only 810 pixels
# Deleting image img/FFRK_Garland_FFI_sprites16.png
# Image have only 693 pixels
# Deleting image img/FFRK_Garland_FFI_sprites17.png
# Image have only 783 pixels
# Deleting image img/FFRK_Garland_FFI_sprites18.png
# Image have only 639 pixels
# Deleting image img/FFRK_Blue_Mage_sprites14.png
# Image have only 720 pixels
# Deleting image img/FFRK_Blue_Mage_sprites15.png
# Image have only 594 pixels
# Deleting image img/FFRK_Blue_Mage_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Blue_Mage_sprites18.png
# Image have only 846 pixels
# Deleting image img/FFRK_Braska_sprites14.png
# Image have only 891 pixels
# Deleting image img/FFRK_Braska_sprites15.png
# Image have only 891 pixels
# Deleting image img/FFRK_Braska_sprites16.png
# Image have only 765 pixels
# Deleting image img/FFRK_Braska_sprites17.png
# Image have only 846 pixels
# Deleting image img/FFRK_Braska_sprites18.png
# Image have only 909 pixels
# Deleting image img/FFRK_Celes_Actress_sprites14.png
# Image have only 963 pixels
# Deleting image img/FFRK_Celes_Actress_sprites15.png
# Image have only 963 pixels
# Deleting image img/FFRK_Celes_Actress_sprites16.png
# Image have only 783 pixels
# Deleting image img/FFRK_Celes_Actress_sprites17.png
# Image have only 954 pixels
# Deleting image img/FFRK_Celes_Actress_sprites18.png
# Image have only 639 pixels
# Deleting image img/FFRK_Celes_sprites14.png
# Image have only 720 pixels
# Deleting image img/FFRK_Celes_sprites15.png
# Image have only 720 pixels
# Deleting image img/FFRK_Celes_sprites16.png
# Image have only 603 pixels
# Deleting image img/FFRK_Celes_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Celes_sprites18.png
# Image have only 720 pixels
# Deleting image img/FFRK_Blue_Mage_sprites16.png
# Image have only 783 pixels
# Deleting image img/FFRK_Cidolfus_Orlandeau_sprites15.png
# Image have only 648 pixels
# Deleting image img/FFRK_Child_Rydia_sprites14.png
# Image have only 729 pixels
# Deleting image img/FFRK_Child_Rydia_sprites15.png
# Image have only 729 pixels
# Deleting image img/FFRK_Child_Rydia_sprites16.png
# Image have only 603 pixels
# Deleting image img/FFRK_Child_Rydia_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Child_Rydia_sprites18.png
# Image have only 711 pixels
# Deleting image img/FFRK_Cidolfus_Orlandeau_sprites14.png
# Image have only 783 pixels
# Deleting image img/FFRK_Cidolfus_Orlandeau_sprites16.png
# Image have only 648 pixels
# Deleting image img/FFRK_Cidolfus_Orlandeau_sprites17.png
# Image have only 738 pixels
# Deleting image img/FFRK_Cidolfus_Orlandeau_sprites18.png
# Image have only 666 pixels
# Deleting image img/FFRK_Cid_Highwind_sprites14.png
# Image have only 747 pixels
# Deleting image img/FFRK_Cid_Highwind_sprites15.png
# Image have only 747 pixels
# Deleting image img/FFRK_Cid_Highwind_sprites16.png
# Image have only 630 pixels
# Deleting image img/FFRK_Cid_Highwind_sprites17.png
# Image have only 729 pixels
# Deleting image img/FFRK_Cid_Highwind_sprites18.png
# Image have only 630 pixels
# Deleting image img/FFRK_Cid_Pollendina_sprites14.png
# Image have only 711 pixels
# Deleting image img/FFRK_Cid_Pollendina_sprites15.png
# Image have only 711 pixels
# Deleting image img/FFRK_Cid_Pollendina_sprites16.png
# Image have only 585 pixels
# Deleting image img/FFRK_Cid_Pollendina_sprites17.png
# Image have only 675 pixels
# Deleting image img/FFRK_Cid_Pollendina_sprites18.png
# Image have only 639 pixels
# Deleting image img/FFRK_Cid_Raines_sprites14.png
# Image have only 720 pixels
# Deleting image img/FFRK_Cid_Raines_sprites15.png
# Image have only 720 pixels
# Deleting image img/FFRK_Cid_Raines_sprites16.png
# Image have only 594 pixels
# Deleting image img/FFRK_Cid_Raines_sprites17.png
# Image have only 684 pixels
# Deleting image img/FFRK_Cloud_FFVII_sprites14.png
# Image have only 765 pixels
# Deleting image img/FFRK_Cloud_FFVII_sprites15.png
# Image have only 765 pixels
# Deleting image img/FFRK_Cloud_FFVII_sprites16.png
# Image have only 639 pixels
# Deleting image img/FFRK_Cloud_FFVII_sprites17.png
# Image have only 738 pixels
# Deleting image img/FFRK_Cloud_FFVII_sprites18.png
# Image have only 819 pixels
# Deleting image img/FFRK_Cloud_of_Darkness_sprites14.png
# Image have only 855 pixels
# Deleting image img/FFRK_Cloud_of_Darkness_sprites15.png
# Image have only 855 pixels
# Deleting image img/FFRK_Cloud_of_Darkness_sprites16.png
# Image have only 720 pixels
# Deleting image img/FFRK_Cloud_of_Darkness_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Cid_Raines_sprites18.png
# Image have only 864 pixels
# Deleting image img/FFRK_Cloud_of_Darkness_sprites18.png
# Image have only 738 pixels
# Deleting image img/FFRK_Cloud_VIIAC_sprites15.png
# Image have only 684 pixels
# Deleting image img/FFRK_Faris_Freelancer_sprites14.png
# Image have only 657 pixels
# Deleting image img/FFRK_Cloud_VIIAC_sprites14.png
# Image have only 738 pixels
# Deleting image img/FFRK_Cloud_VIIAC_sprites16.png
# Image have only 612 pixels
# Deleting image img/FFRK_Cloud_VIIAC_sprites17.png
# Image have only 711 pixels
# Deleting image img/FFRK_Cloud_VIIAC_sprites18.png
# Image have only 693 pixels
# Deleting image img/FFRK_Curilla_sprites14.png
# Image have only 765 pixels
# Deleting image img/FFRK_Curilla_sprites15.png
# Image have only 765 pixels
# Deleting image img/FFRK_Curilla_sprites16.png
# Image have only 639 pixels
# Deleting image img/FFRK_Curilla_sprites17.png
# Image have only 747 pixels
# Deleting image img/FFRK_Curilla_sprites18.png
# Image have only 675 pixels
# Deleting image img/FFRK_Cyan_sprites14.png
# Image have only 729 pixels
# Deleting image img/FFRK_Cyan_sprites15.png
# Image have only 729 pixels
# Deleting image img/FFRK_Cyan_sprites16.png
# Image have only 612 pixels
# Deleting image img/FFRK_Cyan_sprites17.png
# Image have only 729 pixels
# Deleting image img/FFRK_Cyan_sprites18.png
# Image have only 648 pixels
# Deleting image img/FFRK_Dark_Knight_Cecil_sprites14.png
# Image have only 729 pixels
# Deleting image img/FFRK_Dark_Knight_Cecil_sprites15.png
# Image have only 729 pixels
# Deleting image img/FFRK_Dark_Knight_Cecil_sprites16.png
# Image have only 603 pixels
# Deleting image img/FFRK_Dark_Knight_Cecil_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Dark_Knight_Cecil_sprites18.png
# Image have only 657 pixels
# Deleting image img/FFRK_Desch_sprites14.png
# Image have only 738 pixels
# Deleting image img/FFRK_Desch_sprites15.png
# Image have only 612 pixels
# Deleting image img/FFRK_Desch_sprites17.png
# Image have only 711 pixels
# Deleting image img/FFRK_Desch_sprites18.png
# Image have only 684 pixels
# Deleting image img/FFRK_Devout_sprites14.png
# Image have only 765 pixels
# Deleting image img/FFRK_Devout_sprites15.png
# Image have only 765 pixels
# Deleting image img/FFRK_Devout_sprites16.png
# Image have only 639 pixels
# Deleting image img/FFRK_Devout_sprites17.png
# Image have only 729 pixels
# Deleting image img/FFRK_Devout_sprites18.png
# Image have only 693 pixels
# Deleting image img/FFRK_Dorgann_sprites14.png
# Image have only 747 pixels
# Deleting image img/FFRK_Dorgann_sprites15.png
# Image have only 747 pixels
# Deleting image img/FFRK_Dorgann_sprites16.png
# Image have only 621 pixels
# Deleting image img/FFRK_Dorgann_sprites17.png
# Image have only 738 pixels
# Deleting image img/FFRK_Dorgann_sprites18.png
# Image have only 693 pixels
# Deleting image img/FFRK_Dragoon_sprites14.png
# Image have only 774 pixels
# Deleting image img/FFRK_Dragoon_sprites15.png
# Image have only 774 pixels
# Deleting image img/FFRK_Dragoon_sprites16.png
# Image have only 648 pixels
# Deleting image img/FFRK_Dragoon_sprites17.png
# Image have only 738 pixels
# Deleting image img/FFRK_Dragoon_sprites18.png
# Image have only 837 pixels
# Deleting image img/FFRK_Echo_sprites14.png
# Image have only 909 pixels
# Deleting image img/FFRK_Echo_sprites15.png
# Image have only 909 pixels
# Deleting image img/FFRK_Echo_sprites16.png
# Image have only 774 pixels
# Deleting image img/FFRK_Echo_sprites17.png
# Image have only 864 pixels
# Deleting image img/FFRK_Echo_sprites18.png
# Image have only 738 pixels
# Deleting image img/FFRK_Desch_sprites16.png
# Image have only 729 pixels
# Deleting image img/FFRK_Edea_sprites18.png
# Image have only 738 pixels
# Deleting image img/FFRK_Edgar_sprites16.png
# Image have only 333 pixels
# Deleting image img/FFRK_Edge_sprites14.png
# Image have only 675 pixels
# Deleting image img/FFRK_Edea_sprites14.png
# Image have only 756 pixels
# Deleting image img/FFRK_Edea_sprites15.png
# Image have only 756 pixels
# Deleting image img/FFRK_Edea_sprites16.png
# Image have only 630 pixels
# Deleting image img/FFRK_Edea_sprites17.png
# Image have only 666 pixels
# Deleting image img/FFRK_Edgar_sprites14.png
# Image have only 738 pixels
# Deleting image img/FFRK_Edgar_sprites15.png
# Image have only 612 pixels
# Deleting image img/FFRK_Edgar_sprites17.png
# Image have only 702 pixels
# Deleting image img/FFRK_Edgar_sprites18.png
# Image have only 378 pixels
# Deleting image img/FFRK_Edge_sprites15.png
# Image have only 378 pixels
# Deleting image img/FFRK_Edge_sprites16.png
# Image have only 324 pixels
# Deleting image img/FFRK_Edge_sprites17.png
# Image have only 369 pixels
# Deleting image img/FFRK_Edge_sprites18.png
# Image have only 666 pixels
# Deleting image img/FFRK_Edward_sprites14.png
# Image have only 729 pixels
# Deleting image img/FFRK_Edward_sprites15.png
# Image have only 729 pixels
# Deleting image img/FFRK_Edward_sprites16.png
# Image have only 603 pixels
# Deleting image img/FFRK_Edward_sprites17.png
# Image have only 702 pixels
# Deleting image img/FFRK_Edward_sprites18.png
# Image have only 684 pixels
# Deleting image img/FFRK_Eiko_sprites14.png
# Image have only 765 pixels
# Deleting image img/FFRK_Eiko_sprites15.png
# Image have only 765 pixels
# Deleting image img/FFRK_Eiko_sprites16.png
# Image have only 639 pixels
# Deleting image img/FFRK_Eiko_sprites17.png
# Image have only 738 pixels
# Deleting image img/FFRK_Eiko_sprites18.png
# Image have only 774 pixels
# Deleting image img/FFRK_Emperor_Mateus_sprites14.png
# Image have only 810 pixels
# Deleting image img/FFRK_Emperor_Mateus_sprites15.png
# Image have only 810 pixels
# Deleting image img/FFRK_Emperor_Mateus_sprites16.png
# Image have only 684 pixels
# Deleting image img/FFRK_Emperor_Mateus_sprites17.png
# Image have only 819 pixels
# Deleting image img/FFRK_Emperor_Mateus_sprites18.png
# Image have only 666 pixels
# Deleting image img/FFRK_Evoker_sprites14.png
# Image have only 747 pixels
# Deleting image img/FFRK_Evoker_sprites15.png
# Image have only 747 pixels
# Deleting image img/FFRK_Evoker_sprites16.png
# Image have only 621 pixels
# Deleting image img/FFRK_Evoker_sprites17.png
# Image have only 729 pixels
# Deleting image img/FFRK_Evoker_sprites18.png
# Image have only 639 pixels
# Deleting image img/FFRK_Fang_sprites17.png
# Image have only 765 pixels
# Deleting image img/FFRK_Exdeath_sprites14.png
# Image have only 846 pixels
# Deleting image img/FFRK_Exdeath_sprites15.png
# Image have only 846 pixels
# Deleting image img/FFRK_Exdeath_sprites16.png
# Image have only 657 pixels
# Deleting image img/FFRK_Exdeath_sprites17.png
# Image have only 756 pixels
# Deleting image img/FFRK_Exdeath_sprites18.png
# Image have only 675 pixels
# Deleting image img/FFRK_Fang_sprites14.png
# Image have only 738 pixels
# Deleting image img/FFRK_Fang_sprites15.png
# Image have only 738 pixels
# Deleting image img/FFRK_Fang_sprites16.png
# Image have only 756 pixels
# Deleting image img/FFRK_Fang_sprites18.png
# Image have only 729 pixels
# Deleting image img/FFRK_Faris_Freelancer_sprites15.png
# Image have only 729 pixels
# Deleting image img/FFRK_Faris_Freelancer_sprites16.png
# Image have only 621 pixels
# Deleting image img/FFRK_Faris_Freelancer_sprites17.png
# Image have only 684 pixels
# Deleting image img/FFRK_Faris_Freelancer_sprites18.png
# Image have only 693 pixels
# Deleting image img/FFRK_Faris_Summoner_sprites14.png
# Image have only 738 pixels
# Deleting image img/FFRK_Faris_Summoner_sprites15.png
# Image have only 738 pixels
# Deleting image img/FFRK_Faris_Summoner_sprites16.png
# Image have only 630 pixels
# Deleting image img/FFRK_Faris_Summoner_sprites17.png
# Image have only 738 pixels
# Deleting image img/FFRK_Faris_Summoner_sprites18.png
# Image have only 666 pixels
# Deleting image img/FFRK_Firion_sprites14.png
# Image have only 729 pixels
# Deleting image img/FFRK_Firion_sprites15.png
# Image have only 729 pixels
# Deleting image img/FFRK_Firion_sprites16.png
# Image have only 648 pixels
# Deleting image img/FFRK_Firion_sprites17.png
# Image have only 729 pixels
# Deleting image img/FFRK_Firion_sprites18.png
# Image have only 738 pixels
# Deleting image img/FFRK_Freya_sprites14.png
# Image have only 792 pixels
# Deleting image img/FFRK_Freya_sprites15.png
# Image have only 792 pixels
# Deleting image img/FFRK_Freya_sprites16.png
# Image have only 693 pixels
# Deleting image img/FFRK_Freya_sprites17.png
# Image have only 783 pixels
# Deleting image img/FFRK_Freya_sprites18.png
# Image have only 648 pixels
# Deleting image img/FFRK_Fujin_FFVIII_sprites14.png
# Image have only 729 pixels
# Deleting image img/FFRK_Fujin_FFVIII_sprites15.png
# Image have only 729 pixels
# Deleting image img/FFRK_Fujin_FFVIII_sprites16.png
# Image have only 603 pixels
# Deleting image img/FFRK_Fujin_FFVIII_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Fujin_FFVIII_sprites18.png
# Image have only 657 pixels
# Deleting image img/FFRK_Fusoya_sprites14.png
# Image have only 711 pixels
# Deleting image img/FFRK_Fusoya_sprites15.png
# Image have only 711 pixels
# Deleting image img/FFRK_Fusoya_sprites16.png
# Image have only 603 pixels
# Deleting image img/FFRK_Fusoya_sprites17.png
# Image have only 711 pixels
# Deleting image img/FFRK_Gabranth_sprites14.png
# Image have only 783 pixels
# Deleting image img/FFRK_Gabranth_sprites16.png
# Image have only 666 pixels
# Deleting image img/FFRK_Gabranth_sprites17.png
# Image have only 756 pixels
# Deleting image img/FFRK_Gabranth_sprites18.png
# Image have only 648 pixels
# Deleting image img/FFRK_Gaffgarion_sprites14.png
# Image have only 729 pixels
# Deleting image img/FFRK_Gaffgarion_sprites15.png
# Image have only 729 pixels
# Deleting image img/FFRK_Gaffgarion_sprites16.png
# Image have only 612 pixels
# Deleting image img/FFRK_Gaffgarion_sprites17.png
# Image have only 702 pixels
# Deleting image img/FFRK_Gaffgarion_sprites18.png
# Image have only 648 pixels
# Deleting image img/FFRK_Galuf_Freelancer_sprites14.png
# Image have only 720 pixels
# Deleting image img/FFRK_Galuf_Freelancer_sprites15.png
# Image have only 720 pixels
# Deleting image img/FFRK_Galuf_Freelancer_sprites16.png
# Image have only 594 pixels
# Deleting image img/FFRK_Galuf_Freelancer_sprites17.png
# Image have only 702 pixels
# Deleting image img/FFRK_Galuf_Freelancer_sprites18.png
# Image have only 648 pixels
# Deleting image img/FFRK_Galuf_Monk_sprites14.png
# Image have only 720 pixels
# Deleting image img/FFRK_Galuf_Monk_sprites15.png
# Image have only 720 pixels
# Deleting image img/FFRK_Galuf_Monk_sprites16.png
# Image have only 594 pixels
# Deleting image img/FFRK_Galuf_Monk_sprites17.png
# Image have only 702 pixels
# Deleting image img/FFRK_Galuf_Monk_sprites18.png
# Image have only 738 pixels
# Deleting image img/FFRK_Fusoya_sprites18.png
# Image have only 783 pixels
# Deleting image img/FFRK_Gabranth_sprites15.png
# Image have only 639 pixels
# Deleting image img/FFRK_Garnet_Show_of_Resolve_sprites14.png
# Image have only 711 pixels
# Deleting image img/FFRK_Garnet_Show_of_Resolve_sprites15.png
# Image have only 711 pixels
# Deleting image img/FFRK_Garnet_Show_of_Resolve_sprites16.png
# Image have only 594 pixels
# Deleting image img/FFRK_Garnet_Show_of_Resolve_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Garnet_Show_of_Resolve_sprites18.png
# Image have only 693 pixels
# Deleting image img/FFRK_Garnet_sprites14.png
# Image have only 756 pixels
# Deleting image img/FFRK_Garnet_sprites15.png
# Image have only 756 pixels
# Deleting image img/FFRK_Garnet_sprites16.png
# Image have only 621 pixels
# Deleting image img/FFRK_Garnet_sprites17.png
# Image have only 729 pixels
# Deleting image img/FFRK_Garnet_sprites18.png
# Image have only 792 pixels
# Deleting image img/FFRK_Gau_sprites14.png
# Image have only 864 pixels
# Deleting image img/FFRK_Gau_sprites15.png
# Image have only 864 pixels
# Deleting image img/FFRK_Gau_sprites16.png
# Image have only 738 pixels
# Deleting image img/FFRK_Gau_sprites17.png
# Image have only 864 pixels
# Deleting image img/FFRK_Gau_sprites18.png
# Image have only 738 pixels
# Deleting image img/FFRK_Gilgamesh_sprites14.png
# Image have only 801 pixels
# Deleting image img/FFRK_Gilgamesh_sprites15.png
# Image have only 801 pixels
# Deleting image img/FFRK_Gilgamesh_sprites16.png
# Image have only 666 pixels
# Deleting image img/FFRK_Gilgamesh_sprites17.png
# Image have only 756 pixels
# Deleting image img/FFRK_Gilgamesh_sprites18.png
# Image have only 882 pixels
# Deleting image img/FFRK_Gladiator_sprites14.png
# Image have only 945 pixels
# Deleting image img/FFRK_Gladiator_sprites15.png
# Image have only 945 pixels
# Deleting image img/FFRK_Gladiator_sprites16.png
# Image have only 801 pixels
# Deleting image img/FFRK_Gladiator_sprites17.png
# Image have only 954 pixels
# Deleting image img/FFRK_Gladiator_sprites18.png
# Image have only 792 pixels
# Deleting image img/FFRK_Gogo_FFV_sprites14.png
# Image have only 873 pixels
# Deleting image img/FFRK_Gogo_FFV_sprites16.png
# Image have only 729 pixels
# Deleting image img/FFRK_Gogo_FFV_sprites17.png
# Image have only 846 pixels
# Deleting image img/FFRK_Gogo_FFV_sprites18.png
# Image have only 711 pixels
# Deleting image img/FFRK_Golbez_sprites14.png
# Image have only 792 pixels
# Deleting image img/FFRK_Golbez_sprites15.png
# Image have only 792 pixels
# Deleting image img/FFRK_Golbez_sprites16.png
# Image have only 666 pixels
# Deleting image img/FFRK_Golbez_sprites17.png
# Image have only 756 pixels
# Deleting image img/FFRK_Golbez_sprites18.png
# Image have only 684 pixels
# Deleting image img/FFRK_Gordon_sprites14.png
# Image have only 738 pixels
# Deleting image img/FFRK_Gordon_sprites15.png
# Image have only 738 pixels
# Deleting image img/FFRK_Gordon_sprites16.png
# Image have only 621 pixels
# Deleting image img/FFRK_Gordon_sprites17.png
# Image have only 729 pixels
# Deleting image img/FFRK_Gordon_sprites18.png
# Image have only 612 pixels
# Deleting image img/FFRK_Guy_sprites14.png
# Image have only 693 pixels
# Deleting image img/FFRK_Guy_sprites15.png
# Image have only 693 pixels
# Deleting image img/FFRK_Guy_sprites16.png
# Image have only 585 pixels
# Deleting image img/FFRK_Guy_sprites17.png
# Image have only 675 pixels
# Deleting image img/FFRK_Guy_sprites18.png
# Image have only 873 pixels
# Deleting image img/FFRK_Gogo_FFV_sprites15.png
# Image have only 657 pixels
# Deleting image img/FFRK_Hope_sprites14.png
# Image have only 738 pixels
# Deleting image img/FFRK_Hope_sprites16.png
# Image have only 612 pixels
# Deleting image img/FFRK_Hope_sprites17.png
# Image have only 702 pixels
# Deleting image img/FFRK_Hope_sprites18.png
# Image have only 648 pixels
# Deleting image img/FFRK_Hope_XIII2_sprites14.png
# Image have only 729 pixels
# Deleting image img/FFRK_Hope_XIII2_sprites15.png
# Image have only 729 pixels
# Deleting image img/FFRK_Hope_XIII2_sprites16.png
# Image have only 603 pixels
# Deleting image img/FFRK_Hope_XIII2_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Hope_XIII2_sprites18.png
# Image have only 801 pixels
# Deleting image img/FFRK_Ingus_Knight_sprites14.png
# Image have only 882 pixels
# Deleting image img/FFRK_Ingus_Knight_sprites15.png
# Image have only 882 pixels
# Deleting image img/FFRK_Ingus_Knight_sprites16.png
# Image have only 765 pixels
# Deleting image img/FFRK_Ingus_Knight_sprites17.png
# Image have only 855 pixels
# Deleting image img/FFRK_Ingus_Knight_sprites18.png
# Image have only 747 pixels
# Deleting image img/FFRK_Irvine_sprites14.png
# Image have only 801 pixels
# Deleting image img/FFRK_Irvine_sprites15.png
# Image have only 675 pixels
# Deleting image img/FFRK_Irvine_sprites17.png
# Image have only 783 pixels
# Deleting image img/FFRK_Irvine_sprites18.png
# Image have only 585 pixels
# Deleting image img/FFRK_Josef_sprites14.png
# Image have only 666 pixels
# Deleting image img/FFRK_Josef_sprites15.png
# Image have only 540 pixels
# Deleting image img/FFRK_Josef_sprites17.png
# Image have only 675 pixels
# Deleting image img/FFRK_Josef_sprites18.png
# Image have only 693 pixels
# Deleting image img/FFRK_Kain_sprites14.png
# Image have only 774 pixels
# Deleting image img/FFRK_Kain_sprites15.png
# Image have only 774 pixels
# Deleting image img/FFRK_Kain_sprites16.png
# Image have only 648 pixels
# Deleting image img/FFRK_Kain_sprites17.png
# Image have only 738 pixels
# Deleting image img/FFRK_Kain_sprites18.png
# Image have only 684 pixels
# Deleting image img/FFRK_Kefka_sprites14.png
# Image have only 756 pixels
# Deleting image img/FFRK_Kefka_sprites15.png
# Image have only 756 pixels
# Deleting image img/FFRK_Kefka_sprites16.png
# Image have only 648 pixels
# Deleting image img/FFRK_Kefka_sprites17.png
# Image have only 738 pixels
# Deleting image img/FFRK_Kefka_sprites18.png
# Image have only 738 pixels
# Deleting image img/FFRK_Hope_sprites15.png
# Image have only 801 pixels
# Deleting image img/FFRK_Irvine_sprites16.png
# Image have only 666 pixels
# Deleting image img/FFRK_Josef_sprites16.png
# Image have only 774 pixels
# Deleting image img/FFRK_Kimahri_sprites14.png
# Image have only 864 pixels
# Deleting image img/FFRK_Kimahri_sprites15.png
# Image have only 864 pixels
# Deleting image img/FFRK_Kimahri_sprites16.png
# Image have only 837 pixels
# Deleting image img/FFRK_Kimahri_sprites18.png
# Image have only 639 pixels
# Deleting image img/FFRK_Knight_sprites14.png
# Image have only 720 pixels
# Deleting image img/FFRK_Knight_sprites15.png
# Image have only 720 pixels
# Deleting image img/FFRK_Knight_sprites16.png
# Image have only 594 pixels
# Deleting image img/FFRK_Knight_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Knight_sprites18.png
# Image have only 684 pixels
# Deleting image img/FFRK_Krile_Beastmaster_sprites14.png
# Image have only 765 pixels
# Deleting image img/FFRK_Krile_Beastmaster_sprites15.png
# Image have only 765 pixels
# Deleting image img/FFRK_Krile_Beastmaster_sprites16.png
# Image have only 639 pixels
# Deleting image img/FFRK_Krile_Beastmaster_sprites17.png
# Image have only 729 pixels
# Deleting image img/FFRK_Krile_Beastmaster_sprites18.png
# Image have only 711 pixels
# Deleting image img/FFRK_Krile_Freelancer_sprites14.png
# Image have only 792 pixels
# Deleting image img/FFRK_Krile_Freelancer_sprites15.png
# Image have only 792 pixels
# Deleting image img/FFRK_Krile_Freelancer_sprites16.png
# Image have only 783 pixels
# Deleting image img/FFRK_Krile_Freelancer_sprites18.png
# Image have only 756 pixels
# Deleting image img/FFRK_Kuja_sprites14.png
# Image have only 810 pixels
# Deleting image img/FFRK_Kuja_sprites16.png
# Image have only 693 pixels
# Deleting image img/FFRK_Kuja_sprites17.png
# Image have only 783 pixels
# Deleting image img/FFRK_Kuja_sprites18.png
# Image have only 666 pixels
# Deleting image img/FFRK_Laguna_sprites14.png
# Image have only 729 pixels
# Deleting image img/FFRK_Laguna_sprites15.png
# Image have only 729 pixels
# Deleting image img/FFRK_Laguna_sprites16.png
# Image have only 594 pixels
# Deleting image img/FFRK_Laguna_sprites17.png
# Image have only 720 pixels
# Deleting image img/FFRK_Laguna_sprites18.png
# Image have only 729 pixels
# Deleting image img/FFRK_Lann_sprites14.png
# Image have only 810 pixels
# Deleting image img/FFRK_Lann_sprites15.png
# Image have only 810 pixels
# Deleting image img/FFRK_Lann_sprites16.png
# Image have only 693 pixels
# Deleting image img/FFRK_Lann_sprites17.png
# Image have only 774 pixels
# Deleting image img/FFRK_Lann_sprites18.png
# Image have only 657 pixels
# Deleting image img/FFRK_Larsa_sprites14.png
# Image have only 738 pixels
# Deleting image img/FFRK_Larsa_sprites15.png
# Image have only 738 pixels
# Deleting image img/FFRK_Larsa_sprites16.png
# Image have only 603 pixels
# Deleting image img/FFRK_Larsa_sprites17.png
# Image have only 711 pixels
# Deleting image img/FFRK_Larsa_sprites18.png
# Image have only 693 pixels
# Deleting image img/FFRK_Leila_sprites14.png
# Image have only 756 pixels
# Deleting image img/FFRK_Leila_sprites15.png
# Image have only 756 pixels
# Deleting image img/FFRK_Leila_sprites16.png
# Image have only 657 pixels
# Deleting image img/FFRK_Leila_sprites17.png
# Image have only 756 pixels
# Deleting image img/FFRK_Leila_sprites18.png
# Image have only 666 pixels
# Deleting image img/FFRK_Lenna_Freelancer_sprites14.png
# Image have only 702 pixels
# Deleting image img/FFRK_Kimahri_sprites17.png
# Image have only 675 pixels
# Deleting image img/FFRK_Krile_Freelancer_sprites17.png
# Image have only 810 pixels
# Deleting image img/FFRK_Kuja_sprites15.png
# Image have only 738 pixels
# Deleting image img/FFRK_Lenna_Freelancer_sprites16.png
# Image have only 603 pixels
# Deleting image img/FFRK_Lenna_Freelancer_sprites17.png
# Image have only 720 pixels
# Deleting image img/FFRK_Lenna_Freelancer_sprites18.png
# Image have only 684 pixels
# Deleting image img/FFRK_Lenna_sprites14.png
# Image have only 765 pixels
# Deleting image img/FFRK_Lenna_sprites15.png
# Image have only 765 pixels
# Deleting image img/FFRK_Lenna_sprites16.png
# Image have only 639 pixels
# Deleting image img/FFRK_Lenna_sprites17.png
# Image have only 774 pixels
# Deleting image img/FFRK_Lenna_sprites18.png
# Image have only 648 pixels
# Deleting image img/FFRK_Leon_sprites14.png
# Image have only 729 pixels
# Deleting image img/FFRK_Leon_sprites15.png
# Image have only 729 pixels
# Deleting image img/FFRK_Leon_sprites16.png
# Image have only 603 pixels
# Deleting image img/FFRK_Leon_sprites17.png
# Image have only 702 pixels
# Deleting image img/FFRK_Leon_sprites18.png
# Image have only 621 pixels
# Deleting image img/FFRK_Leo_sprites14.png
# Image have only 702 pixels
# Deleting image img/FFRK_Leo_sprites15.png
# Image have only 702 pixels
# Deleting image img/FFRK_Leo_sprites16.png
# Image have only 585 pixels
# Deleting image img/FFRK_Leo_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Leo_sprites18.png
# Image have only 639 pixels
# Deleting image img/FFRK_Lightning_Knight_of_Etro_sprites14.png
# Image have only 720 pixels
# Deleting image img/FFRK_Lightning_Knight_of_Etro_sprites15.png
# Image have only 720 pixels
# Deleting image img/FFRK_Lightning_Knight_of_Etro_sprites16.png
# Image have only 702 pixels
# Deleting image img/FFRK_Lightning_Knight_of_Etro_sprites18.png
# Image have only 720 pixels
# Deleting image img/FFRK_Lightning_sprites15.png
# Image have only 720 pixels
# Deleting image img/FFRK_Lightning_sprites16.png
# Image have only 603 pixels
# Deleting image img/FFRK_Lightning_sprites17.png
# Image have only 702 pixels
# Deleting image img/FFRK_Lightning_sprites18.png
# Image have only 720 pixels
# Deleting image img/FFRK_Lion_sprites14.png
# Image have only 765 pixels
# Deleting image img/FFRK_Lion_sprites15.png
# Image have only 765 pixels
# Deleting image img/FFRK_Lion_sprites16.png
# Image have only 657 pixels
# Deleting image img/FFRK_Lion_sprites17.png
# Image have only 774 pixels
# Deleting image img/FFRK_Lion_sprites18.png
# Image have only 648 pixels
# Deleting image img/FFRK_Locke_sprites14.png
# Image have only 729 pixels
# Deleting image img/FFRK_Locke_sprites15.png
# Image have only 729 pixels
# Deleting image img/FFRK_Locke_sprites16.png
# Image have only 603 pixels
# Deleting image img/FFRK_Locke_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Locke_sprites18.png
# Image have only 720 pixels
# Deleting image img/FFRK_Lulu_sprites14.png
# Image have only 801 pixels
# Deleting image img/FFRK_Lulu_sprites15.png
# Image have only 801 pixels
# Deleting image img/FFRK_Lulu_sprites16.png
# Image have only 666 pixels
# Deleting image img/FFRK_Lulu_sprites17.png
# Image have only 792 pixels
# Deleting image img/FFRK_Lulu_sprites18.png
# Image have only 711 pixels
# Deleting image img/FFRK_Luneth_Dark_Knight_sprites14.png
# Image have only 792 pixels
# Deleting image img/FFRK_Luneth_Dark_Knight_sprites15.png
# Image have only 666 pixels
# Deleting image img/FFRK_Luneth_Dark_Knight_sprites17.png
# Image have only 756 pixels
# Deleting image img/FFRK_Luneth_Dark_Knight_sprites18.png
# Image have only 693 pixels
# Deleting image img/FFRK_Luneth_Warrior_sprites14.png
# Image have only 774 pixels
# Deleting image img/FFRK_Luneth_Warrior_sprites15.png
# Image have only 774 pixels
# Deleting image img/FFRK_Luneth_Warrior_sprites16.png
# Image have only 657 pixels
# Deleting image img/FFRK_Luneth_Warrior_sprites17.png
# Image have only 720 pixels
# Deleting image img/FFRK_Luneth_Warrior_sprites18.png
# Image have only 738 pixels
# Deleting image img/FFRK_Lenna_Freelancer_sprites15.png
# Image have only 603 pixels
# Deleting image img/FFRK_Lightning_Knight_of_Etro_sprites17.png
# Image have only 639 pixels
# Deleting image img/FFRK_Lightning_sprites14.png
# Image have only 792 pixels
# Deleting image img/FFRK_Luneth_Dark_Knight_sprites16.png
# Image have only 693 pixels
# Deleting image img/FFRK_Magus_sprites14.png
# Image have only 774 pixels
# Deleting image img/FFRK_Magus_sprites15.png
# Image have only 774 pixels
# Deleting image img/FFRK_Magus_sprites16.png
# Image have only 648 pixels
# Deleting image img/FFRK_Magus_sprites17.png
# Image have only 738 pixels
# Deleting image img/FFRK_Magus_sprites18.png
# Image have only 666 pixels
# Deleting image img/FFRK_Maria_sprites14.png
# Image have only 729 pixels
# Deleting image img/FFRK_Maria_sprites15.png
# Image have only 729 pixels
# Deleting image img/FFRK_Maria_sprites16.png
# Image have only 621 pixels
# Deleting image img/FFRK_Maria_sprites17.png
# Image have only 738 pixels
# Deleting image img/FFRK_Maria_sprites18.png
# Image have only 657 pixels
# Deleting image img/FFRK_Master_Monk_FFI_sprites14.png
# Image have only 720 pixels
# Deleting image img/FFRK_Master_Monk_FFI_sprites15.png
# Image have only 720 pixels
# Deleting image img/FFRK_Master_Monk_FFI_sprites16.png
# Image have only 603 pixels
# Deleting image img/FFRK_Master_Monk_FFI_sprites17.png
# Image have only 729 pixels
# Deleting image img/FFRK_Master_Monk_FFI_sprites18.png
# Image have only 774 pixels
# Deleting image img/FFRK_Matoya_FFI_sprites14.png
# Image have only 837 pixels
# Deleting image img/FFRK_Matoya_FFI_sprites15.png
# Image have only 837 pixels
# Deleting image img/FFRK_Matoya_FFI_sprites16.png
# Image have only 711 pixels
# Deleting image img/FFRK_Matoya_FFI_sprites17.png
# Image have only 801 pixels
# Deleting image img/FFRK_Matoya_FFI_sprites18.png
# Image have only 738 pixels
# Deleting image img/FFRK_Minfilia_sprites14.png
# Image have only 819 pixels
# Deleting image img/FFRK_Minfilia_sprites15.png
# Image have only 819 pixels
# Deleting image img/FFRK_Minfilia_sprites16.png
# Image have only 693 pixels
# Deleting image img/FFRK_Minfilia_sprites17.png
# Image have only 783 pixels
# Deleting image img/FFRK_Minfilia_sprites18.png
# Image have only 630 pixels
# Deleting image img/FFRK_Minwu_sprites14.png
# Image have only 711 pixels
# Deleting image img/FFRK_Minwu_sprites15.png
# Image have only 711 pixels
# Deleting image img/FFRK_Minwu_sprites16.png
# Image have only 585 pixels
# Deleting image img/FFRK_Minwu_sprites17.png
# Image have only 684 pixels
# Deleting image img/FFRK_Minwu_sprites18.png
# Image have only 693 pixels
# Deleting image img/FFRK_Mog_sprites14.png
# Image have only 747 pixels
# Deleting image img/FFRK_Mog_sprites15.png
# Image have only 747 pixels
# Deleting image img/FFRK_Mog_sprites16.png
# Image have only 621 pixels
# Deleting image img/FFRK_Mog_sprites17.png
# Image have only 711 pixels
# Deleting image img/FFRK_Mog_sprites18.png
# Image have only 639 pixels
# Deleting image img/FFRK_Monk_sprites14.png
# Image have only 720 pixels
# Deleting image img/FFRK_Monk_sprites15.png
# Image have only 720 pixels
# Deleting image img/FFRK_Monk_sprites16.png
# Image have only 594 pixels
# Deleting image img/FFRK_Monk_sprites17.png
# Image have only 639 pixels
# Deleting image img/FFRK_Ninja_sprites14.png
# Image have only 720 pixels
# Deleting image img/FFRK_Ninja_sprites15.png
# Image have only 720 pixels
# Deleting image img/FFRK_Ninja_sprites16.png
# Image have only 594 pixels
# Deleting image img/FFRK_Ninja_sprites17.png
# Image have only 684 pixels
# Deleting image img/FFRK_Ninja_sprites18.png
# Image have only 639 pixels
# Deleting image img/FFRK_Noel_sprites14.png
# Image have only 720 pixels
# Deleting image img/FFRK_Noel_sprites16.png
# Image have only 594 pixels
# Deleting image img/FFRK_Noel_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Noel_sprites18.png
# Image have only 711 pixels
# Deleting image img/FFRK_Onion_Knight_sprites14.png
# Image have only 792 pixels
# Deleting image img/FFRK_Onion_Knight_sprites15.png
# Image have only 792 pixels
# Deleting image img/FFRK_Onion_Knight_sprites16.png
# Image have only 666 pixels
# Deleting image img/FFRK_Onion_Knight_sprites17.png
# Image have only 756 pixels
# Deleting image img/FFRK_Onion_Knight_sprites18.png
# Image have only 675 pixels
# Deleting image img/FFRK_Paladin_Cecil_sprites14.png
# Image have only 756 pixels
# Deleting image img/FFRK_Paladin_Cecil_sprites15.png
# Image have only 756 pixels
# Deleting image img/FFRK_Paladin_Cecil_sprites16.png
# Image have only 630 pixels
# Deleting image img/FFRK_Paladin_Cecil_sprites17.png
# Image have only 756 pixels
# Deleting image img/FFRK_Paladin_Cecil_sprites18.png
# Image have only 693 pixels
# Deleting image img/FFRK_Monk_sprites18.png
# Image have only 720 pixels
# Deleting image img/FFRK_Noel_sprites15.png
# Image have only 693 pixels
# Deleting image img/FFRK_Palom_sprites14.png
# Image have only 774 pixels
# Deleting image img/FFRK_Palom_sprites15.png
# Image have only 774 pixels
# Deleting image img/FFRK_Palom_sprites16.png
# Image have only 648 pixels
# Deleting image img/FFRK_Palom_sprites17.png
# Image have only 756 pixels
# Deleting image img/FFRK_Palom_sprites18.png
# Image have only 639 pixels
# Deleting image img/FFRK_Papalymo_sprites14.png
# Image have only 720 pixels
# Deleting image img/FFRK_Papalymo_sprites15.png
# Image have only 720 pixels
# Deleting image img/FFRK_Papalymo_sprites16.png
# Image have only 594 pixels
# Deleting image img/FFRK_Papalymo_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Papalymo_sprites18.png
# Image have only 684 pixels
# Deleting image img/FFRK_Penelo_sprites14.png
# Image have only 756 pixels
# Deleting image img/FFRK_Penelo_sprites15.png
# Image have only 756 pixels
# Deleting image img/FFRK_Penelo_sprites16.png
# Image have only 621 pixels
# Deleting image img/FFRK_Penelo_sprites17.png
# Image have only 729 pixels
# Deleting image img/FFRK_Penelo_sprites18.png
# Image have only 693 pixels
# Deleting image img/FFRK_Porom_sprites14.png
# Image have only 774 pixels
# Deleting image img/FFRK_Porom_sprites15.png
# Image have only 648 pixels
# Deleting image img/FFRK_Porom_sprites17.png
# Image have only 738 pixels
# Deleting image img/FFRK_Porom_sprites18.png
# Image have only 729 pixels
# Deleting image img/FFRK_Prishe_sprites14.png
# Image have only 774 pixels
# Deleting image img/FFRK_Prishe_sprites15.png
# Image have only 774 pixels
# Deleting image img/FFRK_Prishe_sprites16.png
# Image have only 639 pixels
# Deleting image img/FFRK_Prishe_sprites17.png
# Image have only 756 pixels
# Deleting image img/FFRK_Prishe_sprites18.png
# Image have only 738 pixels
# Deleting image img/FFRK_Quina_sprites14.png
# Image have only 819 pixels
# Deleting image img/FFRK_Quina_sprites15.png
# Image have only 819 pixels
# Deleting image img/FFRK_Quina_sprites16.png
# Image have only 693 pixels
# Deleting image img/FFRK_Quina_sprites17.png
# Image have only 783 pixels
# Deleting image img/FFRK_Quina_sprites18.png
# Image have only 711 pixels
# Deleting image img/FFRK_Quistis_sprites14.png
# Image have only 792 pixels
# Deleting image img/FFRK_Quistis_sprites15.png
# Image have only 792 pixels
# Deleting image img/FFRK_Quistis_sprites16.png
# Image have only 666 pixels
# Deleting image img/FFRK_Quistis_sprites17.png
# Image have only 774 pixels
# Deleting image img/FFRK_Quistis_sprites18.png
# Image have only 774 pixels
# Deleting image img/FFRK_Porom_sprites16.png
# Image have only 630 pixels
# Deleting image img/FFRK_Raijin_FFVIII_sprites14.png
# Image have only 711 pixels
# Deleting image img/FFRK_Raijin_FFVIII_sprites15.png
# Image have only 711 pixels
# Deleting image img/FFRK_Raijin_FFVIII_sprites16.png
# Image have only 693 pixels
# Deleting image img/FFRK_Raijin_FFVIII_sprites18.png
# Image have only 720 pixels
# Deleting image img/FFRK_Ramza_sprites14.png
# Image have only 783 pixels
# Deleting image img/FFRK_Ramza_sprites15.png
# Image have only 783 pixels
# Deleting image img/FFRK_Ramza_sprites16.png
# Image have only 657 pixels
# Deleting image img/FFRK_Ramza_sprites17.png
# Image have only 765 pixels
# Deleting image img/FFRK_Ramza_sprites18.png
# Image have only 639 pixels
# Deleting image img/FFRK_Ranger_sprites14.png
# Image have only 720 pixels
# Deleting image img/FFRK_Ranger_sprites15.png
# Image have only 720 pixels
# Deleting image img/FFRK_Ranger_sprites16.png
# Image have only 594 pixels
# Deleting image img/FFRK_Ranger_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Ranger_sprites18.png
# Image have only 657 pixels
# Deleting image img/FFRK_Red_Mage_sprites14.png
# Image have only 738 pixels
# Deleting image img/FFRK_Red_Mage_sprites15.png
# Image have only 612 pixels
# Deleting image img/FFRK_Red_Mage_sprites17.png
# Image have only 702 pixels
# Deleting image img/FFRK_Red_Mage_sprites18.png
# Image have only 711 pixels
# Deleting image img/FFRK_Red_XIII_sprites14.png
# Image have only 792 pixels
# Deleting image img/FFRK_Red_XIII_sprites15.png
# Image have only 792 pixels
# Deleting image img/FFRK_Red_XIII_sprites16.png
# Image have only 666 pixels
# Deleting image img/FFRK_Red_XIII_sprites17.png
# Image have only 774 pixels
# Deleting image img/FFRK_Red_XIII_sprites18.png
# Image have only 666 pixels
# Deleting image img/FFRK_Refia_Monk_sprites14.png
# Image have only 729 pixels
# Deleting image img/FFRK_Refia_Monk_sprites15.png
# Image have only 729 pixels
# Deleting image img/FFRK_Refia_Monk_sprites16.png
# Image have only 594 pixels
# Deleting image img/FFRK_Refia_Monk_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Refia_Monk_sprites18.png
# Image have only 738 pixels
# Deleting image img/FFRK_Relm_sprites14.png
# Image have only 819 pixels
# Deleting image img/FFRK_Relm_sprites15.png
# Image have only 819 pixels
# Deleting image img/FFRK_Relm_sprites16.png
# Image have only 693 pixels
# Deleting image img/FFRK_Relm_sprites17.png
# Image have only 828 pixels
# Deleting image img/FFRK_Relm_sprites18.png
# Image have only 729 pixels
# Deleting image img/FFRK_Reno_sprites14.png
# Image have only 792 pixels
# Deleting image img/FFRK_Reno_sprites15.png
# Image have only 792 pixels
# Deleting image img/FFRK_Reno_sprites16.png
# Image have only 675 pixels
# Deleting image img/FFRK_Reno_sprites17.png
# Image have only 594 pixels
# Deleting image img/FFRK_Raijin_FFVIII_sprites17.png
# Image have only 738 pixels
# Deleting image img/FFRK_Red_Mage_sprites16.png
# Image have only 666 pixels
# Deleting image img/FFRK_Reynn_sprites14.png
# Image have only 738 pixels
# Deleting image img/FFRK_Reynn_sprites16.png
# Image have only 603 pixels
# Deleting image img/FFRK_Reynn_sprites17.png
# Image have only 720 pixels
# Deleting image img/FFRK_Reynn_sprites18.png
# Image have only 765 pixels
# Deleting image img/FFRK_Ricard_sprites14.png
# Image have only 855 pixels
# Deleting image img/FFRK_Ricard_sprites15.png
# Image have only 855 pixels
# Deleting image img/FFRK_Ricard_sprites16.png
# Image have only 729 pixels
# Deleting image img/FFRK_Ricard_sprites17.png
# Image have only 819 pixels
# Deleting image img/FFRK_Ricard_sprites18.png
# Image have only 783 pixels
# Deleting image img/FFRK_Rikku_sprites14.png
# Image have only 864 pixels
# Deleting image img/FFRK_Rikku_sprites15.png
# Image have only 864 pixels
# Deleting image img/FFRK_Rikku_sprites16.png
# Image have only 738 pixels
# Deleting image img/FFRK_Rikku_sprites17.png
# Image have only 855 pixels
# Deleting image img/FFRK_Rikku_sprites18.png
# Image have only 900 pixels
# Deleting image img/FFRK_Rikku_X2_sprites14.png
# Image have only 954 pixels
# Deleting image img/FFRK_Rikku_X2_sprites15.png
# Image have only 954 pixels
# Deleting image img/FFRK_Rikku_X2_sprites16.png
# Image have only 828 pixels
# Deleting image img/FFRK_Rikku_X2_sprites17.png
# Image have only 675 pixels
# Deleting image img/FFRK_Rinoa_sprites14.png
# Image have only 738 pixels
# Deleting image img/FFRK_Rinoa_sprites15.png
# Image have only 738 pixels
# Deleting image img/FFRK_Rinoa_sprites16.png
# Image have only 630 pixels
# Deleting image img/FFRK_Rinoa_sprites17.png
# Image have only 720 pixels
# Deleting image img/FFRK_Rinoa_sprites18.png
# Image have only 720 pixels
# ...
# Image have only 720 pixels
# Deleting image img/FFRK_Snow_sprites15.png
# Image have only 720 pixels
# Deleting image img/FFRK_Snow_sprites16.png
# Image have only 594 pixels
# Deleting image img/FFRK_Snow_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Snow_sprites18.png
# Image have only 639 pixels
# Deleting image img/FFRK_Spellblade_sprites14.png
# Image have only 720 pixels
# Deleting image img/FFRK_Spellblade_sprites15.png
# Image have only 666 pixels
# Deleting image img/FFRK_Paine_sprites14.png
# Image have only 747 pixels
# Deleting image img/FFRK_Paine_sprites15.png
# Image have only 747 pixels
# Deleting image img/FFRK_Paine_sprites16.png
# Image have only 630 pixels
# Deleting image img/FFRK_Paine_sprites17.png
# Image have only 729 pixels
# Deleting image img/FFRK_Paine_sprites18.png
# Image have only 612 pixels
# Deleting image img/FFRK_Sazh_sprites14.png
# Image have only 702 pixels
# Deleting image img/FFRK_Sazh_sprites15.png
# Image have only 702 pixels
# Deleting image img/FFRK_Sazh_sprites16.png
# Image have only 585 pixels
# Deleting image img/FFRK_Sazh_sprites17.png
# Image have only 702 pixels
# Deleting image img/FFRK_Sazh_sprites18.png
# Image have only 855 pixels
# Deleting image img/FFRK_Seymour_sprites14.png
# Image have only 594 pixels
# Deleting image img/FFRK_Spellblade_sprites17.png
# Image have only 684 pixels
# Deleting image img/FFRK_Spellblade_sprites18.png
# Image have only 702 pixels
# Deleting image img/FFRK_Terra_Esper_sprites14.png
# Image have only 756 pixels
# Deleting image img/FFRK_Terra_Esper_sprites15.png
# Image have only 756 pixels
# Deleting image img/FFRK_Terra_Esper_sprites16.png
# Image have only 639 pixels
# Deleting image img/FFRK_Terra_Esper_sprites17.png
# Image have only 747 pixels
# Deleting image img/FFRK_Terra_Esper_sprites18.png
# Image have only 657 pixels
# Deleting image img/FFRK_Tidus_sprites14.png
# Image have only 738 pixels
# Deleting image img/FFRK_Tidus_sprites15.png
# Image have only 738 pixels
# Deleting image img/FFRK_Tidus_sprites16.png
# Image have only 612 pixels
# Deleting image img/FFRK_Tidus_sprites17.png
# Image have only 711 pixels
# Deleting image img/FFRK_Tidus_sprites18.png
# Image have only 729 pixels
# Deleting image img/FFRK_Setzer_sprites18.png
# Image have only 909 pixels
# Deleting image img/FFRK_Seymour_sprites15.png
# Image have only 720 pixels
# Deleting image img/FFRK_Spellblade_sprites16.png
# Image have only 639 pixels
# Deleting image img/FFRK_Squall_SeeD_Uniform_sprites14.png
# Image have only 720 pixels
# Deleting image img/FFRK_Squall_SeeD_Uniform_sprites15.png
# Image have only 720 pixels
# Deleting image img/FFRK_Squall_SeeD_Uniform_sprites16.png
# Image have only 594 pixels
# Deleting image img/FFRK_Squall_SeeD_Uniform_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Squall_SeeD_Uniform_sprites18.png
# Image have only 639 pixels
# Deleting image img/FFRK_Squall_sprites14.png
# Image have only 720 pixels
# Deleting image img/FFRK_Squall_sprites15.png
# Image have only 720 pixels
# Deleting image img/FFRK_Squall_sprites16.png
# Image have only 594 pixels
# Deleting image img/FFRK_Squall_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Squall_sprites18.png
# Image have only 639 pixels
# Deleting image img/FFRK_Steiner_sprites14.png
# Image have only 720 pixels
# Deleting image img/FFRK_Steiner_sprites15.png
# Image have only 594 pixels
# Deleting image img/FFRK_Steiner_sprites17.png
# Image have only 684 pixels
# Deleting image img/FFRK_Steiner_sprites18.png
# Image have only 657 pixels
# Deleting image img/FFRK_Strago_sprites14.png
# Image have only 738 pixels
# Deleting image img/FFRK_Strago_sprites15.png
# Image have only 738 pixels
# Deleting image img/FFRK_Strago_sprites16.png
# Image have only 612 pixels
# Deleting image img/FFRK_Strago_sprites17.png
# Image have only 720 pixels
# Deleting image img/FFRK_Strago_sprites18.png
# Image have only 666 pixels
# Deleting image img/FFRK_Summoner_sprites14.png
# Image have only 747 pixels
# Deleting image img/FFRK_Summoner_sprites15.png
# Image have only 747 pixels
# Deleting image img/FFRK_Summoner_sprites16.png
# Image have only 621 pixels
# Deleting image img/FFRK_Summoner_sprites17.png
# Image have only 720 pixels
# Deleting image img/FFRK_Summoner_sprites18.png
# Image have only 666 pixels
# Deleting image img/FFRK_Tellah_sprites14.png
# Image have only 747 pixels
# Deleting image img/FFRK_Tellah_sprites15.png
# Image have only 747 pixels
# Deleting image img/FFRK_Tellah_sprites16.png
# Image have only 630 pixels
# Deleting image img/FFRK_Tellah_sprites17.png
# Image have only 711 pixels
# Deleting image img/FFRK_Tellah_sprites18.png
# Image have only 720 pixels
# Deleting image img/FFRK_Terra_sprites14.png
# Image have only 801 pixels
# Deleting image img/FFRK_Terra_sprites15.png
# Image have only 801 pixels
# Deleting image img/FFRK_Terra_sprites16.png
# Image have only 684 pixels
# Deleting image img/FFRK_Terra_sprites17.png
# Image have only 774 pixels
# Deleting image img/FFRK_Terra_sprites18.png
# Image have only 648 pixels
# Deleting image img/FFRK_Thancred_sprites14.png
# Image have only 729 pixels
# Deleting image img/FFRK_Thancred_sprites15.png
# Image have only 729 pixels
# Deleting image img/FFRK_Thancred_sprites16.png
# Image have only 594 pixels
# Deleting image img/FFRK_Thancred_sprites17.png
# Image have only 720 pixels
# Deleting image img/FFRK_Steiner_sprites16.png
# Image have only 693 pixels
# Deleting image img/FFRK_Thancred_sprites18.png
# Image have only 657 pixels
# Deleting image img/FFRK_Thief_sprites14.png
# Image have only 738 pixels
# Deleting image img/FFRK_Thief_sprites15.png
# Image have only 738 pixels
# Deleting image img/FFRK_Thief_sprites16.png
# Image have only 603 pixels
# Deleting image img/FFRK_Thief_sprites17.png
# Image have only 702 pixels
# Deleting image img/FFRK_Thief_sprites18.png
# Image have only 657 pixels
# Deleting image img/FFRK_Tidus_Dreams_of_Glory_sprites14.png
# Image have only 738 pixels
# Deleting image img/FFRK_Tidus_Dreams_of_Glory_sprites15.png
# Image have only 738 pixels
# Deleting image img/FFRK_Tidus_Dreams_of_Glory_sprites16.png
# Image have only 612 pixels
# Deleting image img/FFRK_Tidus_Dreams_of_Glory_sprites17.png
# Image have only 711 pixels
# Deleting image img/FFRK_Tidus_Dreams_of_Glory_sprites18.png
# Image have only 720 pixels
# Deleting image img/FFRK_Tifa_sprites14.png
# Image have only 774 pixels
# Deleting image img/FFRK_Tifa_sprites15.png
# Image have only 774 pixels
# Deleting image img/FFRK_Tifa_sprites16.png
# Image have only 630 pixels
# Deleting image img/FFRK_Tifa_sprites17.png
# Image have only 738 pixels
# Deleting image img/FFRK_Tifa_sprites18.png
# Image have only 666 pixels
# Deleting image img/FFRK_Tifa_VIIAC_sprites14.png
# Image have only 729 pixels
# Deleting image img/FFRK_Tifa_VIIAC_sprites16.png
# Image have only 603 pixels
# Deleting image img/FFRK_Tifa_VIIAC_sprites17.png
# Image have only 720 pixels
# Deleting image img/FFRK_Tifa_VIIAC_sprites18.png
# Image have only 819 pixels
# Deleting image img/FFRK_Tyro_sprites14.png
# Image have only 900 pixels
# Deleting image img/FFRK_Tyro_sprites15.png
# Image have only 900 pixels
# Deleting image img/FFRK_Tyro_sprites16.png
# Image have only 828 pixels
# Deleting image img/FFRK_Tyro_sprites17.png
# Image have only 918 pixels
# Deleting image img/FFRK_Tyro_sprites18.png
# Image have only 648 pixels
# Deleting image img/FFRK_Vaan_sprites14.png
# Image have only 729 pixels
# Deleting image img/FFRK_Vaan_sprites15.png
# Image have only 729 pixels
# Deleting image img/FFRK_Vaan_sprites16.png
# Image have only 621 pixels
# Deleting image img/FFRK_Vaan_sprites17.png
# Image have only 711 pixels
# Deleting image img/FFRK_Vaan_sprites18.png
# Image have only 729 pixels
# Deleting image img/FFRK_Tifa_VIIAC_sprites15.png
# Image have only 711 pixels
# Deleting image img/FFRK_Vanille_sprites14.png
# Image have only 774 pixels
# Deleting image img/FFRK_Vanille_sprites15.png
# Image have only 774 pixels
# Deleting image img/FFRK_Vanille_sprites16.png
# Image have only 657 pixels
# Deleting image img/FFRK_Vanille_sprites17.png
# Image have only 756 pixels
# Deleting image img/FFRK_Vanille_sprites18.png
# Image have only 693 pixels
# Deleting image img/FFRK_Vayne_sprites14.png
# Image have only 747 pixels
# Deleting image img/FFRK_Vayne_sprites15.png
# Image have only 747 pixels
# Deleting image img/FFRK_Vayne_sprites16.png
# Image have only 621 pixels
# Deleting image img/FFRK_Vayne_sprites17.png
# Image have only 747 pixels
# Deleting image img/FFRK_Vayne_sprites18.png
# Image have only 693 pixels
# Deleting image img/FFRK_Viking_sprites14.png
# Image have only 774 pixels
# Deleting image img/FFRK_Viking_sprites15.png
# Image have only 774 pixels
# Deleting image img/FFRK_Viking_sprites16.png
# Image have only 738 pixels
# Deleting image img/FFRK_Viking_sprites18.png
# Image have only 873 pixels
# Deleting image img/FFRK_Vincent_Galian_Beast_sprites14.png
# Image have only 909 pixels
# Deleting image img/FFRK_Vincent_Galian_Beast_sprites15.png
# Image have only 909 pixels
# Deleting image img/FFRK_Vincent_Galian_Beast_sprites16.png
# Image have only 792 pixels
# Deleting image img/FFRK_Vincent_Galian_Beast_sprites17.png
# Image have only 900 pixels
# Deleting image img/FFRK_Vincent_Galian_Beast_sprites18.png
# Image have only 747 pixels
# Deleting image img/FFRK_Vincent_sprites14.png
# Image have only 810 pixels
# Deleting image img/FFRK_Vincent_sprites15.png
# Image have only 810 pixels
# Deleting image img/FFRK_Vincent_sprites16.png
# Image have only 711 pixels
# Deleting image img/FFRK_Vincent_sprites17.png
# Image have only 846 pixels
# Deleting image img/FFRK_Vincent_sprites18.png
# Image have only 747 pixels
# Deleting image img/FFRK_Vivi_sprites14.png
# Image have only 828 pixels
# Deleting image img/FFRK_Vivi_sprites15.png
# Image have only 828 pixels
# Deleting image img/FFRK_Vivi_sprites16.png
# Image have only 702 pixels
# Deleting image img/FFRK_Vivi_sprites17.png
# Image have only 828 pixels
# Deleting image img/FFRK_Vivi_sprites18.png
# Image have only 675 pixels
# Deleting image img/FFRK_Wakka_sprites14.png
# Image have only 756 pixels
# Deleting image img/FFRK_Wakka_sprites15.png
# Image have only 756 pixels
# Deleting image img/FFRK_Wakka_sprites16.png
# Image have only 630 pixels
# Deleting image img/FFRK_Wakka_sprites17.png
# Image have only 729 pixels
# Deleting image img/FFRK_Wakka_sprites18.png
# Image have only 675 pixels
# Deleting image img/FFRK_Warrior_of_Light_sprites14.png
# Image have only 747 pixels
# Deleting image img/FFRK_Warrior_of_Light_sprites15.png
# Image have only 747 pixels
# Deleting image img/FFRK_Warrior_of_Light_sprites16.png
# Image have only 639 pixels
# Deleting image img/FFRK_Warrior_of_Light_sprites17.png
# Image have only 747 pixels
# Deleting image img/FFRK_Warrior_of_Light_sprites18.png
# Image have only 639 pixels
# Deleting image img/FFRK_Warrior_sprites14.png
# Image have only 720 pixels
# Deleting image img/FFRK_Warrior_sprites15.png
# Image have only 720 pixels
# Deleting image img/FFRK_Warrior_sprites16.png
# Image have only 594 pixels
# Deleting image img/FFRK_Warrior_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Warrior_sprites18.png
# Image have only 684 pixels
# Deleting image img/FFRK_White_Mage_sprites14.png
# Image have only 765 pixels
# Deleting image img/FFRK_White_Mage_sprites15.png
# Image have only 648 pixels
# Deleting image img/FFRK_Viking_sprites17.png
# Image have only 765 pixels
# Deleting image img/FFRK_White_Mage_sprites16.png
# Image have only 639 pixels
# Deleting image img/FFRK_White_Mage_sprites17.png
# Image have only 774 pixels
# Deleting image img/FFRK_White_Mage_sprites18.png
# Image have only 657 pixels
# Deleting image img/FFRK_Wol_sprites14.png
# Image have only 738 pixels
# Deleting image img/FFRK_Wol_sprites15.png
# Image have only 738 pixels
# Deleting image img/FFRK_Wol_sprites16.png
# Image have only 612 pixels
# Deleting image img/FFRK_Wol_sprites17.png
# Image have only 702 pixels
# Deleting image img/FFRK_Wol_sprites18.png
# Image have only 684 pixels
# Deleting image img/FFRK_Y%27shtola_sprites14.png
# Image have only 783 pixels
# Deleting image img/FFRK_Y%27shtola_sprites15.png
# Image have only 783 pixels
# Deleting image img/FFRK_Y%27shtola_sprites16.png
# Image have only 666 pixels
# Deleting image img/FFRK_Y%27shtola_sprites17.png
# Image have only 765 pixels
# Deleting image img/FFRK_Y%27shtola_sprites18.png
# Image have only 675 pixels
# Deleting image img/FFRK_Yang_sprites14.png
# Image have only 756 pixels
# Deleting image img/FFRK_Yang_sprites15.png
# Image have only 756 pixels
# Deleting image img/FFRK_Yang_sprites16.png
# Image have only 639 pixels
# Deleting image img/FFRK_Yang_sprites17.png
# Image have only 720 pixels
# Deleting image img/FFRK_Yang_sprites18.png
# Image have only 639 pixels
# Deleting image img/FFRK_Yda_sprites14.png
# Image have only 720 pixels
# Deleting image img/FFRK_Yda_sprites15.png
# Image have only 720 pixels
# Deleting image img/FFRK_Yda_sprites16.png
# Image have only 594 pixels
# Deleting image img/FFRK_Yda_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Yda_sprites18.png
# Image have only 675 pixels
# Deleting image img/FFRK_Young_Auron_sprites14.png
# Image have only 729 pixels
# Deleting image img/FFRK_Young_Auron_sprites15.png
# Image have only 729 pixels
# Deleting image img/FFRK_Young_Auron_sprites16.png
# Image have only 612 pixels
# Deleting image img/FFRK_Young_Auron_sprites17.png
# Image have only 720 pixels
# Deleting image img/FFRK_Young_Auron_sprites18.png
# Image have only 666 pixels
# Deleting image img/FFRK_Yuffie_sprites14.png
# Image have only 747 pixels
# Deleting image img/FFRK_Yuffie_sprites15.png
# Image have only 747 pixels
# Deleting image img/FFRK_Yuffie_sprites16.png
# Image have only 621 pixels
# Deleting image img/FFRK_Yuffie_sprites17.png
# Image have only 729 pixels
# Deleting image img/FFRK_Yuffie_sprites18.png
# Image have only 747 pixels
# Deleting image img/FFRK_Yuna_False_Bride_sprites14.png
# Image have only 828 pixels
# Deleting image img/FFRK_Yuna_False_Bride_sprites15.png
# Image have only 702 pixels
# Deleting image img/FFRK_Yuna_False_Bride_sprites17.png
# Image have only 792 pixels
# Deleting image img/FFRK_Yuna_False_Bride_sprites18.png
# Image have only 720 pixels
# Deleting image img/FFRK_Yuna_sprites15.png
# Image have only 720 pixels
# Deleting image img/FFRK_Yuna_sprites16.png
# Image have only 594 pixels
# Deleting image img/FFRK_Yuna_sprites17.png
# Image have only 693 pixels
# Deleting image img/FFRK_Yuna_sprites18.png
# Image have only 693 pixels
# Deleting image img/FFRK_Yuna_X2_sprites14.png
# Image have only 756 pixels
# Deleting image img/FFRK_Yuna_X2_sprites15.png
# Image have only 756 pixels
# Deleting image img/FFRK_Yuna_X2_sprites16.png
# Image have only 639 pixels
# Deleting image img/FFRK_Yuna_X2_sprites17.png
# Image have only 738 pixels
# Deleting image img/FFRK_Yuna_X2_sprites18.png
# Image have only 765 pixels
# Deleting image img/FFRK_Zack_sprites14.png
# Image have only 819 pixels
# Deleting image img/FFRK_Zack_sprites15.png
# Image have only 819 pixels
# Deleting image img/FFRK_Zack_sprites16.png
# Image have only 693 pixels
# Deleting image img/FFRK_Zack_sprites17.png
# Image have only 837 pixels
# Deleting image img/FFRK_Zack_sprites18.png
# Image have only 828 pixels
# Deleting image img/FFRK_Yuna_False_Bride_sprites16.png
# Image have only 639 pixels
# Deleting image img/FFRK_Yuna_sprites14.png
# Image have only 738 pixels
# Deleting image img/FFRK_Zell_sprites16.png
# Image have only 657 pixels
# Deleting image img/FFRK_Zell_sprites14.png
# Image have only 738 pixels
# Deleting image img/FFRK_Zell_sprites15.png
# Image have only 612 pixels
# Deleting image img/FFRK_Zell_sprites17.png
# Image have only 720 pixels
# Deleting image img/FFRK_Zell_sprites18.png
# Image have only 657 pixels
# Deleting image img/FFRK_Zidane_sprites14.png
# Image have only 756 pixels
# Deleting image img/FFRK_Zidane_sprites15.png
# Image have only 756 pixels
# Deleting image img/FFRK_Zidane_sprites16.png
# Image have only 639 pixels
# Deleting image img/FFRK_Zidane_sprites17.png
# Image have only 738 pixels
# Deleting image img/FFRK_Zidane_sprites18.png
# Image have only 657 pixels
# Deleting image img/FFRK_Zidane_Trance_sprites14.png
# Image have only 756 pixels
# Deleting image img/FFRK_Zidane_Trance_sprites15.png
# Image have only 756 pixels
# Deleting image img/FFRK_Zidane_Trance_sprites16.png
# Image have only 639 pixels
# Deleting image img/FFRK_Zidane_Trance_sprites17.png
# Image have only 738 pixels
# Deleting image img/FFRK_Zidane_Trance_sprites18.png

# %%
# 3838 / 4763 images (81%) left after deletion

# %%
# Resize image from 96x96 to smaller dimension 32x32

IMG_SIZE = 32

def test_img_resize():
    img_path_to_resize = 'img/FFRK_Devout_sprites02.png'
    img_array = cv2.imread(img_path_to_resize, cv2.IMREAD_COLOR)
    # img_array = cv2.imread(os.path.join(path,file), cv2.IMREAD_COLOR)  # convert to array
    
    # convert back to original color
    img_array_RGB = cv2.cvtColor(img_array,cv2.COLOR_BGR2RGB)

    new_array_resize = cv2.resize(img_array_RGB, (IMG_SIZE, IMG_SIZE))

#     plt.axis('off')
    plt.imshow(new_array_resize)
#     plt.imshow(img_array_RGB)
    
    # plt.imshow(new_array, cmap='gray')

    plt.show()  # display!

test_img_resize()

# %%
# 2.5 resize all images to same dimension 32x32
# in img folder, from 96x96 to 32x32

import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from tqdm import tqdm

img_resized = []

def all_imgs_resize_in_memory(img_folder='img', img_resize=32, display=10):
    c = 0
    for file in tqdm_notebook(os.listdir(img_folder)):
        if not file.endswith('.png'):
            continue
            
        img_path_to_resize = os.path.join(img_folder, file)
        img_array = cv2.imread(img_path_to_resize, cv2.IMREAD_COLOR)

        # convert back to original color
        img_array_RGB = cv2.cvtColor(img_array,cv2.COLOR_BGR2RGB)

        # resize
        new_array_resized = cv2.resize(img_array_RGB, (img_resize, img_resize))

        # add to list
        img_resized.append(new_array_resized)
        
        c+=1
        
        # display the first 10 images only
        if c < display+1:
            # plt.axis('off')
            plt.imshow(new_array_resized)    
            plt.show()  # display!
#         else:
#             break

# %%
# resize to 32x32, display first 10 only
all_imgs_resize_in_memory('img', 32, 10)
# Out:
# HBox(children=(IntProgress(value=0, max=3838), HTML(value='')))

# %%
print (len(img_resized))
# Out:
# 3838

# %%
# save all resized image list to a binary file
# so all above code do not need to re-run

import pickle

save_path = 'x_train.pickle'
pickle.dump(img_resized, open(save_path,"wb"))

# %%
######################################################################
# Part 3 - GAN 
# 3.1 load pre-processed images as x train set
# 3.2 implement the GAN model, code ref:
#     book deep learning with python
#     dlnd project 5 source code
# 3.3 after model is trained, generate some new images
######################################################################

# %%
# packages required
import matplotlib.pyplot as plt
import pickle
import numpy as np

# %%
# 3.1 load pre-processed images as x train set

# load data back from pickle
load_path = 'x_train.pickle'
x_train = pickle.load(open(load_path, "rb"))
print (len(x_train))
# Out:
# 3838

# %%
# test load any image from loaded x_train
import random

plt.imshow(random.choice(x_train))
plt.show()

# %%
type(x_train)
# Out:
# list

# %%
# 3.2 implement the GAN model

# Code from book - deep learning with python
# 8.5-introduction-to-gans.ipynb
# https://github.com/fchollet/deep-learning-with-python-notebooks/blob/master/8.5-introduction-to-gans.ipynb

# %%
# No change from original code

import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.2.4'

# %%
import keras
from keras import layers
import numpy as np

# original parameters
# none

# tweak parameters
# none

# these parameters should be fixed
# as input and output images are 32x32, and 3 color channels
latent_dim = 32
height = 32
width = 32
channels = 3

#####################
# No change from here
#####################

generator_input = keras.Input(shape=(latent_dim,))

# First, transform the input into a 16x16 128-channels feature map
x = layers.Dense(128 * 16 * 16)(generator_input)
x = layers.LeakyReLU()(x)
x = layers.Reshape((16, 16, 128))(x)

# Then, add a convolution layer
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# Upsample to 32x32
x = layers.Conv2DTranspose(256, 4, strides=2, padding='same')(x)
x = layers.LeakyReLU()(x)

# Few more conv layers
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# Produce a 32x32 1-channel feature map
x = layers.Conv2D(channels, 7, activation='tanh', padding='same')(x)
generator = keras.models.Model(generator_input, x)
generator.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32768)             1081344
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32768)             0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 256)       819456
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 32, 32, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 3)         37635
# =================================================================
# Total params: 6,264,579
# Trainable params: 6,264,579
# Non-trainable params: 0
# _________________________________________________________________

# %%
# No change from original code structure architect
# but change parameters

# original values
# strides = 2
# drop_out = 0.4
# generated images is bad, nothing like original

# tweaking parameter values
strides = 2
drop_out = 0.8 # better value to avoid overfitting
# generated images is recognisable

discriminator_input = layers.Input(shape=(height, width, channels))
x = layers.Conv2D(128, 3)(discriminator_input)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=strides)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=strides)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=strides)(x)
x = layers.LeakyReLU()(x)
x = layers.Flatten()(x)

# One dropout layer - important trick!
x = layers.Dropout(drop_out)(x)

# Classification layer
x = layers.Dense(1, activation='sigmoid')(x)

discriminator = keras.models.Model(discriminator_input, x)
discriminator.summary()

# To stabilize training, we use learning rate decay
# and gradient clipping (by value) in the optimizer.

# original
# discriminator_optimizer = keras.optimizers.RMSprop(lr=0.0008, clipvalue=1.0, decay=1e-8)

# to tweak later
discriminator_optimizer = keras.optimizers.RMSprop(lr=0.0008, clipvalue=1.0, decay=1e-8)

discriminator.compile(optimizer=discriminator_optimizer, loss='binary_crossentropy')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 30, 30, 128)       3584
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 14, 128)       262272
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 6, 6, 128)         262272
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 2, 2, 128)         262272
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 790,913
# Trainable params: 790,913
# Non-trainable params: 0
# _________________________________________________________________

# %%
# No change from original code

# Set discriminator weights to non-trainable
# (will only apply to the `gan` model)
discriminator.trainable = False

gan_input = keras.Input(shape=(latent_dim,))
gan_output = discriminator(generator(gan_input))
gan = keras.models.Model(gan_input, gan_output)

gan_optimizer = keras.optimizers.RMSprop(lr=0.0004, clipvalue=1.0, decay=1e-8)
gan.compile(optimizer=gan_optimizer, loss='binary_crossentropy')

# %%
# changed from original code
import os
from keras.preprocessing import image

# %%
# Code for loading X, changed to use my own data
x_train = np.array(x_train)

x_train = x_train.reshape(
    (x_train.shape[0],) + (height, width, channels)).astype('float32') / 255.

# %%
###########################################################
# Almost no change from here, except:
#   generated + real images filenames
#   put code into a method to re-train on saved gan weights
###########################################################

def train_model(gan, batch_size, iterations):

    if not os.path.exists('gan_images'):
        os.mkdir('gan_images')
    
    # save_dir = '/home/ubuntu/gan_images/' # book dir path
    save_dir = os.curdir + '/gan_images/'   # my dir path

    # Start training loop
    start = 0
    for step in range(iterations):
        # Sample random points in the latent space
        random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

        # Decode them to fake images
        generated_images = generator.predict(random_latent_vectors)

        # Combine them with real images
        stop = start + batch_size
        real_images = x_train[start: stop]
        combined_images = np.concatenate([generated_images, real_images])

        # Assemble labels discriminating real from fake images
        labels = np.concatenate([np.ones((batch_size, 1)),
                                 np.zeros((batch_size, 1))])
        # Add random noise to the labels - important trick!
        labels += 0.05 * np.random.random(labels.shape)

        # Train the discriminator
        d_loss = discriminator.train_on_batch(combined_images, labels)

        # sample random points in the latent space
        random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

        # Assemble labels that say "all real images"
        misleading_targets = np.zeros((batch_size, 1))

        # Train the generator (via the gan model,
        # where the discriminator weights are frozen)
        a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)

        start += batch_size
        if start > len(x_train) - batch_size:
          start = 0

        # Occasionally save / plot
        if step % 100 == 0:
            # Save model weights
            gan.save_weights('gan.h5')

            # Print metrics
            print('discriminator loss at step %s: %s' % (step, d_loss))
            print('adversarial loss at step %s: %s' % (step, a_loss))

            # Save one generated image
            img = image.array_to_img(generated_images[0] * 255., scale=False)
            img.save(os.path.join(save_dir, 'generated_sprite' + str(step) + '.png'))

            # Save one real image, for comparison
            img = image.array_to_img(real_images[0] * 255., scale=False)
            img.save(os.path.join(save_dir, 'real_sprite' + str(step) + '.png'))

# %%
# gan model load weights
# comment out the follow lines of code if training model from the beginning, 
# with no saved weights

if os.path.exists('saved_gan.h5'):
    gan.load_weights('saved_gan.h5')
    print ('Saved weights is loaded back to the model.')
else:
    print ('No saved weights found.')
# Out:
# Saved weights is loaded back to the model.

# %%
# hyper parameters
# original settings
# iterations = 10000
# batch_size = 20

# tweak parameters
# iterations = 10000
# batch_size = 50
# fair result, face and body shape do look like original images, but too much noise

# iterations = 10000
# batch_size = 200 # ResourceExhaustedError

iterations = 10000
batch_size = 100 # generated acceptable result

train_model(gan, batch_size, iterations)

# rename saved gan file from 'gan.h5' to 'saved_gan.h5'
# to avoid overwritten by model training code if re-run
import os
os.rename('gan.h5', 'saved_gan.h5')
# Out:
# discriminator loss at step 0: 0.1811084
# adversarial loss at step 0: 15.942386

# %%
# save and load generator, so no need to re-train model to generate new images 

# save generator
pickle.dump(generator, open('generator.pickle',"wb"))

# %%
# load generator
load_generator = pickle.load(open('generator.pickle',"rb"))
# Out:
# /home/fi/anaconda3/envs/sentdex/lib/python3.6/site-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
# 3.3 after model is trained, generate some new images
import matplotlib.pyplot as plt

def generate_and_show_images(gen, count):
    # Sample random points in the latent space
    random_latent_vectors = np.random.normal(size=(count, latent_dim))

    # Decode them to fake images
    generated_images = gen.predict(random_latent_vectors)

    for i in range(generated_images.shape[0]):
        img = image.array_to_img(generated_images[i] * 255., scale=False)
        plt.figure()
        plt.imshow(img)

    plt.show()

# %%
generate_and_show_images(load_generator, 10)

# %%
# display best generated images in a grid

import cv2
from tqdm import tnrange, tqdm_notebook

def show_best_generated_imgs(img_folder='best_gen_result'):

    # 1.load images to list
    img_list = []
    
    for file in tqdm_notebook(os.listdir(img_folder)):
        if not file.endswith('.png'):
            continue
            
        img_path = os.path.join(img_folder, file)
        img_array = cv2.imread(img_path, cv2.IMREAD_COLOR)

        # convert back to original color
        img_array_RGB = cv2.cvtColor(img_array,cv2.COLOR_BGR2RGB)

        # add to list
        img_list.append(img_array_RGB)
                
    # 2.display images in a grid
    # copy and pasted from web
    fig=plt.figure(figsize=(12, 12))
    columns = 4
    rows = 5
    for i in range(1, columns*rows +1):
        img = img_list[i]
        fig.add_subplot(rows, columns, i)
        plt.imshow(img)
    plt.show()

# %%
show_best_generated_imgs()
# Out:
# HBox(children=(IntProgress(value=0, max=21), HTML(value='')))

# %%
##########################################################
# Result analysis on generated images in gan_images folder
##########################################################
# train 001 result is rubbish, images mostly a blob of pixels

# train 005 result is much better, training took about 7 hours for 10000 iterations
# with
#   training data - blank images removed
#   training data - mini characters images removed
#   parameter - larger batch size
#   parameter - larger dropout

# The result is not great, the generated images have lot of noise, but recognisable.

# %%
###########################################################
# Ways to improve model training - notes on thu 03 jan 2018
###########################################################
# Data quantity + quality
#   get more ff6 sprite images from websites
#     currently model is training on 3800+ images, 
#     ideally should be 30k images, like some DCGAN examples
#   filter images
#     the character dead pose might not be suitable for training, 
#     could be remove by code
#   cropped images background
#     the bg is cropped on 1st and last image on each row, 
#     the pixels is best fitted on left and right of spritesheet
#     this messes up the train data, and some cropped image bg is stripped with white and black vertically
# GPU upgrade
#   currently using 2015 GTX 960M 2GB, benchmark score is 2279
#   consider 2018 RTX 2070 8GB with Tensor Core, benchmark score is 14383
#     with 16 bit training to double VRam, which allow larger batch size
# Hyper parameters tweaking
#   currently training time is too slow to tweak parameters without waiting a long time  
#   try changing dropout, batch size, learning rate, iterations
#   and latent_dim?
# Architecture
#   add more layers in generator, as the discriminator lost is much smaller 
#   use different lost function and optimizer
#
#   try balance between generator lost and discriminator lost
# result were like the following:
# discriminator loss at step 9700: -0.019410443
# adversarial loss at step 9700: 12.436728
# discriminator loss at step 9800: -0.033391457
# adversarial loss at step 9800: 12.792533
# discriminator loss at step 9900: 0.19051735
# adversarial loss at step 9900: 15.333755
